# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from sys import exit
from osgeo import gdal,gdalconst
import matplotlib.pyplot as plt
from numba import njit
from numba import jit
import os
import xarray
plt.style.use('seaborn')
plt.rcParams['figure.figsize'] = 20, 12

# %%
#BORDERS
countries=["United States of America","Spain"]

def get_borders(country):
    borders=gdal.Open("./data/national_grids/gpw_v4_national_identifier_grid_rev11_30_min.tif").ReadAsArray()
    reference=pd.read_excel("./data/national_grids/gpw-v4-documentation-rev11/gpw-v4-country-level-summary-rev11.xlsx",
                            sheet_name="GPWv4 Rev11 Summary",skiprows=1)
    reference=reference.loc[reference.iloc[:,0]==country,"ISO Numeric"].values[0]
    return (borders==reference).astype("int8")

# %%
#Population version: 

###
# isimip2b.input_secondary.population.ssp2soc.population.yearly
# Description: Population data set prepared for ISIMIP2b. Data Set Details: https://www.isimip.org/gett..., ISIMIP Terms of Use: https://www.isimip.org/prot..., Published under CC BY 4.0 licence.
# Data Node: esg.pik-potsdam.de
# Version: 20200716
# http://esg.pik-potsdam.de/thredds/fileServer/isimip_dataroot_2/isimip2b/input_secondary/population/ssp2soc/population/yearly/v20200716/population_ssp2soc_0p5deg_annual_2006-2100.nc
##

def get_population(year):
    
    if (year<2006)|(year>2100):
        print("Year out of range. Only the period 2006-2100 is available")
        exit
    else:
        return gdal.Open("./data/population/population_ssp2soc_0p5deg_annual_2006-2100.nc").ReadAsArray()[(year-2006),:,:]

# %%
un_translate={"Czech Republic":"Czechia",
                 'United Kingdom of Great Britain and Northern Ireland':"United Kingdom",
             "Cape Verde":"Cabo Verde",
             "Micronesia (Federated States of)":"Micronesia (Fed. States of)",
             "The former Yugoslav Republic of Macedonia":"North Macedonia",
             "Democratic People's Republic of Korea":"Dem. People's Republic of Korea",
             "Taiwan":"China, Taiwan Province of China","Western Samoa":"Samoa"
}
    
def get_proportions(country,year=2015):
    if year==2016:
        year=2015
    if year<=2020:
        un=pd.read_excel("./data/population/WPP2019_POP_F07_1_POPULATION_BY_AGE_BOTH_SEXES.xlsx",sheet_name="ESTIMATES",
                        skiprows=16)
    else:
        un=pd.read_excel("./data/population/WPP2019_POP_F07_1_POPULATION_BY_AGE_BOTH_SEXES.xlsx",sheet_name="HIGH VARIANT",
                        skiprows=16)
    un=un[un["Reference date (as of 1 July)"]==year]

    
    if country in un_translate.keys():
        country=un_translate[country]
    
    df=un[un["Region, subregion, country or area *"]==country]
    
    df["95+"]=df["95-99"]+df["100+"]
    df.drop(["95-99","100+"],axis=1,inplace=True)
    df=df.iloc[:,8:] #Getting ages
    df=df.iloc[0,:]/df.sum(axis=1).values #Calculating proportions
    return df.values

# %%
gbd_translate={"Iran":"Iran (Islamic Republic of)",
                  "The Gambia":"Gambia","Cote d'Ivoire":"Côte d'Ivoire","Tanzania":"United Republic of Tanzania",
                  "Moldova":"Republic of Moldova","Vietnam":"Viet Nam","Brunei":"Brunei Darussalam",
                  "The Bahamas":"Bahamas","South Korea":"Republic of Korea",
                  "Venezuela":"Venezuela (Bolivarian Republic of)","Syria":"Syrian Arab Republic",
                  "Laos":"Lao People's Democratic Republic","Bolivia":"Bolivia (Plurinational State of)",
               "United States":"United States of America",
              "Palestine":"State of Palestine",
              "United Kingdom":"United Kingdom of Great Britain and Northern Ireland",
               "Virgin Islands, U.S.":"United States Virgin Islands",
               "Federated States of Micronesia":"Micronesia (Federated States of)",
               "Macedonia":"The former Yugoslav Republic of Macedonia",
               "North Korea":"Democratic People's Republic of Korea",
               "Taiwan (Province of China)":"Taiwan",
               "Samoa":"Western Samoa"
               
              }
gbd_translate= {v: k for k, v in gbd_translate.items()}

causes_rr=["LRI","COPD","IHD","STROKE","LC","ALL"]


def get_mort(country,year):
    ind={"LC":"LC_ALL_RISKS_MORT","IHD":"IHD_ALL_RISKS_MORT_AGEGR","STROKE":"STROKE_ALL_RISKS_MORT_AGEGR",
    "LRI":"LRI_ALL_RISKS_MORT","COPD":"COPD_ALL_RISKS_MORT"}
    results={}
    if country in gbd_translate.keys():
        country=gbd_translate[country]
    for cause in causes_rr[:-1]:
        rita_file=pd.read_excel("./data/GBD_data/MORTALITY_RATES_COUNTRIES_PROJ_GBD2017_6COD.xlsx",sheet_name=ind[cause])
        if (year==2010)|(year==2016):
            rita_file=rita_file[(rita_file.location_name==country)&(rita_file.year==2015)]
        elif year==2050:
            rita_file=rita_file[(rita_file.location_name==country)&(rita_file.year==2040)]
        else:
            rita_file=rita_file[(rita_file.location_name==country)&(rita_file.year==year)]
        results[cause]=rita_file.val.values
        
    return results    
get_mort("United States of America",2016)
# Out:
# {'LRI': array([27.84745996]),
#  'COPD': array([50.81945422]),
#  'IHD': array([2.29439798e+00, 5.18871831e+00, 1.03150228e+01, 2.01022951e+01,
#         3.82387801e+01, 7.31424524e+01, 1.20868477e+02, 1.82900921e+02,
#         2.56995614e+02, 4.02985929e+02, 6.60646711e+02, 1.17942551e+03,
#         2.23573298e+03, 4.17560391e+03, 8.79766142e+03]),
#  'STROKE': array([1.25193327e+00, 2.26276794e+00, 3.80088348e+00, 6.40453667e+00,
#         1.03871426e+01, 1.80309267e+01, 2.86589932e+01, 4.37472038e+01,
#         6.68164031e+01, 1.20270048e+02, 2.25870068e+02, 4.39699235e+02,
#         8.33266084e+02, 1.47290654e+03, 2.72464442e+03]),
#  'LC': array([55.5583539])}

# %%
def get_coefficients(cause_rr):
    rr=pd.read_csv("./data/GBD_data/RR_PARAMS_GBD2018.csv",sep=",")
    cause=rr[rr["COD"]==cause_rr]
    return cause["alpha_med"].values,cause["beta_med"].values,cause["delta_med"].values,cause["zcf_med"].values

@njit
def get_rr_array(alpha,beta,delta,zcf,conc_array,cause):
    a=conc_array.shape[0]
    b=conc_array.shape[1]
    c=len(alpha)
    rr_array=np.ones((c,a,b))
    for k in range(c):
        for i in range(a):
            for j in range(b):
                if conc_array[i,j]>zcf[k]:    
                    rr_array[k,i,j]=1+(alpha[k]*(1-np.exp(-beta[k]*(conc_array[i,j]-zcf[k])**delta[k])))               
    return rr_array
    
    
#@njit
def process_array(population_array,conc_array,proportions,mort_rate,cause,rr_array):

    results=conc_array*0.

    for i in range(population_array.shape[0]):
        for j in range(population_array.shape[1]):
            if (population_array[i,j]==0.):
                results[i,j]=0.
            else:
                if cause in ["IHD","STROKE"]:
                    atr_mortality=mort_rate[-15:]*(rr_array[:,i,j]-1)
                    mort=np.dot(population_array[i,j]*proportions[-15:]/100000,atr_mortality)

                else:

                    atr_mortality=mort_rate*(rr_array[:,i,j]-1)
                    mort=population_array[i,j]*atr_mortality/100000
                results[i,j]=mort
                
    return results

@njit
def population_weighted_conc(population_array,conc_array):
    results=0.
    pop=0
    for i in range(population_array.shape[0]):
        for j in range(population_array.shape[1]):
            if (conc_array[i,j]>=0) & (population_array[i,j]>0):
                results+=(population_array[i,j]*conc_array[i,j])
                pop+=population_array[i,j]
    return results/pop

# %% [markdown]
# ## MARIANNE PM25 AND SALT FROM AMAP

# %%
salt=xarray.open_dataset("./data/model_layers/pm25_sea_salt_dust_amap.nc")
print(salt)
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 360, lon: 720)
# Coordinates:
#   * lat      (lat) float64 -89.75 -89.25 -88.75 -88.25 ... 88.75 89.25 89.75
#   * lon      (lon) float64 -179.8 -179.2 -178.8 -178.2 ... 178.8 179.2 179.8
# Data variables:
#     pm25     (lat, lon) float32 ...
# Attributes:
#     comment:       contact: knut.vonsalzen@canada.ca
#     data_licence:  1) GRANT OF LICENCE - The Government of Canada (Environmen...

# %%
model_dir="./data/model_layers/corrected/"

year=2016
scenario=""
model=salt["pm25"].data

files=sorted([x for x in os.listdir(model_dir) if (str(year) in x)&(scenario in x)&("speciated" not in x)])

files
# Out:
# ['OsloCTM3_pm25_surfaceconc_annual_2016_ECLv6_PM25.nc',
#  'OsloCTM3_pm25_surfaceconc_annual_2016_ECLv6_PM25.nc.aux.xml']

# %%
plt.subplots(figsize=(20,12))
plt.imshow(np.flipud(model),cmap="Spectral_r")
plt.axis("off")
plt.colorbar(extend="both",orientation="horizontal",aspect=50,pad=-0.1)

# %% [markdown]
# Estimation using AMAP salt layer

# %%
def save_raster(array,raster_template,output_name,fill=False):

    ds = gdal.Open(raster_template)
    band = ds.GetRasterBand(1)
    arr = band.ReadAsArray()
    [cols, rows] = arr.shape

    driver = gdal.GetDriverByName("GTiff")
    outdata = driver.Create(output_name, rows, cols, 1, gdal.GDT_Float32)
    outdata.GetRasterBand(1).SetNoDataValue(-9999)
    outdata.SetGeoTransform(ds.GetGeoTransform())##sets same geotransform as input
    outdata.SetProjection(ds.GetProjection())##sets same projection as input
    outdata.GetRasterBand(1).WriteArray(array)
    if fill:
        result = gdal.FillNodata(targetBand =outdata.GetRasterBand(1), maskBand = None, 
                     maxSearchDist = 50, smoothingIterations = 2)

    outdata.FlushCache() ##saves to disk!!
    outdata = None
    band=None
    ds=None

# %%
#scenarios=[""]
#years=[2010]



def get_conc_array(year=2015,scenario="CLE"):
    amapdir="/home/gaia/Documents/AMAP/repo/data/Model_data/PM25/downscaled/"
    salt=xarray.open_dataset("./data/model_layers/pm25_sea_salt_dust_amap.nc")

    model_dir="./data/model_layers/corrected/"

    model=0.*salt["pm25"].data

    files=sorted([x for x in os.listdir(model_dir) if (str(year) in x)&(scenario in x)&("xml" not in x)])
    variables=["BC","NO3","OA","POA","SO4"]
    for i in range(len(variables)):
        
        model=model+xarray.open_dataset(os.path.join(model_dir,files[i]),engine="netcdf4")[variables[i]].data
    return(np.flipud(model))

def process_all(year,scenario):
    country="China"
    #c -> country class
    
    

        
        
    #         year_band={2010:4,2030:6,2050:8}
    #         population_file="./data/SSP2_POP_GRID_0.5x0.5.tif"
    population_raster=get_borders(country)*get_population(year)
    proportions=get_proportions(country,year)

    print("Total population ",np.sum(population_raster))
    print("Done")

    mortality=get_mort(country,year)
    

    yearidx={2016:1,2030:2,2050:3}
    
    model_raster=get_conc_array(year=year,scenario=scenario)


    health_impacts={}
    age_impacts={}
    rr_arrays={}
    for cause in ["COPD","LRI","LC","IHD","STROKE"]:

        alpha,beta,delta,zcf=get_coefficients(cause)

        rr_array=get_rr_array(alpha,beta,delta,zcf,model_raster,cause)
        rr_arrays[cause]=rr_array
        health_impacts[cause]=process_array(population_raster,model_raster,proportions,
                                         mortality[cause],cause,rr_array)

   
    weighted_conc=population_weighted_conc(population_raster,model_raster)
    results=[rr_arrays,weighted_conc,health_impacts]
    
    return results

# %% [markdown]
# Estimation using PM25 from OsloCTM

# %%
get_conc_array(year=2016,scenario="")
# Out:
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]])

# %%
_,pwc,impacts=process_all(2016,"")
# Out:
# <ipython-input-4-63806c324160>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["95+"]=df["95-99"]+df["100+"]
# /home/gaia/anaconda3/envs/gis/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# Total population  1364991500.0
# Done

# %%
scenarios=["","CLE","MFR","CLE","MFR"]
years=[2016,2030,2030,2050,2050]
results=pd.DataFrame()
for  i in range(len(scenarios)):
    scenario=scenarios[i]
    year=years[i]
    _,pwc,impacts=process_all(year,scenario)
    total=impacts["COPD"]+impacts["LRI"]+impacts["LC"]+impacts["STROKE"]+impacts["IHD"]
    save_raster(total,"/home/gaia/Documents/AMAP/repo/data/EMEP_Average_2014_2015.tif","./impacts_v2/impacts_"+str(year)+scenario+"_nodust.tif")
    print("Finished ok")
# Out:
# <ipython-input-16-82b1195e0ba6>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["95+"]=df["95-99"]+df["100+"]
# /home/gaia/anaconda3/envs/gis/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# Total population  1364991500.0
# Done
# Finished ok
# <ipython-input-16-82b1195e0ba6>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["95+"]=df["95-99"]+df["100+"]
# /home/gaia/anaconda3/envs/gis/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# Total population  1381881700.0
# Done
# Finished ok
# <ipython-input-16-82b1195e0ba6>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["95+"]=df["95-99"]+df["100+"]
# /home/gaia/anaconda3/envs/gis/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# Total population  1381881700.0
# Done
# Finished ok
# <ipython-input-16-82b1195e0ba6>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["95+"]=df["95-99"]+df["100+"]
# /home/gaia/anaconda3/envs/gis/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# Total population  1264786800.0
# Done
# Finished ok
# <ipython-input-16-82b1195e0ba6>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["95+"]=df["95-99"]+df["100+"]
# /home/gaia/anaconda3/envs/gis/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# Total population  1264786800.0
# Done
# Finished ok

# %%
scenarios=["","CLE","MFR","CLE","MFR"]
years=[2016,2030,2030,2050,2050]
results=pd.DataFrame()
for  i in range(len(scenarios)):
    scenario=scenarios[i]
    year=years[i]
    _,pwc,impacts=process_all(year,scenario)
    results=results.append({"country":"China","year":year,"scenario":scenario,"pwc":pwc,"COPD":np.sum(impacts["COPD"]),
                       "LRI":np.sum(impacts["LRI"]),"LC":np.sum(impacts["LC"]),"IHD":np.sum(impacts["IHD"]),
                       "STROKE":np.sum(impacts["STROKE"])},ignore_index=True)
    print("Finished ok")
# Out:
# <ipython-input-16-82b1195e0ba6>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["95+"]=df["95-99"]+df["100+"]
# /home/gaia/anaconda3/envs/gis/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# Total population  1364991500.0
# Done
# Finished ok
# <ipython-input-16-82b1195e0ba6>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["95+"]=df["95-99"]+df["100+"]
# /home/gaia/anaconda3/envs/gis/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# Total population  1381881700.0
# Done
# Finished ok
# <ipython-input-16-82b1195e0ba6>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["95+"]=df["95-99"]+df["100+"]
# /home/gaia/anaconda3/envs/gis/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# Total population  1381881700.0
# Done
# Finished ok
# <ipython-input-16-82b1195e0ba6>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["95+"]=df["95-99"]+df["100+"]
# /home/gaia/anaconda3/envs/gis/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# Total population  1264786800.0
# Done
# Finished ok
# <ipython-input-16-82b1195e0ba6>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["95+"]=df["95-99"]+df["100+"]
# /home/gaia/anaconda3/envs/gis/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# Total population  1264786800.0
# Done
# Finished ok

# %%
results.to_csv(".first_results_china_v2_nodust.csv")

# %%
from pyresample.bilinear import NumpyBilinearResampler
from pyresample.geometry import SwathDefinition


def_b = SwathDefinition(lons=z.variables["lon"], lats=z.variables["lat"])

res= NumpyBilinearResampler(def_b, area_def,radius_of_influence=50000)
results=res.resample(z.variables["TX"].data[0,:,:])

# %%
gdal.Open("./data/paper/pm25_downscaled_CESM_2015.nc").ReadAsArray()
# Out:
# array([[-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#        [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#        [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#        ...,
#        [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#        [-9999., -9999., -9999., ..., -9999., -9999., -9999.],
#        [-9999., -9999., -9999., ..., -9999., -9999., -9999.]])

# %%
def save_raster(array,out_transform,out_meta,output_fname):
    out_meta.update({"driver": "GTiff",
                 "height": array.shape[1],
                 "width": array.shape[2],
                 "transform": out_transform})

    with rasterio.open(output_fname, "w", **out_meta) as dest:
        dest.write(array)

def process_all(country,year,model_file=gdal.Open("./data/paper/pm25_downscaled_emulator_SLCF_total.nc").GetSubDatasets()[3][0],output=False):
    #c -> country class
    
    

        
        
    #         year_band={2010:4,2030:6,2050:8}
    #         population_file="./data/SSP2_POP_GRID_0.5x0.5.tif"
    population_raster=get_borders(country)*get_population(year)
    proportions=get_proportions(country,year)

    print("Total population ",np.sum(population_raster))
    print("Done")

    mortality=get_mort(country,year)
    

    yearidx={2015:1,2030:2,2050:3}
    
    model_array=gdal.Open(model_file).ReadAsArray()[yearidx[year],:,:]
    print(model_array.shape)
    
    dust_array=gdal.Open("./data/pm25_salt.nc").ReadAsArray()


    model_raster=(model_array+dust_array)

    print("Done")


    health_impacts={}
    age_impacts={}
    rr_arrays={}
    for cause in ["COPD","LRI","LC","IHD","STROKE"]:

        alpha,beta,delta,zcf=get_coefficients(cause)

        rr_array=get_rr_array(alpha,beta,delta,zcf,model_raster,cause)
        rr_arrays[cause]=rr_array
        health_impacts[cause]=process_array(population_raster,model_raster,proportions,
                                         mortality[cause],cause,rr_array)

    if output:
        save_raster(np.expand_dims(health_impacts,0),model_transform,model_meta,os.path.join(os.getcwd(),results,country_name+"_"+cause+"_"+str(year)+".tiff"))

    weighted_conc=population_weighted_conc(population_raster,model_raster)
    results=[rr_arrays,weighted_conc,health_impacts]
    
    return results

# %%
with open("./data/non_included_countries.txt", "r") as file:
    non_included_countries = eval(file.readline())
reference=pd.read_excel("./data/national_grids/gpw-v4-documentation-rev11/gpw-v4-country-level-summary-rev11.xlsx",
                       sheet_name="GPWv4 Rev11 Summary",skiprows=1)
countries=reference["Country or Territory Name"].unique()
countries=[x for x in countries if x not in non_included_countries]
reference=None

# %%
results=pd.DataFrame()
check_these=[]

for country in countries:
    print(country)
    try:
        _,pwc,impacts=process_all(country,2050)
        results=results.append({"country":country,"year":2050,"scenario":"SLCF","pwc":pwc,"COPD":np.sum(impacts["COPD"]),
                       "LRI":np.sum(impacts["LRI"]),"LC":np.sum(impacts["LC"]),"IHD":np.sum(impacts["IHD"]),
                       "STROKE":np.sum(impacts["STROKE"])},ignore_index=True)
        print("Finished ok")
    except:
        check_these.append(country)
# Out:
# Afghanistan
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Total population  49244372.0
# Done
# (360, 720)
# Done
# Finished ok
# Angola
# Total population  77523120.0
# Done
# (360, 720)
# Done
# Finished ok
# Albania
# Total population  2673423.2
# Done
# (360, 720)
# Done
# Finished ok
# United Arab Emirates
# Total population  16816204.0
# Done
# (360, 720)
# Done
# Finished ok
# Argentina
# Total population  52678916.0
# Done
# (360, 720)
# Done
# Finished ok
# Armenia
# Total population  6759971.5
# Done
# (360, 720)
# Done
# Finished ok
# Antigua and Barbuda
# Total population  94557.086
# Done
# (360, 720)
# Done
# Australia
# Total population  36032548.0
# Done
# (360, 720)
# Done
# Finished ok
# Austria
# Total population  8329247.0
# Done
# (360, 720)
# Done
# Finished ok
# Azerbaijan
# Total population  11838818.0
# Done
# (360, 720)
# Done
# Finished ok
# Burundi
# Total population  12961723.0
# Done
# (360, 720)
# Done
# Finished ok
# Belgium
# Total population  20892184.0
# Done
# (360, 720)
# Done
# Finished ok
# Benin
# Total population  16168856.0
# Done
# (360, 720)
# Done
# Finished ok
# Burkina Faso
# Total population  27748346.0
# Done
# (360, 720)
# Done
# Finished ok
# Bangladesh
# Total population  187424600.0
# Done
# (360, 720)
# Done
# Finished ok
# Bulgaria
# Total population  8309397.0
# Done
# (360, 720)
# Done
# Finished ok
# Bahrain
# Total population  726788.25
# Done
# (360, 720)
# Done
# Bahamas
# Total population  478394.6
# Done
# (360, 720)
# Done
# Bosnia and Herzegovina
# Total population  3571564.8
# Done
# (360, 720)
# Done
# Finished ok
# Belarus
# Total population  7301416.0
# Done
# (360, 720)
# Done
# Finished ok
# Belize
# Total population  504933.62
# Done
# (360, 720)
# Done
# Finished ok
# Bolivia (Plurinational State of)
# Total population  12840369.0
# Done
# (360, 720)
# Done
# Finished ok
# Brazil
# Total population  230907260.0
# Done
# (360, 720)
# Done
# Finished ok
# Barbados
# Total population  267511.94
# Done
# (360, 720)
# Done
# Brunei Darussalam
# Total population  2473525.2
# Done
# (360, 720)
# Done
# Finished ok
# Bhutan
# Total population  8638305.0
# Done
# (360, 720)
# Done
# Finished ok
# Botswana
# Total population  2645115.2
# Done
# (360, 720)
# Done
# Finished ok
# Central African Republic
# Total population  8258114.0
# Done
# (360, 720)
# Done
# Finished ok
# Canada
# Total population  49904030.0
# Done
# (360, 720)
# Done
# Finished ok
# Switzerland
# Total population  4259457.0
# Done
# (360, 720)
# Done
# Finished ok
# Chile
# Total population  19455236.0
# Done
# (360, 720)
# Done
# Finished ok
# China
# Total population  1221801300.0
# Done
# (360, 720)
# Done
# Finished ok
# Côte d'Ivoire
# Total population  41298484.0
# Done
# (360, 720)
# Done
# Finished ok
# Cameroon
# Total population  35392824.0
# Done
# (360, 720)
# Done
# Finished ok
# Democratic Republic of the Congo
# Total population  99535080.0
# Done
# (360, 720)
# Done
# Finished ok
# Congo
# Total population  24308012.0
# Done
# (360, 720)
# Done
# Finished ok
# Colombia
# Total population  62043676.0
# Done
# (360, 720)
# Done
# Finished ok
# Comoros
# Total population  1286876.4
# Done
# (360, 720)
# Done
# Cape Verde
# Total population  573207.7
# Done
# (360, 720)
# Done
# Costa Rica
# Total population  6678739.0
# Done
# (360, 720)
# Done
# Finished ok
# Cuba
# Total population  9214239.0
# Done
# (360, 720)
# Done
# Finished ok
# Cyprus
# Total population  2321872.5
# Done
# (360, 720)
# Done
# Czech Republic
# Total population  9130968.0
# Done
# (360, 720)
# Done
# Finished ok
# Germany
# Total population  82523816.0
# Done
# (360, 720)
# Done
# Finished ok
# Djibouti
# Total population  8907546.0
# Done
# (360, 720)
# Done
# Finished ok
# Denmark
# Total population  3594485.5
# Done
# (360, 720)
# Done
# Finished ok
# Dominican Republic
# Total population  11695218.0
# Done
# (360, 720)
# Done
# Finished ok
# Algeria
# Total population  49986348.0
# Done
# (360, 720)
# Done
# Finished ok
# Ecuador
# Total population  20828240.0
# Done
# (360, 720)
# Done
# Finished ok
# Egypt
# Total population  124381656.0
# Done
# (360, 720)
# Done
# Finished ok
# Eritrea
# Total population  12914818.0
# Done
# (360, 720)
# Done
# Finished ok
# Spain
# Total population  54796092.0
# Done
# (360, 720)
# Done
# Finished ok
# Estonia
# Total population  1361644.2
# Done
# (360, 720)
# Done
# Finished ok
# Ethiopia
# Total population  123825064.0
# Done
# (360, 720)
# Done
# Finished ok
# Finland
# Total population  7328066.0
# Done
# (360, 720)
# Done
# Finished ok
# Fiji
# Total population  969505.44
# Done
# (360, 720)
# Done
# France
# Total population  70717990.0
# Done
# (360, 720)
# Done
# Finished ok
# Micronesia (Federated States of)
# Total population  104826.195
# Done
# (360, 720)
# Done
# Gabon
# Total population  3514875.0
# Done
# (360, 720)
# Done
# Finished ok
# United Kingdom of Great Britain and Northern Ireland
# Total population  75683870.0
# Done
# (360, 720)
# Done
# Finished ok
# Georgia
# Total population  3610861.2
# Done
# (360, 720)
# Done
# Finished ok
# Ghana
# Total population  41692040.0
# Done
# (360, 720)
# Done
# Finished ok
# Guinea
# Total population  16596372.0
# Done
# (360, 720)
# Done
# Finished ok
# Gambia
# Total population  5256427.5
# Done
# (360, 720)
# Done
# Finished ok
# Guinea-Bissau
# Total population  1341475.5
# Done
# (360, 720)
# Done
# Finished ok
# Equatorial Guinea
# Total population  902017.8
# Done
# (360, 720)
# Done
# Finished ok
# Greece
# Total population  10250518.0
# Done
# (360, 720)
# Done
# Finished ok
# Grenada
# Total population  100846.36
# Done
# (360, 720)
# Done
# Guatemala
# Total population  16915826.0
# Done
# (360, 720)
# Done
# Finished ok
# Guam
# Total population  0.0
# Done
# (360, 720)
# Done
# Guyana
# Total population  732178.25
# Done
# (360, 720)
# Done
# Finished ok
# Honduras
# Total population  16258581.0
# Done
# (360, 720)
# Done
# Finished ok
# Croatia
# Total population  4962409.0
# Done
# (360, 720)
# Done
# Finished ok
# Haiti
# Total population  14184253.0
# Done
# (360, 720)
# Done
# Finished ok
# Hungary
# Total population  6551822.0
# Done
# (360, 720)
# Done
# Finished ok
# Indonesia
# Total population  276818940.0
# Done
# (360, 720)
# Done
# Finished ok
# India
# Total population  1678369800.0
# Done
# (360, 720)
# Done
# Finished ok
# Ireland
# Total population  5606626.5
# Done
# (360, 720)
# Done
# Finished ok
# Iran (Islamic Republic of)
# Total population  104587780.0
# Done
# (360, 720)
# Done
# Finished ok
# Iraq
# Total population  71941710.0
# Done
# (360, 720)
# Done
# Finished ok
# Iceland
# Total population  492265.7
# Done
# (360, 720)
# Done
# Finished ok
# Israel
# Total population  16665209.0
# Done
# (360, 720)
# Done
# Finished ok
# Italy
# Total population  63350972.0
# Done
# (360, 720)
# Done
# Finished ok
# Jamaica
# Total population  2785828.0
# Done
# (360, 720)
# Done
# Finished ok
# Jordan
# Total population  13549134.0
# Done
# (360, 720)
# Done
# Finished ok
# Japan
# Total population  108813500.0
# Done
# (360, 720)
# Done
# Finished ok
# Kazakhstan
# Total population  16603288.0
# Done
# (360, 720)
# Done
# Finished ok
# Kenya
# Total population  88905200.0
# Done
# (360, 720)
# Done
# Finished ok
# Kyrgyzstan
# Total population  6024434.0
# Done
# (360, 720)
# Done
# Finished ok
# Cambodia
# Total population  13794449.0
# Done
# (360, 720)
# Done
# Finished ok
# Kiribati
# Total population  128808.16
# Done
# (360, 720)
# Done
# Republic of Korea
# Total population  51260256.0
# Done
# (360, 720)
# Done
# Finished ok
# Kuwait
# Total population  5032916.5
# Done
# (360, 720)
# Done
# Finished ok
# Lao People's Democratic Republic
# Total population  3538921.0
# Done
# (360, 720)
# Done
# Finished ok
# Lebanon
# Total population  7084520.0
# Done
# (360, 720)
# Done
# Finished ok
# Liberia
# Total population  9844914.0
# Done
# (360, 720)
# Done
# Finished ok
# Libya
# Total population  10853371.0
# Done
# (360, 720)
# Done
# Finished ok
# Saint Lucia
# Total population  125013.555
# Done
# (360, 720)
# Done
# Sri Lanka
# Total population  24188050.0
# Done
# (360, 720)
# Done
# Finished ok
# Lesotho
# Total population  884214.75
# Done
# (360, 720)
# Done
# Finished ok
# Lithuania
# Total population  2842458.2
# Done
# (360, 720)
# Done
# Finished ok
# Luxembourg
# Total population  1230641.5
# Done
# (360, 720)
# Done
# Finished ok
# Latvia
# Total population  2264379.0
# Done
# (360, 720)
# Done
# Finished ok
# Morocco
# Total population  37342360.0
# Done
# (360, 720)
# Done
# Finished ok
# Republic of Moldova
# Total population  2049582.5
# Done
# (360, 720)
# Done
# Finished ok
# Madagascar
# Total population  45111480.0
# Done
# (360, 720)
# Done
# Finished ok
# Maldives
# Total population  457388.4
# Done
# (360, 720)
# Done
# Mexico
# Total population  109813660.0
# Done
# (360, 720)
# Done
# Finished ok
# The former Yugoslav Republic of Macedonia
# Total population  1809045.0
# Done
# (360, 720)
# Done
# Finished ok
# Mali
# Total population  30513578.0
# Done
# (360, 720)
# Done
# Finished ok
# Malta
# Total population  443075.53
# Done
# (360, 720)
# Done
# Myanmar
# Total population  58572950.0
# Done
# (360, 720)
# Done
# Finished ok
# Montenegro
# Total population  1459243.9
# Done
# (360, 720)
# Done
# Finished ok
# Mongolia
# Total population  2970964.8
# Done
# (360, 720)
# Done
# Finished ok
# Mozambique
# Total population  49583204.0
# Done
# (360, 720)
# Done
# Finished ok
# Mauritania
# Total population  7282138.5
# Done
# (360, 720)
# Done
# Finished ok
# Mauritius
# Total population  1469389.5
# Done
# (360, 720)
# Done
# Malawi
# Total population  37064500.0
# Done
# (360, 720)
# Done
# Finished ok
# Malaysia
# Total population  37744748.0
# Done
# (360, 720)
# Done
# Finished ok
# Namibia
# Total population  3372814.2
# Done
# (360, 720)
# Done
# Finished ok
# Niger
# Total population  34667160.0
# Done
# (360, 720)
# Done
# Finished ok
# Nigeria
# Total population  389854270.0
# Done
# (360, 720)
# Done
# Finished ok
# Nicaragua
# Total population  7215163.0
# Done
# (360, 720)
# Done
# Finished ok
# Netherlands
# Total population  13579382.0
# Done
# (360, 720)
# Done
# Finished ok
# Norway
# Total population  7055287.5
# Done
# (360, 720)
# Done
# Finished ok
# Nepal
# Total population  47900064.0
# Done
# (360, 720)
# Done
# Finished ok
# New Zealand
# Total population  5938553.5
# Done
# (360, 720)
# Done
# Finished ok
# Oman
# Total population  5647386.5
# Done
# (360, 720)
# Done
# Finished ok
# Pakistan
# Total population  329160060.0
# Done
# (360, 720)
# Done
# Finished ok
# Panama
# Total population  5134732.5
# Done
# (360, 720)
# Done
# Finished ok
# Peru
# Total population  35279170.0
# Done
# (360, 720)
# Done
# Finished ok
# Philippines
# Total population  149040050.0
# Done
# (360, 720)
# Done
# Finished ok
# Papua New Guinea
# Total population  12407016.0
# Done
# (360, 720)
# Done
# Finished ok
# Poland
# Total population  36847564.0
# Done
# (360, 720)
# Done
# Finished ok
# Puerto Rico
# Total population  2596228.0
# Done
# (360, 720)
# Done
# Finished ok
# Democratic People's Republic of Korea
# Total population  21866334.0
# Done
# (360, 720)
# Done
# Finished ok
# Portugal
# Total population  10082628.0
# Done
# (360, 720)
# Done
# Finished ok
# Paraguay
# Total population  8922056.0
# Done
# (360, 720)
# Done
# Finished ok
# State of Palestine
# Total population  4263884.0
# Done
# (360, 720)
# Done
# Finished ok
# Qatar
# Total population  5551301.0
# Done
# (360, 720)
# Done
# Finished ok
# Romania
# Total population  19719272.0
# Done
# (360, 720)
# Done
# Finished ok
# Russian Federation
# Total population  139683650.0
# Done
# (360, 720)
# Done
# Finished ok
# Rwanda
# Total population  27950554.0
# Done
# (360, 720)
# Done
# Finished ok
# Saudi Arabia
# Total population  58739884.0
# Done
# (360, 720)
# Done
# Finished ok
# Sudan
# Total population  80175500.0
# Done
# (360, 720)
# Done
# Finished ok
# Senegal
# Total population  26714344.0
# Done
# (360, 720)
# Done
# Finished ok
# Singapore
# Total population  21034620.0
# Done
# (360, 720)
# Done
# Solomon Islands
# Total population  951951.9
# Done
# (360, 720)
# Done
# Sierra Leone
# Total population  11428028.0
# Done
# (360, 720)
# Done
# Finished ok
# El Salvador
# Total population  6811854.5
# Done
# (360, 720)
# Done
# Finished ok
# Somalia
# Total population  33854184.0
# Done
# (360, 720)
# Done
# Finished ok
# Serbia
# Total population  7090900.5
# Done
# (360, 720)
# Done
# Finished ok
# South Sudan
# Total population  1477360.6
# Done
# (360, 720)
# Done
# Finished ok
# Sao Tome and Principe
# Total population  211232.31
# Done
# (360, 720)
# Done
# Suriname
# Total population  629316.9
# Done
# (360, 720)
# Done
# Finished ok
# Slovakia
# Total population  5747221.5
# Done
# (360, 720)
# Done
# Finished ok
# Slovenia
# Total population  3188797.0
# Done
# (360, 720)
# Done
# Finished ok
# Sweden
# Total population  14272290.0
# Done
# (360, 720)
# Done
# Finished ok
# Seychelles
# Total population  10658.664
# Done
# (360, 720)
# Done
# Syrian Arab Republic
# Total population  28327852.0
# Done
# (360, 720)
# Done
# Finished ok
# Chad
# Total population  21504286.0
# Done
# (360, 720)
# Done
# Finished ok
# Togo
# Total population  15655740.0
# Done
# (360, 720)
# Done
# Finished ok
# Thailand
# Total population  74618270.0
# Done
# (360, 720)
# Done
# Finished ok
# Tajikistan
# Total population  7297868.0
# Done
# (360, 720)
# Done
# Finished ok
# Turkmenistan
# Total population  12722112.0
# Done
# (360, 720)
# Done
# Finished ok
# Timor-Leste
# Total population  1489204.9
# Done
# (360, 720)
# Done
# Finished ok
# Tonga
# Total population  106193.35
# Done
# (360, 720)
# Done
# Trinidad and Tobago
# Total population  1596754.2
# Done
# (360, 720)
# Done
# Finished ok
# Tunisia
# Total population  12338455.0
# Done
# (360, 720)
# Done
# Finished ok
# Turkey
# Total population  93639310.0
# Done
# (360, 720)
# Done
# Finished ok
# Taiwan
# Total population  59913676.0
# Done
# (360, 720)
# Done
# United Republic of Tanzania
# Total population  104722700.0
# Done
# (360, 720)
# Done
# Finished ok
# Uganda
# Total population  73668120.0
# Done
# (360, 720)
# Done
# Finished ok
# Ukraine
# Total population  38030252.0
# Done
# (360, 720)
# Done
# Finished ok
# Uruguay
# Total population  3200441.2
# Done
# (360, 720)
# Done
# Finished ok
# United States of America
# Total population  438487940.0
# Done
# (360, 720)
# Done
# Finished ok
# Uzbekistan
# Total population  33338624.0
# Done
# (360, 720)
# Done
# Finished ok
# Saint Vincent and the Grenadines
# Total population  119111.55
# Done
# (360, 720)
# Done
# Venezuela (Bolivarian Republic of)
# Total population  42508540.0
# Done
# (360, 720)
# Done
# Finished ok
# United States Virgin Islands
# Total population  108732.19
# Done
# (360, 720)
# Done
# Viet Nam
# Total population  111267260.0
# Done
# (360, 720)
# Done
# Finished ok
# Vanuatu
# Total population  432590.53
# Done
# (360, 720)
# Done
# Western Samoa
# Total population  171023.61
# Done
# (360, 720)
# Done
# Yemen
# Total population  52425104.0
# Done
# (360, 720)
# Done
# Finished ok
# South Africa
# Total population  65846896.0
# Done
# (360, 720)
# Done
# Finished ok
# Zambia
# Total population  27811154.0
# Done
# (360, 720)
# Done
# Finished ok
# Zimbabwe
# Total population  13270910.0
# Done
# (360, 720)
# Done
# Finished ok

# %%
z=process_all("Spain",year=2030)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Total population  52585696.0
# Done
# (360, 720)
# Done

# %%
results
# Out:
#               COPD            IHD             LC           LRI         STROKE  \
# 0       752.727783    8130.972656     244.671631   4826.198242    2469.181885
# 1       288.497070     486.807678     128.181747   1135.517944     282.146820
# 2        74.248199     259.896851      66.941864     38.843758     193.491974
# 3       275.119598     520.069214     126.366440    254.438110     173.890640
# 4      1641.442261    2737.225586     576.492615   1996.761475     913.561584
# 5       606.294495    1760.857910     408.123779    173.776398     429.970367
# 6       599.337280     721.765625     267.062378    163.674332     240.999023
# 7       271.840363     507.039520     159.414322     49.042820     101.147240
# 8       424.597473    2373.454346     243.163071    211.178528     715.008911
# 9        51.349102     107.044769       7.236247    255.546448      69.805710
# 10      439.047485     455.706909     243.836487    207.545593     175.597687
# 11      455.529083     575.408813     145.783234   2822.300781     383.439819
# 12      537.623718    1375.587646     224.270950   6103.821777     551.543701
# 13    22966.492188   17325.044922    8180.357422  11468.674805   13177.423828
# 14      695.521545    2399.309570     368.101379    264.073547    1164.689941
# 15      279.587677     954.660156     234.874512     49.911316     431.343689
# 16       30.203705     266.908752      35.073936     10.617558      75.689148
# 17        0.121327       0.333166       0.041976      0.135864       0.170127
# 18      188.317856     468.235382      54.977211    302.192261     205.421738
# 19     8778.466797   11608.661133    1945.880859   7640.703613    6238.309082
# 20        1.848934       2.299178       1.030155      1.414054       0.958253
# 21      731.680664     695.384644      62.663422    199.027512     254.126526
# 22       77.409492     105.153656      19.835726    107.426514      68.457077
# 23      467.508698    1252.273560     149.529114   3766.429199     736.831421
# 24      643.674255     913.907349     447.909668    233.767960     251.098831
# 25       63.943146      97.663841      40.678799     27.725773      27.663807
# 26      245.911972     425.433044      90.931572    197.775009     238.474136
# 27   297357.406250  118345.718750  126760.140625  51082.019531  121177.945312
# 28      924.124878    2447.929688     234.724869   7716.347656    1257.089600
# 29     1296.999512    1346.368652     517.874023   6408.942871     975.906189
# ..             ...            ...            ...           ...            ...
# 131     151.714066     389.162537      44.527294    299.034851      89.325188
# 132     444.880371    2091.710938      76.859779   3635.648926    1339.223267
# 133     720.393555    2157.892334     594.871887    197.200165    1159.885742
# 134      49.120975     138.085419      17.467159    821.617554      88.252632
# 135      13.017495      41.968388       5.514163     11.709154      30.346684
# 136     224.227722    1214.800659     229.740433    278.524872     281.667755
# 137      83.407623     173.353485      58.901802     51.838593      71.155014
# 138      21.010628      53.289131      10.773966     11.736881      15.295507
# 139     702.199463    4616.179199     308.320374    568.763306     839.575012
# 140     597.602234    1124.921143     221.601059   9772.527344     695.106934
# 141     264.789093     436.927185      95.436874   1300.990967     233.895523
# 142    5560.486328    5386.906250    3965.842285  10123.833008    4073.823730
# 143     202.780411    1135.604736      54.545273    540.258911     412.312988
# 144     315.370148    2830.117188     184.729645    369.432617    1052.145996
# 145      33.630241      49.584595       8.237426     29.522934      40.513336
# 146       4.477174      24.386351       1.929155      6.093589      10.846968
# 147     154.951172     645.984192     106.773842    113.780617     162.230011
# 148    4095.169434    4834.570312    2290.055908   1360.141724    1308.159424
# 149     505.643829    1355.394775     126.996574   2439.682373     639.428345
# 150    1225.648071    1632.628052     409.785065   7093.802246    1035.463013
# 151     940.356812   10815.215820     657.648560    441.283905    3057.629639
# 152      61.163067      80.717201      25.284645     29.808666      44.316139
# 153    9758.019531   15086.049805    5433.827148   3985.484619    3411.629150
# 154     833.980347    9829.395508     463.932312   1458.375977    2872.586182
# 155    1129.155273    3187.639648     483.093414    693.905762     920.653137
# 156    6270.112305    7102.535156    7589.435547   3792.343262    9649.748047
# 157     784.305176    5056.984375     276.680664   1470.019043    1395.408691
# 158    2580.536621    2622.659180     794.269104   3811.169922    1572.146606
# 159     284.532745     686.502747      70.106979   1487.749390     382.102356
# 160     236.677917    1048.885498      59.687073   1211.318970     365.515015
#
#                                 country        pwc scenario    year
# 0                           Afghanistan  29.291361     SLCF  2030.0
# 1                                Angola  29.155862     SLCF  2030.0
# 2                               Albania  12.108003     SLCF  2030.0
# 3                  United Arab Emirates  75.576220     SLCF  2030.0
# 4                             Argentina   7.923834     SLCF  2030.0
# 5                               Armenia  20.423663     SLCF  2030.0
# 6                             Australia   6.172722     SLCF  2030.0
# 7                               Austria   6.207591     SLCF  2030.0
# 8                            Azerbaijan  17.842465     SLCF  2030.0
# 9                               Burundi  28.156517     SLCF  2030.0
# 10                              Belgium   4.610573     SLCF  2030.0
# 11                                Benin  78.255320     SLCF  2030.0
# 12                         Burkina Faso  55.125376     SLCF  2030.0
# 13                           Bangladesh  71.247485     SLCF  2030.0
# 14                             Bulgaria  10.694041     SLCF  2030.0
# 15               Bosnia and Herzegovina  10.096292     SLCF  2030.0
# 16                              Belarus   4.065569     SLCF  2030.0
# 17                               Belize   6.910953     SLCF  2030.0
# 18     Bolivia (Plurinational State of)   9.082552     SLCF  2030.0
# 19                               Brazil   8.862856     SLCF  2030.0
# 20                    Brunei Darussalam  13.276957     SLCF  2030.0
# 21                               Bhutan  17.321114     SLCF  2030.0
# 22                             Botswana  10.905626     SLCF  2030.0
# 23             Central African Republic  86.142480     SLCF  2030.0
# 24                               Canada   4.555666     SLCF  2030.0
# 25                          Switzerland   4.737833     SLCF  2030.0
# 26                                Chile   5.406809     SLCF  2030.0
# 27                                China  28.417157     SLCF  2030.0
# 28                        Côte d'Ivoire  64.472370     SLCF  2030.0
# 29                             Cameroon  71.578304     SLCF  2030.0
# ..                                  ...        ...      ...     ...
# 131                         El Salvador  13.793582     SLCF  2030.0
# 132                             Somalia  14.328248     SLCF  2030.0
# 133                              Serbia  13.150729     SLCF  2030.0
# 134                         South Sudan  84.475751     SLCF  2030.0
# 135                            Suriname   7.916458     SLCF  2030.0
# 136                            Slovakia  10.708979     SLCF  2030.0
# 137                            Slovenia   7.283494     SLCF  2030.0
# 138                              Sweden   2.925303     SLCF  2030.0
# 139                Syrian Arab Republic  21.044398     SLCF  2030.0
# 140                                Chad  65.124271     SLCF  2030.0
# 141                                Togo  89.576346     SLCF  2030.0
# 142                            Thailand  25.470821     SLCF  2030.0
# 143                          Tajikistan  21.993733     SLCF  2030.0
# 144                        Turkmenistan  25.171631     SLCF  2030.0
# 145                         Timor-Leste  11.150034     SLCF  2030.0
# 146                 Trinidad and Tobago   8.796788     SLCF  2030.0
# 147                             Tunisia  18.034037     SLCF  2030.0
# 148                              Turkey  13.072732     SLCF  2030.0
# 149         United Republic of Tanzania  11.545055     SLCF  2030.0
# 150                              Uganda  87.000175     SLCF  2030.0
# 151                             Ukraine   6.680077     SLCF  2030.0
# 152                             Uruguay   6.722109     SLCF  2030.0
# 153            United States of America   5.848860     SLCF  2030.0
# 154                          Uzbekistan  22.939243     SLCF  2030.0
# 155  Venezuela (Bolivarian Republic of)  10.772710     SLCF  2030.0
# 156                            Viet Nam  37.402323     SLCF  2030.0
# 157                               Yemen  33.612315     SLCF  2030.0
# 158                        South Africa  14.465726     SLCF  2030.0
# 159                              Zambia  18.062227     SLCF  2030.0
# 160                            Zimbabwe  11.413457     SLCF  2030.0
#
# [161 rows x 9 columns]

# %%
#results.to_csv("./2050_SLCF_impacts.csv",index=False)

# %%
results
# Out:
#               COPD            IHD             LC           LRI        STROKE  \
# 0       996.190674   14858.207031     382.085327   4683.534668   4387.050781
# 1       384.101868     554.770203     203.137970   1400.575195    324.002625
# 2        88.761642     338.955109      69.424950     48.262619    262.884033
# 3       475.682861     820.172180     233.752487    544.375732    310.498199
# 4      1705.330688    3063.434082     603.826965   2287.462158    969.622192
# 5       822.843628    2315.025879     449.544525    226.583206    500.734375
# 6       568.515381     716.132080     232.711868    181.871872    237.095703
# 7       235.641541     462.466553     134.556137     49.780411     91.179047
# 8       537.289673    2791.136475     249.394897    233.621292    797.782471
# 9        73.961044     207.565521      10.536538    332.430573    131.497345
# 10      209.046249     119.464546     138.992432    139.465836     76.180008
# 11      629.823181     745.361572     233.648315   3658.162598    467.878052
# 12      787.251099    2080.641113     416.232239   7444.618652    776.247986
# 13    29552.667969   20524.400391   10851.125977  13948.384766  17381.171875
# 14      615.883606    1608.223145     287.965424    239.324066    742.756958
# 15      270.401611    1049.398315     205.050735     48.412643    378.882660
# 16        4.136465      16.168978       3.703436      1.238965      4.708604
# 17        0.115837       0.379640       0.040222      0.146913      0.196049
# 18      204.100891     493.273254      63.564957    347.981171    210.634415
# 19     9939.850586   13610.701172    1998.669189   9387.040039   7177.418945
# 20        2.423310       2.812987       1.115358      2.038962      1.290998
# 21      992.190247     973.494324      90.472450    259.199188    370.627319
# 22       84.283279     124.944107      21.965858    105.670471     82.678467
# 23      568.170837    1769.583618     214.083023   4353.668457   1015.657532
# 24      657.365051     918.544556     406.256104    291.489563    247.996445
# 25       33.618439      61.205292      31.432955     26.676186     16.408123
# 26      260.955048     539.389587      84.823494    243.345566    270.427551
# 27   325258.281250  102915.351562  114842.523438  55531.468750  96459.664062
# 28     1001.423767    2584.691895     289.602478   8025.258789   1276.824585
# 29     1773.306274    1701.467285     889.736267   8108.035156   1196.515381
# ..             ...            ...            ...           ...           ...
# 131     162.255325     449.078430      51.130283    353.117493    102.747452
# 132     467.884216    2637.331055      89.708054   2972.272705   1646.741577
# 133     669.436279    2043.415527     510.052582    174.057678    939.631714
# 134      56.815990     190.163467      24.846184    816.221069    119.987259
# 135      17.126657      51.532417       7.103967     16.541048     37.884182
# 136     233.532425    1297.243896     202.552032    320.383972    260.224274
# 137      84.328423     167.412155      47.955559     56.423386     64.245026
# 138      10.254332      20.980598       5.981290      8.883944      5.511777
# 139     973.517700    7341.644531     407.906250    751.858276   1370.462402
# 140     801.486877    1740.049561     356.327454   9431.728516   1010.928101
# 141     324.348114     508.847260     134.421875   1634.118164    262.918701
# 142    6187.462402    6613.042480    4042.913574  12008.981445   4587.185059
# 143     235.566910    1273.190674      55.021049    498.282013    471.411377
# 144     446.542542    3413.130371     226.634079    336.739227   1048.408936
# 145      40.664406      78.368507      11.582441     31.302738     61.956947
# 146       5.160087      25.540745       2.020364      8.387952     11.932922
# 147     180.427032     827.401672     113.993553    151.212082    199.975769
# 148    4179.778320    4919.587891    2155.416992   1397.985840   1233.128662
# 149     603.589966    1645.965576     178.676483   2616.465820    764.985718
# 150    2205.526367    3264.887939     920.242798  11355.665039   2066.429199
# 151     522.077026    4846.554199     339.345642    252.688660   1325.252319
# 152      56.563492      76.983536      23.862335     30.333225     40.588478
# 153    7398.625488   14138.178711    4247.226074   4572.068359   2882.662842
# 154    1114.818604   12690.813477     587.967957   1448.091553   3535.809814
# 155    1430.144531    4211.404785     583.363647    980.016418   1161.399902
# 156    7770.698730    8269.404297    9488.367188   4780.680664  11188.867188
# 157    1134.797363    9067.892578     459.917419   1951.675659   2419.774170
# 158    2262.460938    2663.636230     604.293091   2919.005859   1658.088135
# 159     401.046021    1038.427490     112.790047   1873.354736    602.156433
# 160     245.741013    1411.349731      69.786064   1309.542725    479.283691
#
#                                 country        pwc scenario    year
# 0                           Afghanistan  27.801523      MFR  2050.0
# 1                                Angola  28.918470      MFR  2050.0
# 2                               Albania  10.172077      MFR  2050.0
# 3                  United Arab Emirates  71.749044      MFR  2050.0
# 4                             Argentina   7.583780      MFR  2050.0
# 5                               Armenia  18.370463      MFR  2050.0
# 6                             Australia   5.365144      MFR  2050.0
# 7                               Austria   5.437768      MFR  2050.0
# 8                            Azerbaijan  16.410812      MFR  2050.0
# 9                               Burundi  27.613023      MFR  2050.0
# 10                              Belgium   4.032994      MFR  2050.0
# 11                                Benin  76.087344      MFR  2050.0
# 12                         Burkina Faso  54.250810      MFR  2050.0
# 13                           Bangladesh  67.377042      MFR  2050.0
# 14                             Bulgaria   9.314284      MFR  2050.0
# 15               Bosnia and Herzegovina   8.839409      MFR  2050.0
# 16                              Belarus   2.981845      MFR  2050.0
# 17                               Belize   6.691733      MFR  2050.0
# 18     Bolivia (Plurinational State of)   8.732305      MFR  2050.0
# 19                               Brazil   8.369810      MFR  2050.0
# 20                    Brunei Darussalam  12.381719      MFR  2050.0
# 21                               Bhutan  14.579548      MFR  2050.0
# 22                             Botswana   7.988490      MFR  2050.0
# 23             Central African Republic  85.295433      MFR  2050.0
# 24                               Canada   4.214154      MFR  2050.0
# 25                          Switzerland   4.432002      MFR  2050.0
# 26                                Chile   5.004628      MFR  2050.0
# 27                                China  24.227891      MFR  2050.0
# 28                        Côte d'Ivoire  63.326884      MFR  2050.0
# 29                             Cameroon  70.326313      MFR  2050.0
# ..                                  ...        ...      ...     ...
# 131                         El Salvador  13.124819      MFR  2050.0
# 132                             Somalia  13.438372      MFR  2050.0
# 133                              Serbia  11.205966      MFR  2050.0
# 134                         South Sudan  86.303620      MFR  2050.0
# 135                            Suriname   7.807829      MFR  2050.0
# 136                            Slovakia   9.226507      MFR  2050.0
# 137                            Slovenia   6.298332      MFR  2050.0
# 138                              Sweden   2.536515      MFR  2050.0
# 139                Syrian Arab Republic  18.137535      MFR  2050.0
# 140                                Chad  63.756115      MFR  2050.0
# 141                                Togo  85.986195      MFR  2050.0
# 142                            Thailand  22.643467      MFR  2050.0
# 143                          Tajikistan  20.291982      MFR  2050.0
# 144                        Turkmenistan  23.435086      MFR  2050.0
# 145                         Timor-Leste  11.147291      MFR  2050.0
# 146                 Trinidad and Tobago   8.680618      MFR  2050.0
# 147                             Tunisia  17.157309      MFR  2050.0
# 148                              Turkey  11.101111      MFR  2050.0
# 149         United Republic of Tanzania  11.030428      MFR  2050.0
# 150                              Uganda  84.652112      MFR  2050.0
# 151                             Ukraine   5.046936      MFR  2050.0
# 152                             Uruguay   6.399191      MFR  2050.0
# 153            United States of America   5.352403      MFR  2050.0
# 154                          Uzbekistan  21.045085      MFR  2050.0
# 155  Venezuela (Bolivarian Republic of)  10.307512      MFR  2050.0
# 156                            Viet Nam  35.393788      MFR  2050.0
# 157                               Yemen  30.759196      MFR  2050.0
# 158                        South Africa   9.446386      MFR  2050.0
# 159                              Zambia  17.056279      MFR  2050.0
# 160                            Zimbabwe  10.484302      MFR  2050.0
#
# [161 rows x 9 columns]

# %%
# reference=pd.read_excel("./data/borders/gpw-v4-documentation-rev11/gpw-v4-country-level-summary-rev11.xlsx",
#                        sheet_name="GPWv4 Rev11 Summary",skiprows=1)
# countries_masks=reference["Country or Territory Name"].unique()

# countries_inc=gbd=pd.read_csv("./data/GBD/IHME-GBD_2017_DATA-23a76344-1.csv").location_name.unique()

# missing=[x for x in countries_masks if (x not in countries_inc)&(x not in gbd_translate.keys())]
# missing=missing+["Andorra","American Samoa","Bermuda","Dominica","Greenland",
#                 'Marshall Islands', 'Northern Mariana Islands', 'Swaziland']

# countries_un=pd.read_excel("./data/WPP2019_POP_F07_1_POPULATION_BY_AGE_BOTH_SEXES.xlsx",sheet_name="ESTIMATES",
#                          skiprows=16)
# countries_un=np.unique(countries_un.iloc[:,2])
# countries=[x for x in countries_masks if (x not in countries_un)&(x not in un_translate.keys())&(x not in missing)]
# with open("./data/non_included_countries.txt", "w") as file:
#     file.write(str(missing))

# %%
countries
# Out:
# ['Afghanistan',
#  'Angola',
#  'Albania',
#  'United Arab Emirates',
#  'Argentina',
#  'Armenia',
#  'Antigua and Barbuda',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Burundi',
#  'Belgium',
#  'Benin',
#  'Burkina Faso',
#  'Bangladesh',
#  'Bulgaria',
#  'Bahrain',
#  'Bahamas',
#  'Bosnia and Herzegovina',
#  'Belarus',
#  'Belize',
#  'Bolivia (Plurinational State of)',
#  'Brazil',
#  'Barbados',
#  'Brunei Darussalam',
#  'Bhutan',
#  'Botswana',
#  'Central African Republic',
#  'Canada',
#  'Switzerland',
#  'Chile',
#  'China',
#  "Côte d'Ivoire",
#  'Cameroon',
#  'Democratic Republic of the Congo',
#  'Congo',
#  'Colombia',
#  'Comoros',
#  'Cape Verde',
#  'Costa Rica',
#  'Cuba',
#  'Cyprus',
#  'Czech Republic',
#  'Germany',
#  'Djibouti',
#  'Denmark',
#  'Dominican Republic',
#  'Algeria',
#  'Ecuador',
#  'Egypt',
#  'Eritrea',
#  'Spain',
#  'Estonia',
#  'Ethiopia',
#  'Finland',
#  'Fiji',
#  'France',
#  'Micronesia (Federated States of)',
#  'Gabon',
#  'United Kingdom of Great Britain and Northern Ireland',
#  'Georgia',
#  'Ghana',
#  'Guinea',
#  'Gambia',
#  'Guinea-Bissau',
#  'Equatorial Guinea',
#  'Greece',
#  'Grenada',
#  'Guatemala',
#  'Guam',
#  'Guyana',
#  'Honduras',
#  'Croatia',
#  'Haiti',
#  'Hungary',
#  'Indonesia',
#  'India',
#  'Ireland',
#  'Iran (Islamic Republic of)',
#  'Iraq',
#  'Iceland',
#  'Israel',
#  'Italy',
#  'Jamaica',
#  'Jordan',
#  'Japan',
#  'Kazakhstan',
#  'Kenya',
#  'Kyrgyzstan',
#  'Cambodia',
#  'Kiribati',
#  'Republic of Korea',
#  'Kuwait',
#  "Lao People's Democratic Republic",
#  'Lebanon',
#  'Liberia',
#  'Libya',
#  'Saint Lucia',
#  'Sri Lanka',
#  'Lesotho',
#  'Lithuania',
#  'Luxembourg',
#  'Latvia',
#  'Morocco',
#  'Republic of Moldova',
#  'Madagascar',
#  'Maldives',
#  'Mexico',
#  'The former Yugoslav Republic of Macedonia',
#  'Mali',
#  'Malta',
#  'Myanmar',
#  'Montenegro',
#  'Mongolia',
#  'Mozambique',
#  'Mauritania',
#  'Mauritius',
#  'Malawi',
#  'Malaysia',
#  'Namibia',
#  'Niger',
#  'Nigeria',
#  'Nicaragua',
#  'Netherlands',
#  'Norway',
#  'Nepal',
#  'New Zealand',
#  'Oman',
#  'Pakistan',
#  'Panama',
#  'Peru',
#  'Philippines',
#  'Papua New Guinea',
#  'Poland',
#  'Puerto Rico',
#  "Democratic People's Republic of Korea",
#  'Portugal',
#  'Paraguay',
#  'State of Palestine',
#  'Qatar',
#  'Romania',
#  'Russian Federation',
#  'Rwanda',
#  'Saudi Arabia',
#  'Sudan',
#  'Senegal',
#  'Singapore',
#  'Solomon Islands',
#  'Sierra Leone',
#  'El Salvador',
#  'Somalia',
#  'Serbia',
#  'South Sudan',
#  'Sao Tome and Principe',
#  'Suriname',
#  'Slovakia',
#  'Slovenia',
#  'Sweden',
#  'Seychelles',
#  'Syrian Arab Republic',
#  'Chad',
#  'Togo',
#  'Thailand',
#  'Tajikistan',
#  'Turkmenistan',
#  'Timor-Leste',
#  'Tonga',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkey',
#  'Taiwan',
#  'United Republic of Tanzania',
#  'Uganda',
#  'Ukraine',
#  'Uruguay',
#  'United States of America',
#  'Uzbekistan',
#  'Saint Vincent and the Grenadines',
#  'Venezuela (Bolivarian Republic of)',
#  'United States Virgin Islands',
#  'Viet Nam',
#  'Vanuatu',
#  'Western Samoa',
#  'Yemen',
#  'South Africa',
#  'Zambia',
#  'Zimbabwe']

# %%
scenarios=["","CLE","MFR","CLE","MFR"]
years=[2015,2030,2030,2050,2050]
#scenarios=[""]
#years=[2010]


def get_nox_array(year=2015,scenario="CLE"):
    noxfolder="/media/gaia/Seagate Expansion Drive/Liliana/fon/Downscaling/averaged_susan"

    if year!=2015:
        filename=[x for x in os.listdir(noxfolder) if (str(year) in x)&(scenario in x)][0]
    else:
        filename=[x for x in os.listdir(noxfolder) if (str(year) in x)][0]
    conc_array=gdal.Open(os.path.join(noxfolder,filename)).ReadAsArray()

    return conc_array

results=pd.DataFrame()
for i in range(len(years)):
    year=years[i]
    print(year)
    scenario=scenarios[i]
    print(scenario)
    conc_array=get_nox_array(year=year,scenario=scenario)
    for country in countries:


        try:
            print("Country.... ",country)
            population=get_population(country,year=year)
            print("Population -> ",np.sum(population))
            mask=np.where(conc_array>=0)
            pwc=np.sum(population[mask]*conc_array[mask])/np.sum(population[mask])
            
            
            
            
            print("pwc = ",pwc)
           
            results=results.append({"country":country,"year":year,"scenario":scenario,"pwc":pwc},ignore_index=True)
        except:
            results=results.append({"country":country,"year":"","scenario":"","pwc":""},ignore_index=True)
# Out:
# 2015
#
# Country....  Afghanistan
# Population ->  32535250
# pwc =  10.348867546375322
# Country....  Angola
# Population ->  24998348
# pwc =  11.671505600287425
# Country....  Albania
# Population ->  2897151
# pwc =  7.659855775913949
# Country....  United Arab Emirates
# Population ->  9096391
# pwc =  22.616743026336323
# Country....  Argentina
# Population ->  43444096
# pwc =  11.475979733972897
# Country....  Armenia
# Population ->  3017776
# pwc =  12.220022586723227
# Country....  Antigua and Barbuda
# Population ->  91820
# pwc =  7.8094423120814405
# Country....  Australia
# Population ->  23946420
# pwc =  6.534136426947167
# Country....  Austria
# Population ->  8525752
# pwc =  8.235976924951744
# Country....  Azerbaijan
# Population ->  9738267
# pwc =  11.386293337661195
# Country....  Burundi
# Population ->  11177870
# pwc =  7.733533992080636
# Country....  Belgium
# Population ->  11294176
# pwc =  14.884116630085577
# Country....  Benin
# Population ->  10866640
# pwc =  11.221350482858448
# Country....  Burkina Faso
# Population ->  18068091
# pwc =  13.869371466123987
# Country....  Bangladesh
# Population ->  161003254
# pwc =  13.372219170218813
# Country....  Bulgaria
# Population ->  7133942
# pwc =  6.71344713418076
# Country....  Bahrain
# Population ->  1370366
# pwc =  16.9537188607556
# Country....  Bahamas
# Population ->  388003
# pwc =  10.806148765750665
# Country....  Bosnia and Herzegovina
# Population ->  3811004
# pwc =  5.771422574326683
# Country....  Belarus
# Population ->  9493644
# pwc =  8.292649096068383
# Country....  Belize
# Population ->  360744
# pwc =  9.535396097581325
# Country....  Bolivia (Plurinational State of)
# Population ->  10701428
# pwc =  7.723366450113011
# Country....  Brazil
# Population ->  207626897
# pwc =  12.91605728335744
# Country....  Barbados
# Population ->  284217
# pwc =  10.538082882123286
# Country....  Brunei Darussalam
# Population ->  423063
# pwc =  8.390138661128132
# Country....  Bhutan
# Population ->  776535
# pwc =  3.9535596871890286
# Country....  Botswana
# Population ->  2264488
# pwc =  5.1475617837357035
# Country....  Central African Republic
# Population ->  4926954
# pwc =  9.650605051755697
# Country....  Canada
# Population ->  35861596
# pwc =  9.983223495952778
# Country....  Switzerland
# Population ->  8359336
# pwc =  8.70776661936913
# Country....  Chile
# Population ->  17941023
# pwc =  29.08291043292419
# Country....  China
# Population ->  1375612385
# pwc =  24.149594793813197
# Country....  Côte d'Ivoire
# Population ->  22694993
# pwc =  12.663043611558724
# Country....  Cameroon
# Population ->  23353723
# pwc =  15.525020038536397
# Country....  Democratic Republic of the Congo
# Population ->  77174336
# pwc =  8.960032541990378
# Country....  Congo
# Population ->  4632691
# pwc =  12.08906700899639
# Country....  Colombia
# Population ->  48165706
# pwc =  16.10454897614678
# Country....  Comoros
# Population ->  788400
# pwc =  2.779869832875819
# Country....  Cape Verde
# Population ->  520487
# pwc =  3.7122620391007914
# Country....  Costa Rica
# Population ->  4808009
# pwc =  10.912316950202825
# Country....  Cuba
# Population ->  11389454
# pwc =  11.741418646226892
# Country....  Cyprus
# Population ->  1165222
# pwc =  12.409926020739265
# Country....  Czech Republic
# Population ->  10534188
# pwc =  7.695297247747922
# Country....  Germany
# Population ->  80590138
# pwc =  10.051653886301958
# Country....  Djibouti
# Population ->  887863
# pwc =  7.987446209178053
# Country....  Denmark
# Population ->  5667440
# pwc =  5.093274215686285
# Country....  Dominican Republic
# Population ->  10524855
# pwc =  18.930138045299383
# Country....  Algeria
# Population ->  39660404
# pwc =  9.02491443498069
# Country....  Ecuador
# Population ->  16141381
# pwc =  13.246088955110018
# Country....  Egypt
# Population ->  91486046
# pwc =  39.79277136522545
# Country....  Eritrea
# Population ->  5217942
# pwc =  9.27697265760385
# Country....  Spain
# Population ->  46097737
# pwc =  8.542347797455795
# Country....  Estonia
# Population ->  1308782
# pwc =  4.929693940963729
# Country....  Ethiopia
# Population ->  99323818
# pwc =  7.527269838364134
# Country....  Finland
# Population ->  5470259
# pwc =  4.337552107383355
# Country....  Fiji
# Population ->  891663
# pwc =  0.0
# Country....  France
# Population ->  64352689
# pwc =  8.97627040678492
# Country....  Micronesia (Federated States of)
# Population ->  104370
# pwc =  0.019014292757094133
# Country....  Gabon
# Population ->  1734537
# pwc =  10.277276713461639
# Country....  United Kingdom of Great Britain and Northern Ireland
# Population ->  64692460
# pwc =  10.070273046987383
# Country....  Georgia
# Population ->  4000217
# pwc =  9.161190699915243
# Country....  Ghana
# Population ->  27400345
# pwc =  12.626028531659282
# Country....  Guinea
# Population ->  12588011
# pwc =  9.797344845111452
# Country....  Gambia
# Population ->  1993471
# pwc =  13.408761999057706
# Country....  Guinea-Bissau
# Population ->  1840852
# pwc =  8.337396944724775
# Country....  Equatorial Guinea
# Population ->  847710
# pwc =  9.446969367581845
# Country....  Greece
# Population ->  10953989
# pwc =  10.744357048453937
# Country....  Grenada
# Population ->  106823
# pwc =  4.6793750063357615
# Country....  Guatemala
# Population ->  16314891
# pwc =  13.847360410142763
# Country....  Guam
# Population ->  169875
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in double_scalars
# pwc =  nan
# Country....  Guyana
# Population ->  758357
# pwc =  7.740708122492792
# Country....  Honduras
# Population ->  8067398
# pwc =  8.77664729078847
# Country....  Croatia
# Population ->  4240009
# pwc =  6.8247949604262335
# Country....  Haiti
# Population ->  10713963
# pwc =  14.086227938353
# Country....  Hungary
# Population ->  9839742
# pwc =  7.130317426994326
# Country....  Indonesia
# Population ->  257410910
# pwc =  26.210473336076138
# Country....  India
# Population ->  1310522649
# pwc =  17.662351161842512
# Country....  Ireland
# Population ->  4688028
# pwc =  3.9060018504768834
# Country....  Iran (Islamic Republic of)
# Population ->  79106590
# pwc =  26.84953167735745
# Country....  Iraq
# Population ->  36414892
# pwc =  23.04275172490251
# Country....  Iceland
# Population ->  322844
# pwc =  0.8661505339816578
# Country....  Israel
# Population ->  8047393
# pwc =  16.836097025372922
# Country....  Italy
# Population ->  59784563
# pwc =  10.773271701772375
# Country....  Jamaica
# Population ->  2793077
# pwc =  11.171428599706408
# Country....  Jordan
# Population ->  7589382
# pwc =  19.332161635391582
# Country....  Japan
# Population ->  126381096
# pwc =  11.77936122821858
# Country....  Kazakhstan
# Population ->  17600962
# pwc =  7.906146830726289
# Country....  Kenya
# Population ->  46002455
# pwc =  5.715695631024425
# Country....  Kyrgyzstan
# Population ->  5932835
# pwc =  8.121519478674891
# Country....  Cambodia
# Population ->  15528104
# pwc =  15.61555482335695
# Country....  Kiribati
# Population ->  112314
# pwc =  nan
# Country....  Republic of Korea
# Population ->  50237966
# pwc =  32.833913438052434
# Country....  Kuwait
# Population ->  3892735
# pwc =  21.83665185665904
# Country....  Lao People's Democratic Republic
# Population ->  6828276
# pwc =  10.345163566116472
# Country....  Lebanon
# Population ->  5850023
# pwc =  26.930314088205254
# Country....  Liberia
# Population ->  4503925
# pwc =  7.074457679832015
# Country....  Libya
# Population ->  6278713
# pwc =  11.50441756092993
# Country....  Saint Lucia
# Population ->  184989
# pwc =  4.9930427318565584
# Country....  Sri Lanka
# Population ->  20707422
# pwc =  12.533200633098842
# Country....  Lesotho
# Population ->  2126447
# pwc =  3.4956167096264856
# Country....  Lithuania
# Population ->  2878732
# pwc =  4.834679394344914
# Country....  Luxembourg
# Population ->  565621
# pwc =  12.397779003843764
# Country....  Latvia
# Population ->  1970648
# pwc =  4.003952973493428
# Country....  Morocco
# Population ->  34362025
# pwc =  10.999555974780746
# Country....  Republic of Moldova
# Population ->  4065446
# pwc =  4.341108921758996
# Country....  Madagascar
# Population ->  24210096
# pwc =  2.898737737963795
# Country....  Maldives
# Population ->  363544
# pwc =  19.176032933870268
# Country....  Mexico
# Population ->  126932104
# pwc =  16.489409820069145
# Country....  The former Yugoslav Republic of Macedonia
# Population ->  2078392
# pwc =  7.997423805244231
# Country....  Mali
# Population ->  17564595
# pwc =  12.452509780799428
# Country....  Malta
# Population ->  418661
# pwc =  9.619751106707994
# Country....  Myanmar
# Population ->  53875985
# pwc =  11.495869956757346
# Country....  Montenegro
# Population ->  624444
# pwc =  4.791865471049203
# Country....  Mongolia
# Population ->  2782185
# pwc =  6.768391836467815
# Country....  Mozambique
# Population ->  27892582
# pwc =  5.278514326846396
# Country....  Mauritania
# Population ->  4040522
# pwc =  5.057412044429773
# Country....  Mauritius
# Population ->  1273164
# pwc =  3.669000817681847
# Country....  Malawi
# Population ->  17283718
# pwc =  4.148386472734571
# Country....  Malaysia
# Population ->  30316258
# pwc =  31.30879555778306
# Country....  Namibia
# Population ->  2412609
# pwc =  3.008934547905805
# Country....  Niger
# Population ->  19913235
# pwc =  8.339154471915354
# Country....  Nigeria
# Population ->  182146716
# pwc =  12.942083207736724
# Country....  Nicaragua
# Population ->  6070050
# pwc =  6.144261937606019
# Country....  Netherlands
# Population ->  16917702
# pwc =  13.554334627655063
# Country....  Norway
# Population ->  5198285
# pwc =  3.1358366880545194
# Country....  Nepal
# Population ->  28480718
# pwc =  7.929472425622901
# Country....  New Zealand
# Population ->  4519521
# pwc =  2.6206110970212553
# Country....  Oman
# Population ->  4490007
# pwc =  10.517150912570866
# Country....  Pakistan
# Population ->  188790170
# pwc =  20.01059900809629
# Country....  Panama
# Population ->  3926466
# pwc =  8.719841301744438
# Country....  Peru
# Population ->  31342771
# pwc =  6.979048634786147
# Country....  Philippines
# Population ->  100450908
# pwc =  11.566520905531279
# Country....  Papua New Guinea
# Population ->  7623336
# pwc =  2.042526739239068
# Country....  Poland
# Population ->  38588375
# pwc =  7.591759028682798
# Country....  Puerto Rico
# Population ->  3683089
# pwc =  12.445626512933373
# Country....  Democratic People's Republic of Korea
# Population ->  25074443
# pwc =  11.10694399464369
# Country....  Portugal
# Population ->  10348955
# pwc =  6.6344649354630585
# Country....  Paraguay
# Population ->  6594079
# pwc =  12.34957279075813
# Country....  State of Palestine
# Population ->  4665463
# pwc =  13.763957978576784
# Country....  Qatar
# Population ->  2218596
# pwc =  18.6763871431117
# Country....  Romania
# Population ->  19458086
# pwc =  6.269444133324724
# Country....  Russian Federation
# Population ->  143310698
# pwc =  8.202041951266787
# Country....  Rwanda
# Population ->  11663895
# pwc =  7.182963339633015
# Country....  Saudi Arabia
# Population ->  31538631
# pwc =  22.092081435120797
# Country....  Sudan
# Population ->  40178808
# pwc =  12.586778297586912
# Country....  Senegal
# Population ->  15128691
# pwc =  11.297541004142474
# Country....  Singapore
# Population ->  5603781
# pwc =  74.30581841129347
# Country....  Solomon Islands
# Population ->  581029
# pwc =  0.4821020398437889
# Country....  Sierra Leone
# Population ->  6446918
# pwc =  9.614140876103686
# Country....  El Salvador
# Population ->  6125622
# pwc =  13.355998695007443
# Country....  Somalia
# Population ->  10786598
# pwc =  4.463032541813978
# Country....  Serbia
# Population ->  6954247
# pwc =  7.036597235681567
# Country....  South Sudan
# Population ->  12218878
# pwc =  14.154288857306529
# Country....  Sao Tome and Principe
# Population ->  189984
# pwc =  7.04794586078877
# Country....  Suriname
# Population ->  545249
# pwc =  7.179087884187279
# Country....  Slovakia
# Population ->  5423124
# pwc =  6.528964527485428
# Country....  Slovenia
# Population ->  2067109
# pwc =  7.206861119694157
# Country....  Sweden
# Population ->  9766759
# pwc =  4.255553326196905
# Country....  Seychelles
# Population ->  96443
# pwc =  nan
# Country....  Syrian Arab Republic
# Population ->  18499053
# pwc =  13.84774361844135
# Country....  Chad
# Population ->  14067467
# pwc =  12.437892056227927
# Country....  Togo
# Population ->  7311252
# pwc =  11.03902696229072
# Country....  Thailand
# Population ->  67926704
# pwc =  22.21160324803341
# Country....  Tajikistan
# Population ->  8479644
# pwc =  9.304665875512052
# Country....  Turkmenistan
# Population ->  5371979
# pwc =  9.122679978965037
# Country....  Timor-Leste
# Population ->  1183682
# pwc =  10.428948656643996
# Country....  Tonga
# Population ->  106166
# pwc =  nan
# Country....  Trinidad and Tobago
# Population ->  1358270
# pwc =  8.810386786741937
# Country....  Tunisia
# Population ->  11241714
# pwc =  11.117194455776819
# Country....  Turkey
# Population ->  78657124
# pwc =  12.238560379456642
# Country....  Taiwan
# Population ->  23380037
# pwc =  30.266578167788012
# Country....  United Republic of Tanzania
# Population ->  53437505
# pwc =  5.151668606235211
# Country....  Uganda
# Population ->  39076872
# pwc =  7.315633180151849
# Country....  Ukraine
# Population ->  44688805
# pwc =  5.7681952051243615
# Country....  Uruguay
# Population ->  3421839
# pwc =  7.3663066183206265
# Country....  United States of America
# Population ->  321342898
# pwc =  12.813368035634891
# Country....  Uzbekistan
# Population ->  29908082
# pwc =  11.11495220636676
# Country....  Saint Vincent and the Grenadines
# Population ->  109464
# pwc =  3.8358684324274823
# Country....  Venezuela (Bolivarian Republic of)
# Population ->  31064201
# pwc =  20.28160442542471
# Country....  United States Virgin Islands
# Population ->  106292
# pwc =  7.479520602054044
# Country....  Viet Nam
# Population ->  93380080
# pwc =  21.202822670971145
# Country....  Vanuatu
# Population ->  264317
# pwc =  0.15942098271655003
# Country....  Western Samoa
# Population ->  193186
# pwc =  nan
# Country....  Yemen
# Population ->  26817827
# pwc =  7.331592979236715
# Country....  South Africa
# Population ->  54523098
# pwc =  7.634552258155022
# Country....  Zambia
# Population ->  16173199
# pwc =  7.307113722827265
# Country....  Zimbabwe
# Population ->  15581694
# pwc =  4.760479821491969
# 2030
# CLE
# Country....  Afghanistan
# Population ->  51569350.0
# pwc =  7.065734
# Country....  Angola
# Population ->  31810306.0
# pwc =  2.5769181
# Country....  Albania
# Population ->  3275444.0
# pwc =  2.7175467
# Country....  United Arab Emirates
# Population ->  13130389.0
# pwc =  10.321249
# Country....  Argentina
# Population ->  46156050.0
# pwc =  9.990329
# Country....  Armenia
# Population ->  2971908.0
# pwc =  12.080954
# Country....  Antigua and Barbuda
# Population ->  104914.68
# pwc =  4.033886
# Country....  Australia
# Population ->  29546142.0
# pwc =  5.626465
# Country....  Austria
# Population ->  8906304.0
# pwc =  3.6375153
# Country....  Azerbaijan
# Population ->  10601552.0
# pwc =  14.143784
# Country....  Burundi
# Population ->  13138348.0
# pwc =  5.0247974
# Country....  Belgium
# Population ->  11877237.0
# pwc =  7.8952923
# Country....  Benin
# Population ->  14119145.0
# pwc =  7.6217136
# Country....  Burkina Faso
# Population ->  27219980.0
# pwc =  6.3177686
# Country....  Bangladesh
# Population ->  181337010.0
# pwc =  12.383533
# Country....  Bulgaria
# Population ->  6820245.0
# pwc =  3.5507617
# Country....  Bahrain
# Population ->  2317281.8
# pwc =  15.434508
# Country....  Bahamas
# Population ->  421744.8
# pwc =  6.682148
# Country....  Bosnia and Herzegovina
# Population ->  3628331.8
# pwc =  2.0129642
# Country....  Belarus
# Population ->  8850704.0
# pwc =  5.094321
# Country....  Belize
# Population ->  389663.4
# pwc =  1.5089959
# Country....  Bolivia (Plurinational State of)
# Population ->  12577440.0
# pwc =  2.602055
# Country....  Brazil
# Population ->  220909840.0
# pwc =  8.828754
# Country....  Barbados
# Population ->  278090.28
# pwc =  7.629216
# Country....  Brunei Darussalam
# Population ->  525387.1
# pwc =  6.543571
# Country....  Bhutan
# Population ->  1122573.4
# pwc =  2.3961847
# Country....  Botswana
# Population ->  2392943.2
# pwc =  1.8716931
# Country....  Central African Republic
# Population ->  6087641.0
# pwc =  3.0217667
# Country....  Canada
# Population ->  41252284.0
# pwc =  6.522685
# Country....  Switzerland
# Population ->  8473224.0
# pwc =  5.4041357
# Country....  Chile
# Population ->  19636982.0
# pwc =  22.408543
# Country....  China
# Population ->  1380762000.0
# pwc =  12.723929
# Country....  Côte d'Ivoire
# Population ->  26194698.0
# pwc =  6.649937
# Country....  Cameroon
# Population ->  27296116.0
# pwc =  5.4876986
# Country....  Democratic Republic of the Congo
# Population ->  107298650.0
# pwc =  3.9220457
# Country....  Congo
# Population ->  6317289.0
# pwc =  4.133136
# Country....  Colombia
# Population ->  57311930.0
# pwc =  7.888428
# Country....  Comoros
# Population ->  1018113.06
# pwc =  0.49559146
# Country....  Cape Verde
# Population ->  545873.75
# pwc =  2.761363
# Country....  Costa Rica
# Population ->  5916929.0
# pwc =  8.219299
# Country....  Cuba
# Population ->  10656096.0
# pwc =  5.836708
# Country....  Cyprus
# Population ->  1363787.4
# pwc =  10.925197
# Country....  Czech Republic
# Population ->  11271592.0
# pwc =  4.226728
# Country....  Germany
# Population ->  81352080.0
# pwc =  4.7363644
# Country....  Djibouti
# Population ->  1167196.8
# pwc =  3.8252804
# Country....  Denmark
# Population ->  6078603.0
# pwc =  2.5437028
# Country....  Dominican Republic
# Population ->  11993334.0
# pwc =  8.567684
# Country....  Algeria
# Population ->  44396916.0
# pwc =  6.7007556
# Country....  Ecuador
# Population ->  17978846.0
# pwc =  5.8446627
# Country....  Egypt
# Population ->  106585930.0
# pwc =  29.277594
# Country....  Eritrea
# Population ->  8419884.0
# pwc =  1.8331506
# Country....  Spain
# Population ->  50226230.0
# pwc =  4.5695243
# Country....  Estonia
# Population ->  1295291.1
# pwc =  2.9521608
# Country....  Ethiopia
# Population ->  124165280.0
# pwc =  3.472109
# Country....  Finland
# Population ->  5818852.0
# pwc =  2.1426885
# Country....  Fiji
# Population ->  959424.9
# pwc =  0.0
# Country....  France
# Population ->  70312770.0
# pwc =  5.3329167
# Country....  Micronesia (Federated States of)
# Population ->  111568.516
# pwc =  0.020070564
# Country....  Gabon
# Population ->  1982088.0
# pwc =  8.607979
# Country....  United Kingdom of Great Britain and Northern Ireland
# Population ->  69232220.0
# pwc =  3.9656227
# Country....  Georgia
# Population ->  3871044.0
# pwc =  8.935435
# Country....  Ghana
# Population ->  36048332.0
# pwc =  7.5854306
# Country....  Guinea
# Population ->  13446847.0
# pwc =  3.3940516
# Country....  Gambia
# Population ->  2555412.8
# pwc =  10.177898
# Country....  Guinea-Bissau
# Population ->  2121141.5
# pwc =  4.3834105
# Country....  Equatorial Guinea
# Population ->  1105595.1
# pwc =  2.732077
# Country....  Greece
# Population ->  11379352.0
# pwc =  7.6221423
# Country....  Grenada
# Population ->  121295.2
# pwc =  1.6321567
# Country....  Guatemala
# Population ->  20315920.0
# pwc =  8.555266
# Country....  Guam
# Population ->  219413.16
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in float_scalars
# pwc =  nan
# Country....  Guyana
# Population ->  779836.3
# pwc =  1.3011345
# Country....  Honduras
# Population ->  10016948.0
# pwc =  6.5080395
# Country....  Croatia
# Population ->  4220629.0
# pwc =  2.8721507
# Country....  Haiti
# Population ->  11822517.0
# pwc =  7.9579535
# Country....  Hungary
# Population ->  9527543.0
# pwc =  4.5438848
# Country....  Indonesia
# Population ->  276454340.0
# pwc =  28.946255
# Country....  India
# Population ->  1520157800.0
# pwc =  12.47232
# Country....  Ireland
# Population ->  5493274.0
# pwc =  2.1132886
# Country....  Iran (Islamic Republic of)
# Population ->  88126200.0
# pwc =  20.55411
# Country....  Iraq
# Population ->  49970390.0
# pwc =  11.751307
# Country....  Iceland
# Population ->  411115.56
# pwc =  0.44174865
# Country....  Israel
# Population ->  10896391.0
# pwc =  14.027418
# Country....  Italy
# Population ->  61975372.0
# pwc =  5.2778053
# Country....  Jamaica
# Population ->  2876547.5
# pwc =  3.7117124
# Country....  Jordan
# Population ->  9924447.0
# pwc =  15.997361
# Country....  Japan
# Population ->  120325620.0
# pwc =  7.108158
# Country....  Kazakhstan
# Population ->  18706794.0
# pwc =  4.856509
# Country....  Kenya
# Population ->  60631976.0
# pwc =  5.2143946
# Country....  Kyrgyzstan
# Population ->  6092815.0
# pwc =  4.2360163
# Country....  Cambodia
# Population ->  16616119.0
# pwc =  13.594763
# Country....  Kiribati
# Population ->  95301.5
# pwc =  nan
# Country....  Republic of Korea
# Population ->  49694828.0
# pwc =  22.698042
# Country....  Kuwait
# Population ->  4423457.0
# pwc =  17.038328
# Country....  Lao People's Democratic Republic
# Population ->  7696361.5
# pwc =  6.441375
# Country....  Lebanon
# Population ->  4904970.0
# pwc =  21.253628
# Country....  Liberia
# Population ->  7469352.5
# pwc =  2.3968377
# Country....  Libya
# Population ->  8266879.0
# pwc =  5.256512
# Country....  Saint Lucia
# Population ->  201732.45
# pwc =  0.97171867
# Country....  Sri Lanka
# Population ->  23432206.0
# pwc =  11.362188
# Country....  Lesotho
# Population ->  2519346.0
# pwc =  1.7907864
# Country....  Lithuania
# Population ->  3051096.5
# pwc =  2.7800014
# Country....  Luxembourg
# Population ->  640977.44
# pwc =  5.0758314
# Country....  Latvia
# Population ->  2021167.0
# pwc =  2.3185625
# Country....  Morocco
# Population ->  36699784.0
# pwc =  7.0064836
# Country....  Republic of Moldova
# Population ->  2852623.2
# pwc =  3.2858534
# Country....  Madagascar
# Population ->  33253620.0
# pwc =  1.9250866
# Country....  Maldives
# Population ->  396984.2
# pwc =  7.849357
# Country....  Mexico
# Population ->  136970750.0
# pwc =  12.59573
# Country....  The former Yugoslav Republic of Macedonia
# Population ->  2186053.2
# pwc =  4.5744963
# Country....  Mali
# Population ->  25754680.0
# pwc =  4.689537
# Country....  Malta
# Population ->  444386.97
# pwc =  9.718471
# Country....  Myanmar
# Population ->  50970932.0
# pwc =  5.8834085
# Country....  Montenegro
# Population ->  576325.3
# pwc =  1.6466668
# Country....  Mongolia
# Population ->  3402033.2
# pwc =  1.7770263
# Country....  Mozambique
# Population ->  33668230.0
# pwc =  2.2563097
# Country....  Mauritania
# Population ->  5005213.0
# pwc =  1.901881
# Country....  Mauritius
# Population ->  1423854.0
# pwc =  2.2098463
# Country....  Malawi
# Population ->  26223352.0
# pwc =  3.8684475
# Country....  Malaysia
# Population ->  36488184.0
# pwc =  30.936977
# Country....  Namibia
# Population ->  2982699.8
# pwc =  1.9441621
# Country....  Niger
# Population ->  29652588.0
# pwc =  3.4329295
# Country....  Nigeria
# Population ->  252850430.0
# pwc =  7.7936273
# Country....  Nicaragua
# Population ->  6760911.0
# pwc =  2.782614
# Country....  Netherlands
# Population ->  17850448.0
# pwc =  6.5691156
# Country....  Norway
# Population ->  5992047.5
# pwc =  1.3286884
# Country....  Nepal
# Population ->  40950624.0
# pwc =  5.3657823
# Country....  New Zealand
# Population ->  5273856.0
# pwc =  2.1409154
# Country....  Oman
# Population ->  4012189.5
# pwc =  6.403637
# Country....  Pakistan
# Population ->  244536340.0
# pwc =  14.022485
# Country....  Panama
# Population ->  4460000.5
# pwc =  5.386955
# Country....  Peru
# Population ->  32811166.0
# pwc =  7.6322083
# Country....  Philippines
# Population ->  125228050.0
# pwc =  9.196972
# Country....  Papua New Guinea
# Population ->  9536360.0
# pwc =  0.63712436
# Country....  Poland
# Population ->  37922504.0
# pwc =  4.4887924
# Country....  Puerto Rico
# Population ->  3474375.8
# pwc =  8.596437
# Country....  Democratic People's Republic of Korea
# Population ->  25592082.0
# pwc =  5.134759
# Country....  Portugal
# Population ->  11081253.0
# pwc =  4.089252
# Country....  Paraguay
# Population ->  8378024.0
# pwc =  8.567229
# Country....  State of Palestine
# Population ->  5579556.0
# pwc =  11.945701
# Country....  Qatar
# Population ->  3029320.0
# pwc =  15.813983
# Country....  Romania
# Population ->  19695578.0
# pwc =  4.1785846
# Country....  Russian Federation
# Population ->  139611860.0
# pwc =  6.2367754
# Country....  Rwanda
# Population ->  16842354.0
# pwc =  5.917868
# Country....  Saudi Arabia
# Population ->  41718332.0
# pwc =  2.0410743
# Country....  Sudan
# Population ->  52033920.0
# pwc =  3.0457907
# Country....  Senegal
# Population ->  18602842.0
# pwc =  7.0715575
# Country....  Singapore
# Population ->  6236800.0
# pwc =  82.874306
# Country....  Solomon Islands
# Population ->  748808.06
# pwc =  0.16441831
# Country....  Sierra Leone
# Population ->  8754925.0
# pwc =  3.6020818
# Country....  El Salvador
# Population ->  6479347.5
# pwc =  10.362157
# Country....  Somalia
# Population ->  13152596.0
# pwc =  1.5221437
# Country....  Serbia
# Population ->  7699008.0
# pwc =  2.6396606
# Country....  South Sudan
# Population ->  12438253.0
# pwc =  3.5731266
# Country....  Sao Tome and Principe
# Population ->  195532.03
# pwc =  1.2875329
# Country....  Suriname
# Population ->  614288.2
# pwc =  4.8677073
# Country....  Slovakia
# Population ->  5675950.5
# pwc =  3.742063
# Country....  Slovenia
# Population ->  2154835.2
# pwc =  3.1786852
# Country....  Sweden
# Population ->  10974586.0
# pwc =  1.7858384
# Country....  Seychelles
# Population ->  97601.16
# pwc =  nan
# Country....  Syrian Arab Republic
# Population ->  27681192.0
# pwc =  5.680676
# Country....  Chad
# Population ->  18198582.0
# pwc =  2.3561983
# Country....  Togo
# Population ->  8287472.5
# pwc =  6.213884
# Country....  Thailand
# Population ->  75071930.0
# pwc =  16.248678
# Country....  Tajikistan
# Population ->  8093265.0
# pwc =  7.989765
# Country....  Turkmenistan
# Population ->  6005728.5
# pwc =  4.6202455
# Country....  Timor-Leste
# Population ->  1611926.5
# pwc =  3.666627
# Country....  Tonga
# Population ->  106246.195
# pwc =  nan
# Country....  Trinidad and Tobago
# Population ->  1351832.4
# pwc =  2.974046
# Country....  Tunisia
# Population ->  12203123.0
# pwc =  7.361782
# Country....  Turkey
# Population ->  87723680.0
# pwc =  3.9650347
# Country....  Taiwan
# Population ->  23371140.0
# pwc =  12.655666
# Country....  United Republic of Tanzania
# Population ->  72953190.0
# pwc =  2.5574698
# Country....  Uganda
# Population ->  59718216.0
# pwc =  5.4151034
# Country....  Ukraine
# Population ->  41132760.0
# pwc =  4.767613
# Country....  Uruguay
# Population ->  3442118.0
# pwc =  3.9926414
# Country....  United States of America
# Population ->  360721340.0
# pwc =  8.973218
# Country....  Uzbekistan
# Population ->  32100784.0
# pwc =  11.173
# Country....  Saint Vincent and the Grenadines
# Population ->  100569.68
# pwc =  1.1586714
# Country....  Venezuela (Bolivarian Republic of)
# Population ->  36772216.0
# pwc =  12.493325
# Country....  United States Virgin Islands
# Population ->  116202.29
# pwc =  5.991824
# Country....  Viet Nam
# Population ->  101790040.0
# pwc =  19.741205
# Country....  Vanuatu
# Population ->  339034.16
# pwc =  0.04890656
# Country....  Western Samoa
# Population ->  181161.45
# pwc =  nan
# Country....  Yemen
# Population ->  40429292.0
# pwc =  3.183426
# Country....  South Africa
# Population ->  58631504.0
# pwc =  6.526018
# Country....  Zambia
# Population ->  21303554.0
# pwc =  2.5333235
# Country....  Zimbabwe
# Population ->  13433098.0
# pwc =  3.1917112
# 2030
# MFR
# Country....  Afghanistan
# Population ->  51569350.0
# pwc =  5.6254
# Country....  Angola
# Population ->  31810306.0
# pwc =  2.2702048
# Country....  Albania
# Population ->  3275444.0
# pwc =  2.0928016
# Country....  United Arab Emirates
# Population ->  13130389.0
# pwc =  5.750523
# Country....  Argentina
# Population ->  46156050.0
# pwc =  7.1138563
# Country....  Armenia
# Population ->  2971908.0
# pwc =  7.944373
# Country....  Antigua and Barbuda
# Population ->  104914.68
# pwc =  3.4061308
# Country....  Australia
# Population ->  29546142.0
# pwc =  4.2414675
# Country....  Austria
# Population ->  8906304.0
# pwc =  2.9022605
# Country....  Azerbaijan
# Population ->  10601552.0
# pwc =  8.477088
# Country....  Burundi
# Population ->  13138348.0
# pwc =  4.4944773
# Country....  Belgium
# Population ->  11877237.0
# pwc =  6.386613
# Country....  Benin
# Population ->  14119145.0
# pwc =  6.534978
# Country....  Burkina Faso
# Population ->  27219980.0
# pwc =  6.0509295
# Country....  Bangladesh
# Population ->  181337010.0
# pwc =  9.844795
# Country....  Bulgaria
# Population ->  6820245.0
# pwc =  2.927335
# Country....  Bahrain
# Population ->  2317281.8
# pwc =  10.420443
# Country....  Bahamas
# Population ->  421744.8
# pwc =  5.1959677
# Country....  Bosnia and Herzegovina
# Population ->  3628331.8
# pwc =  1.5968128
# Country....  Belarus
# Population ->  8850704.0
# pwc =  3.781632
# Country....  Belize
# Population ->  389663.4
# pwc =  1.2466786
# Country....  Bolivia (Plurinational State of)
# Population ->  12577440.0
# pwc =  2.3204877
# Country....  Brazil
# Population ->  220909840.0
# pwc =  6.54577
# Country....  Barbados
# Population ->  278090.28
# pwc =  6.5418634
# Country....  Brunei Darussalam
# Population ->  525387.1
# pwc =  5.683889
# Country....  Bhutan
# Population ->  1122573.4
# pwc =  1.8172648
# Country....  Botswana
# Population ->  2392943.2
# pwc =  1.5891522
# Country....  Central African Republic
# Population ->  6087641.0
# pwc =  2.8069048
# Country....  Canada
# Population ->  41252284.0
# pwc =  4.5127425
# Country....  Switzerland
# Population ->  8473224.0
# pwc =  4.42882
# Country....  Chile
# Population ->  19636982.0
# pwc =  13.163559
# Country....  China
# Population ->  1380762000.0
# pwc =  8.333394
# Country....  Côte d'Ivoire
# Population ->  26194698.0
# pwc =  6.373473
# Country....  Cameroon
# Population ->  27296116.0
# pwc =  4.875892
# Country....  Democratic Republic of the Congo
# Population ->  107298650.0
# pwc =  3.5653741
# Country....  Congo
# Population ->  6317289.0
# pwc =  3.657262
# Country....  Colombia
# Population ->  57311930.0
# pwc =  6.200544
# Country....  Comoros
# Population ->  1018113.06
# pwc =  0.44369462
# Country....  Cape Verde
# Population ->  545873.75
# pwc =  2.3562067
# Country....  Costa Rica
# Population ->  5916929.0
# pwc =  6.855546
# Country....  Cuba
# Population ->  10656096.0
# pwc =  4.657693
# Country....  Cyprus
# Population ->  1363787.4
# pwc =  7.545435
# Country....  Czech Republic
# Population ->  11271592.0
# pwc =  3.1721332
# Country....  Germany
# Population ->  81352080.0
# pwc =  3.984624
# Country....  Djibouti
# Population ->  1167196.8
# pwc =  3.0129097
# Country....  Denmark
# Population ->  6078603.0
# pwc =  2.1160526
# Country....  Dominican Republic
# Population ->  11993334.0
# pwc =  6.788727
# Country....  Algeria
# Population ->  44396916.0
# pwc =  4.69378
# Country....  Ecuador
# Population ->  17978846.0
# pwc =  4.55613
# Country....  Egypt
# Population ->  106585930.0
# pwc =  19.451593
# Country....  Eritrea
# Population ->  8419884.0
# pwc =  1.5884801
# Country....  Spain
# Population ->  50226230.0
# pwc =  3.6396065
# Country....  Estonia
# Population ->  1295291.1
# pwc =  2.3289068
# Country....  Ethiopia
# Population ->  124165280.0
# pwc =  2.937356
# Country....  Finland
# Population ->  5818852.0
# pwc =  1.7057843
# Country....  Fiji
# Population ->  959424.9
# pwc =  0.0
# Country....  France
# Population ->  70312770.0
# pwc =  4.4440575
# Country....  Micronesia (Federated States of)
# Population ->  111568.516
# pwc =  0.017682405
# Country....  Gabon
# Population ->  1982088.0
# pwc =  7.2614007
# Country....  United Kingdom of Great Britain and Northern Ireland
# Population ->  69232220.0
# pwc =  3.135563
# Country....  Georgia
# Population ->  3871044.0
# pwc =  6.7150617
# Country....  Ghana
# Population ->  36048332.0
# pwc =  6.9223127
# Country....  Guinea
# Population ->  13446847.0
# pwc =  3.1643941
# Country....  Gambia
# Population ->  2555412.8
# pwc =  9.162658
# Country....  Guinea-Bissau
# Population ->  2121141.5
# pwc =  3.9851098
# Country....  Equatorial Guinea
# Population ->  1105595.1
# pwc =  2.298542
# Country....  Greece
# Population ->  11379352.0
# pwc =  6.136118
# Country....  Grenada
# Population ->  121295.2
# pwc =  1.3837124
# Country....  Guatemala
# Population ->  20315920.0
# pwc =  6.519455
# Country....  Guam
# Population ->  219413.16
# pwc =  nan
# Country....  Guyana
# Population ->  779836.3
# pwc =  1.2668889
# Country....  Honduras
# Population ->  10016948.0
# pwc =  5.6803985
# Country....  Croatia
# Population ->  4220629.0
# pwc =  2.3449218
# Country....  Haiti
# Population ->  11822517.0
# pwc =  6.3832626
# Country....  Hungary
# Population ->  9527543.0
# pwc =  3.5762165
# Country....  Indonesia
# Population ->  276454340.0
# pwc =  20.62479
# Country....  India
# Population ->  1520157800.0
# pwc =  9.737357
# Country....  Ireland
# Population ->  5493274.0
# pwc =  1.535059
# Country....  Iran (Islamic Republic of)
# Population ->  88126200.0
# pwc =  13.753881
# Country....  Iraq
# Population ->  49970390.0
# pwc =  8.443163
# Country....  Iceland
# Population ->  411115.56
# pwc =  0.333449
# Country....  Israel
# Population ->  10896391.0
# pwc =  9.235556
# Country....  Italy
# Population ->  61975372.0
# pwc =  4.3084836
# Country....  Jamaica
# Population ->  2876547.5
# pwc =  3.037444
# Country....  Jordan
# Population ->  9924447.0
# pwc =  10.380143
# Country....  Japan
# Population ->  120325620.0
# pwc =  4.9661636
# Country....  Kazakhstan
# Population ->  18706794.0
# pwc =  2.5216656
# Country....  Kenya
# Population ->  60631976.0
# pwc =  4.3378243
# Country....  Kyrgyzstan
# Population ->  6092815.0
# pwc =  2.63665
# Country....  Cambodia
# Population ->  16616119.0
# pwc =  11.435179
# Country....  Kiribati
# Population ->  95301.5
# pwc =  nan
# Country....  Republic of Korea
# Population ->  49694828.0
# pwc =  11.492117
# Country....  Kuwait
# Population ->  4423457.0
# pwc =  10.681728
# Country....  Lao People's Democratic Republic
# Population ->  7696361.5
# pwc =  5.805277
# Country....  Lebanon
# Population ->  4904970.0
# pwc =  13.8547535
# Country....  Liberia
# Population ->  7469352.5
# pwc =  2.2250848
# Country....  Libya
# Population ->  8266879.0
# pwc =  3.9392383
# Country....  Saint Lucia
# Population ->  201732.45
# pwc =  0.8235385
# Country....  Sri Lanka
# Population ->  23432206.0
# pwc =  8.993794
# Country....  Lesotho
# Population ->  2519346.0
# pwc =  1.4916728
# Country....  Lithuania
# Population ->  3051096.5
# pwc =  2.1527262
# Country....  Luxembourg
# Population ->  640977.44
# pwc =  4.0668044
# Country....  Latvia
# Population ->  2021167.0
# pwc =  1.8354328
# Country....  Morocco
# Population ->  36699784.0
# pwc =  4.9073296
# Country....  Republic of Moldova
# Population ->  2852623.2
# pwc =  2.5550714
# Country....  Madagascar
# Population ->  33253620.0
# pwc =  1.6978178
# Country....  Maldives
# Population ->  396984.2
# pwc =  5.0856013
# Country....  Mexico
# Population ->  136970750.0
# pwc =  7.1932316
# Country....  The former Yugoslav Republic of Macedonia
# Population ->  2186053.2
# pwc =  3.4777305
# Country....  Mali
# Population ->  25754680.0
# pwc =  4.5307965
# Country....  Malta
# Population ->  444386.97
# pwc =  7.3475223
# Country....  Myanmar
# Population ->  50970932.0
# pwc =  5.21874
# Country....  Montenegro
# Population ->  576325.3
# pwc =  1.2773644
# Country....  Mongolia
# Population ->  3402033.2
# pwc =  1.0736201
# Country....  Mozambique
# Population ->  33668230.0
# pwc =  1.9579874
# Country....  Mauritania
# Population ->  5005213.0
# pwc =  1.6767128
# Country....  Mauritius
# Population ->  1423854.0
# pwc =  1.9222476
# Country....  Malawi
# Population ->  26223352.0
# pwc =  3.4268854
# Country....  Malaysia
# Population ->  36488184.0
# pwc =  24.335913
# Country....  Namibia
# Population ->  2982699.8
# pwc =  1.7477852
# Country....  Niger
# Population ->  29652588.0
# pwc =  3.2691295
# Country....  Nigeria
# Population ->  252850430.0
# pwc =  6.7118893
# Country....  Nicaragua
# Population ->  6760911.0
# pwc =  2.4137528
# Country....  Netherlands
# Population ->  17850448.0
# pwc =  5.3874264
# Country....  Norway
# Population ->  5992047.5
# pwc =  1.0348238
# Country....  Nepal
# Population ->  40950624.0
# pwc =  4.4485555
# Country....  New Zealand
# Population ->  5273856.0
# pwc =  1.651432
# Country....  Oman
# Population ->  4012189.5
# pwc =  3.5175483
# Country....  Pakistan
# Population ->  244536340.0
# pwc =  11.412534
# Country....  Panama
# Population ->  4460000.5
# pwc =  4.3910403
# Country....  Peru
# Population ->  32811166.0
# pwc =  5.80497
# Country....  Philippines
# Population ->  125228050.0
# pwc =  7.252468
# Country....  Papua New Guinea
# Population ->  9536360.0
# pwc =  0.6194906
# Country....  Poland
# Population ->  37922504.0
# pwc =  3.3085644
# Country....  Puerto Rico
# Population ->  3474375.8
# pwc =  6.8257484
# Country....  Democratic People's Republic of Korea
# Population ->  25592082.0
# pwc =  2.8543637
# Country....  Portugal
# Population ->  11081253.0
# pwc =  3.2499995
# Country....  Paraguay
# Population ->  8378024.0
# pwc =  7.7841897
# Country....  State of Palestine
# Population ->  5579556.0
# pwc =  7.8459783
# Country....  Qatar
# Population ->  3029320.0
# pwc =  10.600004
# Country....  Romania
# Population ->  19695578.0
# pwc =  3.0797684
# Country....  Russian Federation
# Population ->  139611860.0
# pwc =  3.5259573
# Country....  Rwanda
# Population ->  16842354.0
# pwc =  5.320852
# Country....  Saudi Arabia
# Population ->  41718332.0
# pwc =  1.4590069
# Country....  Sudan
# Population ->  52033920.0
# pwc =  2.6497486
# Country....  Senegal
# Population ->  18602842.0
# pwc =  6.131462
# Country....  Singapore
# Population ->  6236800.0
# pwc =  66.00999
# Country....  Solomon Islands
# Population ->  748808.06
# pwc =  0.14334077
# Country....  Sierra Leone
# Population ->  8754925.0
# pwc =  3.3271234
# Country....  El Salvador
# Population ->  6479347.5
# pwc =  8.749089
# Country....  Somalia
# Population ->  13152596.0
# pwc =  1.3938112
# Country....  Serbia
# Population ->  7699008.0
# pwc =  2.04068
# Country....  South Sudan
# Population ->  12438253.0
# pwc =  3.4210918
# Country....  Sao Tome and Principe
# Population ->  195532.03
# pwc =  1.0787547
# Country....  Suriname
# Population ->  614288.2
# pwc =  4.7495494
# Country....  Slovakia
# Population ->  5675950.5
# pwc =  2.7835436
# Country....  Slovenia
# Population ->  2154835.2
# pwc =  2.645951
# Country....  Sweden
# Population ->  10974586.0
# pwc =  1.4675813
# Country....  Seychelles
# Population ->  97601.16
# pwc =  nan
# Country....  Syrian Arab Republic
# Population ->  27681192.0
# pwc =  3.9566622
# Country....  Chad
# Population ->  18198582.0
# pwc =  2.2049067
# Country....  Togo
# Population ->  8287472.5
# pwc =  5.4722624
# Country....  Thailand
# Population ->  75071930.0
# pwc =  12.576723
# Country....  Tajikistan
# Population ->  8093265.0
# pwc =  5.1202292
# Country....  Turkmenistan
# Population ->  6005728.5
# pwc =  3.1494422
# Country....  Timor-Leste
# Population ->  1611926.5
# pwc =  2.6700742
# Country....  Tonga
# Population ->  106246.195
# pwc =  nan
# Country....  Trinidad and Tobago
# Population ->  1351832.4
# pwc =  2.5252485
# Country....  Tunisia
# Population ->  12203123.0
# pwc =  5.379931
# Country....  Turkey
# Population ->  87723680.0
# pwc =  2.8316076
# Country....  Taiwan
# Population ->  23371140.0
# pwc =  8.657335
# Country....  United Republic of Tanzania
# Population ->  72953190.0
# pwc =  2.3351583
# Country....  Uganda
# Population ->  59718216.0
# pwc =  4.917162
# Country....  Ukraine
# Population ->  41132760.0
# pwc =  3.113451
# Country....  Uruguay
# Population ->  3442118.0
# pwc =  3.2665052
# Country....  United States of America
# Population ->  360721340.0
# pwc =  5.765197
# Country....  Uzbekistan
# Population ->  32100784.0
# pwc =  6.0861945
# Country....  Saint Vincent and the Grenadines
# Population ->  100569.68
# pwc =  0.98216945
# Country....  Venezuela (Bolivarian Republic of)
# Population ->  36772216.0
# pwc =  10.040439
# Country....  United States Virgin Islands
# Population ->  116202.29
# pwc =  4.7705
# Country....  Viet Nam
# Population ->  101790040.0
# pwc =  14.659901
# Country....  Vanuatu
# Population ->  339034.16
# pwc =  0.0377233
# Country....  Western Samoa
# Population ->  181161.45
# pwc =  nan
# Country....  Yemen
# Population ->  40429292.0
# pwc =  2.273755
# Country....  South Africa
# Population ->  58631504.0
# pwc =  4.787476
# Country....  Zambia
# Population ->  21303554.0
# pwc =  2.277163
# Country....  Zimbabwe
# Population ->  13433098.0
# pwc =  2.8380728
# 2050
# CLE
# Country....  Afghanistan
# Population ->  74851224.0
# pwc =  7.860895
# Country....  Angola
# Population ->  43894250.0
# pwc =  2.8283598
# Country....  Albania
# Population ->  3178503.5
# pwc =  2.3684814
# Country....  United Arab Emirates
# Population ->  16626324.0
# pwc =  12.627676
# Country....  Argentina
# Population ->  49394132.0
# pwc =  11.730841
# Country....  Armenia
# Population ->  2661070.2
# pwc =  16.443293
# Country....  Antigua and Barbuda
# Population ->  114910.34
# pwc =  4.217781
# Country....  Australia
# Population ->  36016376.0
# pwc =  5.866748
# Country....  Austria
# Population ->  9167247.0
# pwc =  3.2306535
# Country....  Azerbaijan
# Population ->  10958307.0
# pwc =  19.533194
# Country....  Burundi
# Population ->  16952834.0
# pwc =  6.190861
# Country....  Belgium
# Population ->  12699647.0
# pwc =  6.175038
# Country....  Benin
# Population ->  19043810.0
# pwc =  8.994601
# Country....  Burkina Faso
# Population ->  38491132.0
# pwc =  6.655105
# Country....  Bangladesh
# Population ->  196263040.0
# pwc =  14.060175
# Country....  Bulgaria
# Population ->  6371603.0
# pwc =  3.1569383
# Country....  Bahrain
# Population ->  3166215.5
# pwc =  18.837767
# Country....  Bahamas
# Population ->  474483.56
# pwc =  6.527394
# Country....  Bosnia and Herzegovina
# Population ->  3304486.0
# pwc =  1.6447853
# Country....  Belarus
# Population ->  8145775.0
# pwc =  5.487083
# Country....  Belize
# Population ->  433652.28
# pwc =  1.5639173
# Country....  Bolivia (Plurinational State of)
# Population ->  14235534.0
# pwc =  2.7378404
# Country....  Brazil
# Population ->  229886480.0
# pwc =  9.443405
# Country....  Barbados
# Population ->  265086.66
# pwc =  7.982746
# Country....  Brunei Darussalam
# Population ->  624933.4
# pwc =  7.683681
# Country....  Bhutan
# Population ->  1313211.2
# pwc =  2.3589396
# Country....  Botswana
# Population ->  2687887.0
# pwc =  2.1060946
# Country....  Central African Republic
# Population ->  7416881.5
# pwc =  3.1910875
# Country....  Canada
# Population ->  47430064.0
# pwc =  6.3239055
# Country....  Switzerland
# Population ->  9101440.0
# pwc =  4.3475127
# Country....  Chile
# Population ->  20482258.0
# pwc =  23.862423
# Country....  China
# Population ->  1263429800.0
# pwc =  10.989268
# Country....  Côte d'Ivoire
# Population ->  30718252.0
# pwc =  7.000817
# Country....  Cameroon
# Population ->  33233482.0
# pwc =  6.2780805
# Country....  Democratic Republic of the Congo
# Population ->  145742370.0
# pwc =  4.3233685
# Country....  Congo
# Population ->  8144484.0
# pwc =  4.62185
# Country....  Colombia
# Population ->  63885450.0
# pwc =  8.761522
# Country....  Comoros
# Population ->  1248867.2
# pwc =  0.59719276
# Country....  Cape Verde
# Population ->  560125.25
# pwc =  3.436071
# Country....  Costa Rica
# Population ->  6743049.0
# pwc =  9.048474
# Country....  Cuba
# Population ->  9159511.0
# pwc =  5.7211146
# Country....  Cyprus
# Population ->  1563442.1
# pwc =  12.399556
# Country....  Czech Republic
# Population ->  11666367.0
# pwc =  3.3942375
# Country....  Germany
# Population ->  78995256.0
# pwc =  3.855276
# Country....  Djibouti
# Population ->  1364366.9
# pwc =  4.565834
# Country....  Denmark
# Population ->  6563784.0
# pwc =  2.0127542
# Country....  Dominican Republic
# Population ->  13117961.0
# pwc =  9.078239
# Country....  Algeria
# Population ->  49387556.0
# pwc =  7.382319
# Country....  Ecuador
# Population ->  20090172.0
# pwc =  6.394298
# Country....  Egypt
# Population ->  124763460.0
# pwc =  33.516724
# Country....  Eritrea
# Population ->  11458640.0
# pwc =  2.06285
# Country....  Spain
# Population ->  52781310.0
# pwc =  4.231579
# Country....  Estonia
# Population ->  1257269.9
# pwc =  2.4833653
# Country....  Ethiopia
# Population ->  159083730.0
# pwc =  4.205346
# Country....  Finland
# Population ->  6147114.5
# pwc =  1.7925173
# Country....  Fiji
# Population ->  968932.06
# pwc =  0.0
# Country....  France
# Population ->  76476180.0
# pwc =  4.258013
# Country....  Micronesia (Federated States of)
# Population ->  103917.57
# pwc =  0.0205188
# Country....  Gabon
# Population ->  2288900.8
# pwc =  10.264224
# Country....  United Kingdom of Great Britain and Northern Ireland
# Population ->  75753030.0
# pwc =  3.0932019
# Country....  Georgia
# Population ->  3263309.5
# pwc =  11.713345
# Country....  Ghana
# Population ->  46507180.0
# pwc =  8.32449
# Country....  Guinea
# Population ->  15641220.0
# pwc =  3.7055335
# Country....  Gambia
# Population ->  3224612.0
# pwc =  11.662249
# Country....  Guinea-Bissau
# Population ->  2558649.5
# pwc =  4.975276
# Country....  Equatorial Guinea
# Population ->  1450070.0
# pwc =  3.2910178
# Country....  Greece
# Population ->  11255213.0
# pwc =  7.68753
# Country....  Grenada
# Population ->  123442.86
# pwc =  1.6993369
# Country....  Guatemala
# Population ->  24824948.0
# pwc =  9.60269
# Country....  Guam
# Population ->  241078.47
# pwc =  nan
# Country....  Guyana
# Population ->  731892.75
# pwc =  1.3241636
# Country....  Honduras
# Population ->  11604133.0
# pwc =  6.9471374
# Country....  Croatia
# Population ->  4024295.0
# pwc =  2.5118394
# Country....  Haiti
# Population ->  12664234.0
# pwc =  8.441882
# Country....  Hungary
# Population ->  8942928.0
# pwc =  4.1295166
# Country....  Indonesia
# Population ->  286657800.0
# pwc =  35.311317
# Country....  India
# Population ->  1725363600.0
# pwc =  12.227933
# Country....  Ireland
# Population ->  6333134.5
# pwc =  1.8624102
# Country....  Iran (Islamic Republic of)
# Population ->  93755820.0
# pwc =  24.773403
# Country....  Iraq
# Population ->  67420690.0
# pwc =  14.683584
# Country....  Iceland
# Population ->  489741.84
# pwc =  0.41956592
# Country....  Israel
# Population ->  14277582.0
# pwc =  16.370476
# Country....  Italy
# Population ->  61505264.0
# pwc =  4.506531
# Country....  Jamaica
# Population ->  2782784.2
# pwc =  3.8805668
# Country....  Jordan
# Population ->  13312479.0
# pwc =  19.369633
# Country....  Japan
# Population ->  108531770.0
# pwc =  6.3231487
# Country....  Kazakhstan
# Population ->  20155218.0
# pwc =  5.5203347
# Country....  Kenya
# Population ->  78194040.0
# pwc =  6.7755947
# Country....  Kyrgyzstan
# Population ->  6335187.0
# pwc =  5.168643
# Country....  Cambodia
# Population ->  17551128.0
# pwc =  14.48102
# Country....  Kiribati
# Population ->  113375.414
# pwc =  nan
# Country....  Republic of Korea
# Population ->  46228788.0
# pwc =  19.591385
# Country....  Kuwait
# Population ->  5871702.0
# pwc =  20.87184
# Country....  Lao People's Democratic Republic
# Population ->  8461506.0
# pwc =  6.6705804
# Country....  Lebanon
# Population ->  5119278.5
# pwc =  25.666206
# Country....  Liberia
# Population ->  10896365.0
# pwc =  2.605254
# Country....  Libya
# Population ->  9673473.0
# pwc =  5.7715974
# Country....  Saint Lucia
# Population ->  212600.7
# pwc =  1.0129344
# Country....  Sri Lanka
# Population ->  24184630.0
# pwc =  13.559865
# Country....  Lesotho
# Population ->  2662419.2
# pwc =  2.0166783
# Country....  Lithuania
# Population ->  2715172.2
# pwc =  2.4413707
# Country....  Luxembourg
# Population ->  778738.6
# pwc =  4.1003795
# Country....  Latvia
# Population ->  1837967.5
# pwc =  1.9469379
# Country....  Morocco
# Population ->  37691508.0
# pwc =  7.8718934
# Country....  Republic of Moldova
# Population ->  2197278.2
# pwc =  3.3938987
# Country....  Madagascar
# Population ->  45090172.0
# pwc =  2.26578
# Country....  Maldives
# Population ->  451378.1
# pwc =  6.3307443
# Country....  Mexico
# Population ->  149000210.0
# pwc =  13.444802
# Country....  The former Yugoslav Republic of Macedonia
# Population ->  2298596.2
# pwc =  3.9832172
# Country....  Mali
# Population ->  35844424.0
# pwc =  4.899498
# Country....  Malta
# Population ->  443076.0
# pwc =  10.286117
# Country....  Myanmar
# Population ->  48526104.0
# pwc =  6.418017
# Country....  Montenegro
# Population ->  563689.25
# pwc =  1.325971
# Country....  Mongolia
# Population ->  3746047.2
# pwc =  1.865279
# Country....  Mozambique
# Population ->  42219972.0
# pwc =  2.6059015
# Country....  Mauritania
# Population ->  6242149.0
# pwc =  2.2426314
# Country....  Mauritius
# Population ->  1467225.5
# pwc =  2.7189
# Country....  Malawi
# Population ->  40419316.0
# pwc =  4.540224
# Country....  Malaysia
# Population ->  42453270.0
# pwc =  44.59448
# Country....  Namibia
# Population ->  3394970.2
# pwc =  2.2449198
# Country....  Niger
# Population ->  50550210.0
# pwc =  3.6654377
# Country....  Nigeria
# Population ->  371913800.0
# pwc =  9.130756
# Country....  Nicaragua
# Population ->  7027129.5
# pwc =  2.9743233
# Country....  Netherlands
# Population ->  18528804.0
# pwc =  5.1538258
# Country....  Norway
# Population ->  7049558.0
# pwc =  1.1444728
# Country....  Nepal
# Population ->  49475228.0
# pwc =  5.7979264
# Country....  New Zealand
# Population ->  5932629.0
# pwc =  2.227903
# Country....  Oman
# Population ->  5041499.5
# pwc =  7.7363415
# Country....  Pakistan
# Population ->  297235040.0
# pwc =  16.239132
# Country....  Panama
# Population ->  5089046.5
# pwc =  5.929929
# Country....  Peru
# Population ->  33624870.0
# pwc =  8.76714
# Country....  Philippines
# Population ->  148896020.0
# pwc =  9.716699
# Country....  Papua New Guinea
# Population ->  11494345.0
# pwc =  0.6351034
# Country....  Poland
# Population ->  35216320.0
# pwc =  3.6080232
# Country....  Puerto Rico
# Population ->  2968537.5
# pwc =  9.095169
# Country....  Democratic People's Republic of Korea
# Population ->  24648276.0
# pwc =  5.3525233
# Country....  Portugal
# Population ->  11310766.0
# pwc =  3.753711
# Country....  Paraguay
# Population ->  9684122.0
# pwc =  8.959034
# Country....  State of Palestine
# Population ->  6216437.5
# pwc =  13.953888
# Country....  Qatar
# Population ->  3778571.0
# pwc =  19.544273
# Country....  Romania
# Population ->  17559112.0
# pwc =  3.9146395
# Country....  Russian Federation
# Population ->  136708420.0
# pwc =  5.7966795
# Country....  Rwanda
# Population ->  22958144.0
# pwc =  7.2332582
# Country....  Saudi Arabia
# Population ->  54235172.0
# pwc =  2.5092976
# Country....  Sudan
# Population ->  65859536.0
# pwc =  3.398865
# Country....  Senegal
# Population ->  23998222.0
# pwc =  8.587296
# Country....  Singapore
# Population ->  6722587.5
# pwc =  113.926994
# Country....  Solomon Islands
# Population ->  932247.4
# pwc =  0.16011667
# Country....  Sierra Leone
# Population ->  11274036.0
# pwc =  3.9402049
# Country....  El Salvador
# Population ->  6201797.0
# pwc =  11.707289
# Country....  Somalia
# Population ->  16131355.0
# pwc =  1.7894582
# Country....  Serbia
# Population ->  7669823.0
# pwc =  2.3661997
# Country....  South Sudan
# Population ->  15747296.0
# pwc =  3.7286587
# Country....  Sao Tome and Principe
# Population ->  207235.4
# pwc =  1.5315988
# Country....  Suriname
# Population ->  661254.25
# pwc =  5.066794
# Country....  Slovakia
# Population ->  5539414.5
# pwc =  3.2056124
# Country....  Slovenia
# Population ->  2212949.0
# pwc =  2.6989346
# Country....  Sweden
# Population ->  12498127.0
# pwc =  1.4784582
# Country....  Seychelles
# Population ->  99595.2
# pwc =  nan
# Country....  Syrian Arab Republic
# Population ->  33294062.0
# pwc =  6.662476
# Country....  Chad
# Population ->  25131790.0
# pwc =  2.5070279
# Country....  Togo
# Population ->  10168086.0
# pwc =  7.207077
# Country....  Thailand
# Population ->  73688000.0
# pwc =  19.200993
# Country....  Tajikistan
# Population ->  8270009.5
# pwc =  9.158357
# Country....  Turkmenistan
# Population ->  6390211.5
# pwc =  5.829358
# Country....  Timor-Leste
# Population ->  2002030.6
# pwc =  4.181354
# Country....  Tonga
# Population ->  102639.72
# pwc =  nan
# Country....  Trinidad and Tobago
# Population ->  1239042.5
# pwc =  3.2331827
# Country....  Tunisia
# Population ->  12748625.0
# pwc =  8.1105585
# Country....  Turkey
# Population ->  95869650.0
# pwc =  4.1332397
# Country....  Taiwan
# Population ->  21260308.0
# pwc =  11.203885
# Country....  United Republic of Tanzania
# Population ->  102119080.0
# pwc =  2.989715
# Country....  Uganda
# Population ->  92730150.0
# pwc =  6.057624
# Country....  Ukraine
# Population ->  38902750.0
# pwc =  5.469594
# Country....  Uruguay
# Population ->  3327044.0
# pwc =  4.3160176
# Country....  United States of America
# Population ->  401977250.0
# pwc =  8.059853
# Country....  Uzbekistan
# Population ->  33526986.0
# pwc =  13.362092
# Country....  Saint Vincent and the Grenadines
# Population ->  95967.55
# pwc =  1.213453
# Country....  Venezuela (Bolivarian Republic of)
# Population ->  41608360.0
# pwc =  13.575021
# Country....  United States Virgin Islands
# Population ->  115740.0
# pwc =  6.353708
# Country....  Viet Nam
# Population ->  104221550.0
# pwc =  21.445477
# Country....  Vanuatu
# Population ->  424158.28
# pwc =  0.05115201
# Country....  Western Samoa
# Population ->  166094.94
# pwc =  nan
# Country....  Yemen
# Population ->  56907950.0
# pwc =  3.8498454
# Country....  South Africa
# Population ->  63106100.0
# pwc =  6.8246946
# Country....  Zambia
# Population ->  30011614.0
# pwc =  2.9301908
# Country....  Zimbabwe
# Population ->  13274143.0
# pwc =  3.9899993
# 2050
# MFR
# Country....  Afghanistan
# Population ->  74851224.0
# pwc =  5.822359
# Country....  Angola
# Population ->  43894250.0
# pwc =  2.2974281
# Country....  Albania
# Population ->  3178503.5
# pwc =  1.7162653
# Country....  United Arab Emirates
# Population ->  16626324.0
# pwc =  6.443979
# Country....  Argentina
# Population ->  49394132.0
# pwc =  7.3555517
# Country....  Armenia
# Population ->  2661070.2
# pwc =  10.064655
# Country....  Antigua and Barbuda
# Population ->  114910.34
# pwc =  3.3700206
# Country....  Australia
# Population ->  36016376.0
# pwc =  3.982885
# Country....  Austria
# Population ->  9167247.0
# pwc =  2.4084113
# Country....  Azerbaijan
# Population ->  10958307.0
# pwc =  9.436315
# Country....  Burundi
# Population ->  16952834.0
# pwc =  5.175093
# Country....  Belgium
# Population ->  12699647.0
# pwc =  4.641489
# Country....  Benin
# Population ->  19043810.0
# pwc =  6.9018035
# Country....  Burkina Faso
# Population ->  38491132.0
# pwc =  6.1774387
# Country....  Bangladesh
# Population ->  196263040.0
# pwc =  9.754172
# Country....  Bulgaria
# Population ->  6371603.0
# pwc =  2.6031282
# Country....  Bahrain
# Population ->  3166215.5
# pwc =  12.149748
# Country....  Bahamas
# Population ->  474483.56
# pwc =  4.804552
# Country....  Bosnia and Herzegovina
# Population ->  3304486.0
# pwc =  1.2911432
# Country....  Belarus
# Population ->  8145775.0
# pwc =  3.8942552
# Country....  Belize
# Population ->  433652.28
# pwc =  1.2403605
# Country....  Bolivia (Plurinational State of)
# Population ->  14235534.0
# pwc =  2.3800213
# Country....  Brazil
# Population ->  229886480.0
# pwc =  6.437307
# Country....  Barbados
# Population ->  265086.66
# pwc =  6.5057526
# Country....  Brunei Darussalam
# Population ->  624933.4
# pwc =  6.2299623
# Country....  Bhutan
# Population ->  1313211.2
# pwc =  1.6381611
# Country....  Botswana
# Population ->  2687887.0
# pwc =  1.697453
# Country....  Central African Republic
# Population ->  7416881.5
# pwc =  2.84132
# Country....  Canada
# Population ->  47430064.0
# pwc =  4.2780647
# Country....  Switzerland
# Population ->  9101440.0
# pwc =  3.3428261
# Country....  Chile
# Population ->  20482258.0
# pwc =  7.6101165
# Country....  China
# Population ->  1263429800.0
# pwc =  6.0788927
# Country....  Côte d'Ivoire
# Population ->  30718252.0
# pwc =  6.5219383
# Country....  Cameroon
# Population ->  33233482.0
# pwc =  5.1900926
# Country....  Democratic Republic of the Congo
# Population ->  145742370.0
# pwc =  3.6778464
# Country....  Congo
# Population ->  8144484.0
# pwc =  3.748094
# Country....  Colombia
# Population ->  63885450.0
# pwc =  6.549724
# Country....  Comoros
# Population ->  1248867.2
# pwc =  0.49633387
# Country....  Cape Verde
# Population ->  560125.25
# pwc =  2.570434
# Country....  Costa Rica
# Population ->  6743049.0
# pwc =  7.2624865
# Country....  Cuba
# Population ->  9159511.0
# pwc =  4.350171
# Country....  Cyprus
# Population ->  1563442.1
# pwc =  7.5766735
# Country....  Czech Republic
# Population ->  11666367.0
# pwc =  2.5462134
# Country....  Germany
# Population ->  78995256.0
# pwc =  3.1507025
# Country....  Djibouti
# Population ->  1364366.9
# pwc =  3.4167767
# Country....  Denmark
# Population ->  6563784.0
# pwc =  1.5884771
# Country....  Dominican Republic
# Population ->  13117961.0
# pwc =  6.6989923
# Country....  Algeria
# Population ->  49387556.0
# pwc =  4.8219004
# Country....  Ecuador
# Population ->  20090172.0
# pwc =  4.6089993
# Country....  Egypt
# Population ->  124763460.0
# pwc =  18.443457
# Country....  Eritrea
# Population ->  11458640.0
# pwc =  1.7119067
# Country....  Spain
# Population ->  52781310.0
# pwc =  3.1890366
# Country....  Estonia
# Population ->  1257269.9
# pwc =  1.8640877
# Country....  Ethiopia
# Population ->  159083730.0
# pwc =  3.1432266
# Country....  Finland
# Population ->  6147114.5
# pwc =  1.3551064
# Country....  Fiji
# Population ->  968932.06
# pwc =  0.0
# Country....  France
# Population ->  76476180.0
# pwc =  3.436312
# Country....  Micronesia (Federated States of)
# Population ->  103917.57
# pwc =  0.01752247
# Country....  Gabon
# Population ->  2288900.8
# pwc =  7.7751956
# Country....  United Kingdom of Great Britain and Northern Ireland
# Population ->  75753030.0
# pwc =  2.2173164
# Country....  Georgia
# Population ->  3263309.5
# pwc =  8.6642475
# Country....  Ghana
# Population ->  46507180.0
# pwc =  7.1256223
# Country....  Guinea
# Population ->  15641220.0
# pwc =  3.2826483
# Country....  Gambia
# Population ->  3224612.0
# pwc =  9.683386
# Country....  Guinea-Bissau
# Population ->  2558649.5
# pwc =  4.2211604
# Country....  Equatorial Guinea
# Population ->  1450070.0
# pwc =  2.4799054
# Country....  Greece
# Population ->  11255213.0
# pwc =  5.8561754
# Country....  Grenada
# Population ->  123442.86
# pwc =  1.3650523
# Country....  Guatemala
# Population ->  24824948.0
# pwc =  6.8302736
# Country....  Guam
# Population ->  241078.47
# pwc =  nan
# Country....  Guyana
# Population ->  731892.75
# pwc =  1.2799647
# Country....  Honduras
# Population ->  11604133.0
# pwc =  5.870542
# Country....  Croatia
# Population ->  4024295.0
# pwc =  1.9684327
# Country....  Haiti
# Population ->  12664234.0
# pwc =  6.319125
# Country....  Hungary
# Population ->  8942928.0
# pwc =  3.254899
# Country....  Indonesia
# Population ->  286657800.0
# pwc =  23.23333
# Country....  India
# Population ->  1725363600.0
# pwc =  8.941305
# Country....  Ireland
# Population ->  6333134.5
# pwc =  1.2506204
# Country....  Iran (Islamic Republic of)
# Population ->  93755820.0
# pwc =  16.217121
# Country....  Iraq
# Population ->  67420690.0
# pwc =  10.310382
# Country....  Iceland
# Population ->  489741.84
# pwc =  0.23626581
# Country....  Israel
# Population ->  14277582.0
# pwc =  9.828326
# Country....  Italy
# Population ->  61505264.0
# pwc =  3.4983375
# Country....  Jamaica
# Population ->  2782784.2
# pwc =  3.0053215
# Country....  Jordan
# Population ->  13312479.0
# pwc =  11.874584
# Country....  Japan
# Population ->  108531770.0
# pwc =  3.6707788
# Country....  Kazakhstan
# Population ->  20155218.0
# pwc =  2.4496346
# Country....  Kenya
# Population ->  78194040.0
# pwc =  4.859067
# Country....  Kyrgyzstan
# Population ->  6335187.0
# pwc =  2.903265
# Country....  Cambodia
# Population ->  17551128.0
# pwc =  11.714201
# Country....  Kiribati
# Population ->  113375.414
# pwc =  nan
# Country....  Republic of Korea
# Population ->  46228788.0
# pwc =  9.400201
# Country....  Kuwait
# Population ->  5871702.0
# pwc =  12.507255
# Country....  Lao People's Democratic Republic
# Population ->  8461506.0
# pwc =  5.8665576
# Country....  Lebanon
# Population ->  5119278.5
# pwc =  16.041248
# Country....  Liberia
# Population ->  10896365.0
# pwc =  2.2945035
# Country....  Libya
# Population ->  9673473.0
# pwc =  4.1238384
# Country....  Saint Lucia
# Population ->  212600.7
# pwc =  0.81310606
# Country....  Sri Lanka
# Population ->  24184630.0
# pwc =  10.505316
# Country....  Lesotho
# Population ->  2662419.2
# pwc =  1.5565155
# Country....  Lithuania
# Population ->  2715172.2
# pwc =  1.8405555
# Country....  Luxembourg
# Population ->  778738.6
# pwc =  3.2039118
# Country....  Latvia
# Population ->  1837967.5
# pwc =  1.4870092
# Country....  Morocco
# Population ->  37691508.0
# pwc =  5.0377603
# Country....  Republic of Moldova
# Population ->  2197278.2
# pwc =  2.5172842
# Country....  Madagascar
# Population ->  45090172.0
# pwc =  1.8434036
# Country....  Maldives
# Population ->  451378.1
# pwc =  4.0945144
# Country....  Mexico
# Population ->  149000210.0
# pwc =  6.6293907
# Country....  The former Yugoslav Republic of Macedonia
# Population ->  2298596.2
# pwc =  2.991183
# Country....  Mali
# Population ->  35844424.0
# pwc =  4.624279
# Country....  Malta
# Population ->  443076.0
# pwc =  7.1953025
# Country....  Myanmar
# Population ->  48526104.0
# pwc =  5.320672
# Country....  Montenegro
# Population ->  563689.25
# pwc =  1.0065992
# Country....  Mongolia
# Population ->  3746047.2
# pwc =  0.85906386
# Country....  Mozambique
# Population ->  42219972.0
# pwc =  2.1072516
# Country....  Mauritania
# Population ->  6242149.0
# pwc =  1.8281844
# Country....  Mauritius
# Population ->  1467225.5
# pwc =  2.1423457
# Country....  Malawi
# Population ->  40419316.0
# pwc =  3.6985724
# Country....  Malaysia
# Population ->  42453270.0
# pwc =  32.066612
# Country....  Namibia
# Population ->  3394970.2
# pwc =  1.8553957
# Country....  Niger
# Population ->  50550210.0
# pwc =  3.378829
# Country....  Nigeria
# Population ->  371913800.0
# pwc =  7.1542854
# Country....  Nicaragua
# Population ->  7027129.5
# pwc =  2.5049992
# Country....  Netherlands
# Population ->  18528804.0
# pwc =  3.9196763
# Country....  Norway
# Population ->  7049558.0
# pwc =  0.8212001
# Country....  Nepal
# Population ->  49475228.0
# pwc =  4.503826
# Country....  New Zealand
# Population ->  5932629.0
# pwc =  1.5579342
# Country....  Oman
# Population ->  5041499.5
# pwc =  3.9142532
# Country....  Pakistan
# Population ->  297235040.0
# pwc =  12.43217
# Country....  Panama
# Population ->  5089046.5
# pwc =  4.625465
# Country....  Peru
# Population ->  33624870.0
# pwc =  6.301768
# Country....  Philippines
# Population ->  148896020.0
# pwc =  7.2714496
# Country....  Papua New Guinea
# Population ->  11494345.0
# pwc =  0.61464053
# Country....  Poland
# Population ->  35216320.0
# pwc =  2.6560986
# Country....  Puerto Rico
# Population ->  2968537.5
# pwc =  6.7447934
# Country....  Democratic People's Republic of Korea
# Population ->  24648276.0
# pwc =  2.879479
# Country....  Portugal
# Population ->  11310766.0
# pwc =  2.7528772
# Country....  Paraguay
# Population ->  9684122.0
# pwc =  7.8678823
# Country....  State of Palestine
# Population ->  6216437.5
# pwc =  8.277141
# Country....  Qatar
# Population ->  3778571.0
# pwc =  12.480459
# Country....  Romania
# Population ->  17559112.0
# pwc =  2.8223133
# Country....  Russian Federation
# Population ->  136708420.0
# pwc =  2.9770672
# Country....  Rwanda
# Population ->  22958144.0
# pwc =  6.0834646
# Country....  Saudi Arabia
# Population ->  54235172.0
# pwc =  1.7865442
# Country....  Sudan
# Population ->  65859536.0
# pwc =  2.7284412
# Country....  Senegal
# Population ->  23998222.0
# pwc =  6.563108
# Country....  Singapore
# Population ->  6722587.5
# pwc =  81.51747
# Country....  Solomon Islands
# Population ->  932247.4
# pwc =  0.13566855
# Country....  Sierra Leone
# Population ->  11274036.0
# pwc =  3.4321306
# Country....  El Salvador
# Population ->  6201797.0
# pwc =  9.506294
# Country....  Somalia
# Population ->  16131355.0
# pwc =  1.5631695
# Country....  Serbia
# Population ->  7669823.0
# pwc =  1.7863799
# Country....  South Sudan
# Population ->  15747296.0
# pwc =  3.475406
# Country....  Sao Tome and Principe
# Population ->  207235.4
# pwc =  1.1533039
# Country....  Suriname
# Population ->  661254.25
# pwc =  4.908399
# Country....  Slovakia
# Population ->  5539414.5
# pwc =  2.3961327
# Country....  Slovenia
# Population ->  2212949.0
# pwc =  2.0659006
# Country....  Sweden
# Population ->  12498127.0
# pwc =  1.1478313
# Country....  Seychelles
# Population ->  99595.2
# pwc =  nan
# Country....  Syrian Arab Republic
# Population ->  33294062.0
# pwc =  4.421185
# Country....  Chad
# Population ->  25131790.0
# pwc =  2.2604327
# Country....  Togo
# Population ->  10168086.0
# pwc =  5.7892094
# Country....  Thailand
# Population ->  73688000.0
# pwc =  12.197714
# Country....  Tajikistan
# Population ->  8270009.5
# pwc =  4.607003
# Country....  Turkmenistan
# Population ->  6390211.5
# pwc =  3.579608
# Country....  Timor-Leste
# Population ->  2002030.6
# pwc =  2.7988613
# Country....  Tonga
# Population ->  102639.72
# pwc =  nan
# Country....  Trinidad and Tobago
# Population ->  1239042.5
# pwc =  2.6083431
# Country....  Tunisia
# Population ->  12748625.0
# pwc =  5.519613
# Country....  Turkey
# Population ->  95869650.0
# pwc =  2.728174
# Country....  Taiwan
# Population ->  21260308.0
# pwc =  6.9382467
# Country....  United Republic of Tanzania
# Population ->  102119080.0
# pwc =  2.5700364
# Country....  Uganda
# Population ->  92730150.0
# pwc =  5.0625525
# Country....  Ukraine
# Population ->  38902750.0
# pwc =  3.128334
# Country....  Uruguay
# Population ->  3327044.0
# pwc =  3.3127697
# Country....  United States of America
# Population ->  401977250.0
# pwc =  5.012215
# Country....  Uzbekistan
# Population ->  33526986.0
# pwc =  5.61953
# Country....  Saint Vincent and the Grenadines
# Population ->  95967.55
# pwc =  0.9743877
# Country....  Venezuela (Bolivarian Republic of)
# Population ->  41608360.0
# pwc =  10.35451
# Country....  United States Virgin Islands
# Population ->  115740.0
# pwc =  4.728599
# Country....  Viet Nam
# Population ->  104221550.0
# pwc =  15.156871
# Country....  Vanuatu
# Population ->  424158.28
# pwc =  0.03554193
# Country....  Western Samoa
# Population ->  166094.94
# pwc =  nan
# Country....  Yemen
# Population ->  56907950.0
# pwc =  2.680515
# Country....  South Africa
# Population ->  63106100.0
# pwc =  4.732327
# Country....  Zambia
# Population ->  30011614.0
# pwc =  2.4486654
# Country....  Zimbabwe
# Population ->  13274143.0
# pwc =  3.2928538

# %%
mid=np.log(1-0.26)/-10
low=np.log(1-0.10)/-10
high=np.log(1-0.37)/-10

@njit
def get_rr_array(conc_array,beta=low):
    a=conc_array.shape[0]
    b=conc_array.shape[1]
    rr_array=np.zeros((a,b),dtype=np.float32)
    for i in range(a):
        for j in range(b):
            if conc_array[i,j]>5:
                rr_array[i,j]=(1-np.exp(-beta*conc_array[i,j]))
    
    return rr_array


@njit
def estimate_impact(rr_array,population_array,proportion,incidence):

    a=rr_array.shape[0]
    b=rr_array.shape[1]
    results=0
    population=0
    for i in range(a):
        for j in range(b):
            results=results+(proportion*incidence*population_array[i,j]*rr_array[i,j])/100000
            population+=population_array[i,j]*proportion
    return results,population

################
################

def get_nox_array(year=2015,scenario="CLE"):
    noxfolder="/media/gaia/Seagate Expansion Drive/Liliana/fon/Downscaling/averaged_susan"

    if year!=2015:
        filename=[x for x in os.listdir(noxfolder) if (str(year) in x)&(scenario in x)][0]
    else:
        filename=[x for x in os.listdir(noxfolder) if (str(year) in x)][0]
    conc_array=gdal.Open(os.path.join(noxfolder,filename)).ReadAsArray()

    return conc_array

scenarios=["CLE","MFR","CLE","MFR"]
years=[2030,2030,2050,2050]
#scenarios=[""]
#years=[2010]

results=pd.DataFrame()
for i in range(len(years)):
    year=years[i]
    print(year)
    scenario=scenarios[i]
    print(scenario)
    conc_array=get_nox_array(year=year,scenario=scenario)
    rr_array=get_rr_array(conc_array)
    conc_array=None

    for country in countries:


        try:
            print("Country.... ",country)
            population=get_population(country,year=year)
            
            print("Population -> ",np.sum(population))
            proportions=get_proportions(country,year)
            print("Proportions -> ",proportions)
            incidence=get_incidence(country,2015)[0] #Only using the mid value!
            print("Incidence -> ",incidence)
            total=0
            children=0
            
            for agegroup in range(len(proportions)):
                tot,popul=estimate_impact(rr_array,population,proportions[agegroup],incidence[agegroup])    
                children+=popul
                total+=tot
            
            
            print("Number of cases caused ",total)
            print("Number of cases inc/100.000 ",(100000)*total/children)
            print("Population under up until 18y ",children)
            results=results.append({"country":country,"year":year,"scenario":scenario,"1-18 population":children,"NO2cases":total,"NO2incidence":100000*total/children},ignore_index=True)
        except:
            results=results.append({"country":country,"year":"","scenario":"","1-18 population":"","NO2cases":"","NO2incidence":""},ignore_index=True)
    rr_array=None
# Out:
# 2030
# CLE
# Country....  Afghanistan
# Population ->  51569350.0
# Proportions ->  [0.10746793 0.12466025 0.11334642 0.08624862]
# Incidence ->  [4223.44324934  844.74810127  892.58200632  692.90914554]
# Number of cases caused  22308.98788443644
# Number of cases inc/100.000  100.20332366597198
# Population under up until 18y  22263720.47179144
# Country....  Angola
# Population ->  31810306.0
# Proportions ->  [0.13927968 0.14748716 0.12396052 0.08802416]
# Incidence ->  [5202.28048147  996.18319478  821.07295254  662.20950265]
# Number of cases caused  5047.962135020351
# Number of cases inc/100.000  31.81732737708284
# Population under up until 18y  15865449.901540948
# Country....  Albania
# Population ->  3275444.0
# Proportions ->  [0.04730721 0.06179645 0.05664783 0.04546151]
# Incidence ->  [1365.84146615  564.81771483  538.08038319  480.28921014]
# Number of cases caused  37.614362068766404
# Number of cases inc/100.000  5.437044540075806
# Population under up until 18y  691816.3313085893
# Country....  United Arab Emirates
# Population ->  13130389.0
# Proportions ->  [0.04700844 0.05529043 0.04740867 0.04126611]
# Incidence ->  [5865.96826551  972.74197798  988.41550107  777.6517882 ]
# Number of cases caused  4987.77921651006
# Number of cases inc/100.000  198.909901924029
# Population under up until 18y  2507557.023689588
# Country....  Argentina
# Population ->  46156050.0
# Proportions ->  [0.06937435 0.08207756 0.07434762 0.05903317]
# Incidence ->  [2920.26056665  749.00266072  528.04435297  374.20578422]
# Number of cases caused  13074.034218975545
# Number of cases inc/100.000  99.44709442450578
# Population under up until 18y  13146723.1844572
# Country....  Armenia
# Population ->  2971908.0
# Proportions ->  [0.05132758 0.06766175 0.06720251 0.05548488]
# Incidence ->  [1717.37822269  690.70625733  587.330211    453.49839447]
# Number of cases caused  663.933723099884
# Number of cases inc/100.000  92.4388797849185
# Population under up until 18y  718240.7712476471
# Country....  Antigua and Barbuda
# Population ->  104914.68
# Proportions ->  [0.06142881 0.07441648 0.06845532 0.05382391]
# Incidence ->  [8519.84846897 1465.36226945 1708.01306764 1284.019911  ]
# Number of cases caused  19.56487041321537
# Number of cases inc/100.000  72.24560762068549
# Population under up until 18y  27081.05178648054
# Country....  Australia
# Population ->  29546142.0
# Proportions ->  [0.05528113 0.0673511  0.06276135 0.04983706]
# Incidence ->  [4827.00751133  868.83302892  696.35177051  528.87192122]
# Number of cases caused  5246.178510476144
# Number of cases inc/100.000  75.48297392922363
# Population under up until 18y  6950148.142540338
# Country....  Austria
# Population ->  8906304.0
# Proportions ->  [0.04685197 0.05642312 0.04859582 0.03715258]
# Incidence ->  [1609.28581331  466.1556422   562.24350335  409.94552607]
# Number of cases caused  187.25741326999918
# Number of cases inc/100.000  11.123099327905777
# Population under up until 18y  1683500.3244123275
# Country....  Azerbaijan
# Population ->  10601552.0
# Proportions ->  [0.05622704 0.07214104 0.0749359  0.06257984]
# Incidence ->  [1703.49762338  687.41391663  589.22065697  452.56286881]
# Number of cases caused  2760.5436438633556
# Number of cases inc/100.000  97.93394753536349
# Population under up until 18y  2818781.1411017985
# Country....  Burundi
# Population ->  13138348.0
# Proportions ->  [0.12927177 0.14292894 0.12380871 0.08833264]
# Incidence ->  [3486.59206313  951.54805159  893.26748954  632.29619686]
# Number of cases caused  3454.82736157111
# Number of cases inc/100.000  54.291684372821635
# Population under up until 18y  6363455.843157803
# Country....  Belgium
# Population ->  11877237.0
# Proportions ->  [0.04935997 0.0597047  0.05397378 0.04535606]
# Incidence ->  [1509.16135284  446.86620478  537.44243164  393.05140359]
# Number of cases caused  1319.314817633171
# Number of cases inc/100.000  53.302398262570605
# Population under up until 18y  2475150.951246419
# Country....  Benin
# Population ->  14119145.0
# Proportions ->  [0.12459316 0.13473336 0.11511976 0.0827893 ]
# Incidence ->  [2464.82273686  935.89179312  704.58829379  506.24661196]
# Number of cases caused  4644.229756914847
# Number of cases inc/100.000  71.93912750385766
# Population under up until 18y  6455777.1522400025
# Country....  Burkina Faso
# Population ->  27219980.0
# Proportions ->  [0.12958539 0.14042973 0.12052667 0.08640919]
# Incidence ->  [2955.8606813  1012.17724736  746.11715769  527.63055326]
# Number of cases caused  8717.30417390601
# Number of cases inc/100.000  67.14604383659392
# Population under up until 18y  12982602.809959099
# Country....  Bangladesh
# Population ->  181337010.0
# Proportions ->  [0.06890166 0.08446772 0.07736699 0.06250999]
# Incidence ->  [884.35902305 419.23924906 282.94525021 226.89351557]
# Number of cases caused  24935.517777202393
# Number of cases inc/100.000  46.89205840935254
# Population under up until 18y  53176419.68182195
# Country....  Bulgaria
# Population ->  6820245.0
# Proportions ->  [0.04180307 0.05141987 0.04760677 0.04077689]
# Incidence ->  [1664.70517067  642.07596822  597.44769403  544.00300689]
# Number of cases caused  175.882074064971
# Number of cases inc/100.000  14.200053194623933
# Population under up until 18y  1238601.5154616395
# Country....  Bahrain
# Population ->  2317281.8
# Proportions ->  [0.05318291 0.06137879 0.05308041 0.04312684]
# Incidence ->  [4286.56678239  833.53432038  798.48436101  629.30126133]
# Number of cases caused  1166.9590177734162
# Number of cases inc/100.000  238.92973368370286
# Population under up until 18y  488410.964923372
# Country....  Bahamas
# Population ->  421744.8
# Proportions ->  [0.06201363 0.07188372 0.06228672 0.04966653]
# Incidence ->  [8786.638389   1485.01880084 1740.94560712 1320.92474037]
# Number of cases caused  178.9167178619842
# Number of cases inc/100.000  172.5561533724655
# Population under up until 18y  103686.08384297333
# Country....  Bosnia and Herzegovina
# Population ->  3628331.8
# Proportions ->  [0.03800536 0.04540312 0.04169236 0.04052541]
# Incidence ->  [2072.97340616  736.05136356  675.75881022  628.16823053]
# Number of cases caused  9.152677165920796
# Number of cases inc/100.000  1.5230420321835367
# Population under up until 18y  600947.1158717067
# Country....  Belarus
# Population ->  8850704.0
# Proportions ->  [0.04731439 0.0620756  0.05805467 0.05056537]
# Incidence ->  [2103.56647902  815.4299687   709.63112781  556.06659608]
# Number of cases caused  698.8636015148952
# Number of cases inc/100.000  36.219146506773804
# Population under up until 18y  1929541.8830043164
# Country....  Belize
# Population ->  389663.4
# Proportions ->  [0.08004918 0.09434992 0.08243923 0.06523624]
# Incidence ->  [8772.42548297 1481.56876161 1769.16819604 1337.72633225]
# Number of cases caused  27.578095435494685
# Number of cases inc/100.000  21.974458198245124
# Population under up until 18y  125500.684415951
# Country....  Bolivia (Plurinational State of)
# Population ->  12577440.0
# Proportions ->  [0.08309042 0.09630303 0.08574636 0.06832205]
# Incidence ->  [8345.0721996  1544.55972741 1499.25825235  950.8346257 ]
# Number of cases caused  1617.8627664101134
# Number of cases inc/100.000  38.574812445724326
# Population under up until 18y  4194091.076104348
# Country....  Brazil
# Population ->  220909840.0
# Proportions ->  [0.05576931 0.06844814 0.06302498 0.05082205]
# Incidence ->  [6610.2695386  1637.80835204 1385.49367046  770.28625728]
# Number of cases caused  98713.025219792
# Number of cases inc/100.000  187.7002566938132
# Population under up until 18y  52590777.95552407
# Country....  Barbados
# Population ->  278090.28
# Proportions ->  [0.05035804 0.05853933 0.05099253 0.04172307]
# Incidence ->  [7892.08010258 1404.75241103 1642.50304996 1232.23422335]
# Number of cases caused  110.40746539586148
# Number of cases inc/100.000  196.92196635657996
# Population under up until 18y  56066.60721432122
# Country....  Brunei Darussalam
# Population ->  525387.1
# Proportions ->  [0.05691677 0.06993577 0.06555791 0.05741829]
# Incidence ->  [2422.02895285  607.89483277  490.89104985  381.95746716]
# Number of cases caused  54.539375963263375
# Number of cases inc/100.000  41.55166353042477
# Population under up until 18y  131256.78090680725
# Country....  Bhutan
# Population ->  1122573.4
# Proportions ->  [0.06412842 0.07986758 0.07341815 0.05671146]
# Incidence ->  [1164.14018658  467.60026677  306.12903201  254.68319233]
# Number of cases caused  11.092829184706034
# Number of cases inc/100.000  3.6047733621589253
# Population under up until 18y  307726.1195156651
# Country....  Botswana
# Population ->  2392943.2
# Proportions ->  [0.08700255 0.10203854 0.09519824 0.07524852]
# Incidence ->  [1852.95345246  943.74873621  856.41059823  565.18114631]
# Number of cases caused  69.30174209310717
# Number of cases inc/100.000  8.056153363925919
# Population under up until 18y  860233.6495160154
# Country....  Central African Republic
# Population ->  6087641.0
# Proportions ->  [0.12508157 0.13516997 0.11590838 0.08915362]
# Incidence ->  [4431.00294042  899.08642379  794.49476542  625.31659209]
# Number of cases caused  877.6342047996569
# Number of cases inc/100.000  30.98266427258309
# Population under up until 18y  2832662.1528681293
# Country....  Canada
# Population ->  41252284.0
# Proportions ->  [0.04884964 0.05664299 0.04913738 0.04096215]
# Incidence ->  [4792.94223062 1157.32874137  654.56474151  650.41806332]
# Number of cases caused  7875.178709157039
# Number of cases inc/100.000  97.60245889920597
# Population under up until 18y  8068627.366539744
# Country....  Switzerland
# Population ->  8473224.0
# Proportions ->  [0.04771341 0.05663741 0.04923396 0.03920918]
# Incidence ->  [1773.51825613  502.2287876   622.90737326  448.76203092]
# Number of cases caused  500.9903700250371
# Number of cases inc/100.000  30.668131823741746
# Population under up until 18y  1633586.2024604813
# Country....  Chile
# Population ->  19636982.0
# Proportions ->  [0.05244212 0.06395921 0.05765997 0.05018006]
# Incidence ->  [2980.01626486  758.62331449  525.86259835  374.56589444]
# Number of cases caused  8848.099359157322
# Number of cases inc/100.000  200.93744391326808
# Population under up until 18y  4403409.930394299
# Country....  China
# Population ->  1380762000.0
# Proportions ->  [0.04696589 0.05856376 0.05604806 0.04627707]
# Incidence ->  [2567.99337872  628.34529056  452.94356034  330.60109817]
# Number of cases caused  305364.2044851438
# Number of cases inc/100.000  106.39950624736971
# Population under up until 18y  286997764.60916865
# Country....  Côte d'Ivoire
# Population ->  26194698.0
# Proportions ->  [0.1247283  0.13624845 0.11645412 0.08256518]
# Incidence ->  [2718.37511848  988.22347709  739.7225263   547.4232516 ]
# Number of cases caused  7565.974419066123
# Number of cases inc/100.000  62.79096679355765
# Population under up until 18y  12049463.171894323
# Country....  Cameroon
# Population ->  27296116.0
# Proportions ->  [0.12072835 0.13293843 0.11579971 0.08490655]
# Incidence ->  [2404.58893021  923.52572359  703.3767851   508.50416169]
# Number of cases caused  5920.375261087832
# Number of cases inc/100.000  47.73492666327198
# Population under up until 18y  12402606.801621137
# Country....  Democratic Republic of the Congo
# Population ->  107298650.0
# Proportions ->  [0.13532696 0.14524779 0.12420595 0.08739003]
# Incidence ->  [3656.15838467  846.46341347  708.14374318  540.57544809]
# Number of cases caused  17495.52119710855
# Number of cases inc/100.000  33.129657099564575
# Population under up until 18y  52809243.22436918
# Country....  Congo
# Population ->  6317289.0
# Proportions ->  [0.11893307 0.12952708 0.11294564 0.08502371]
# Incidence ->  [5327.46054493 1068.14986906  861.08529778  688.81288057]
# Number of cases caused  1139.0962007061128
# Number of cases inc/100.000  40.3902731081689
# Population under up until 18y  2820224.061509828
# Country....  Colombia
# Population ->  57311930.0
# Proportions ->  [0.05908948 0.07255809 0.06692681 0.05329341]
# Incidence ->  [3963.35466965 1074.27667551 1283.16492641  839.88237748]
# Number of cases caused  15507.843736804773
# Number of cases inc/100.000  107.43204141380583
# Population under up until 18y  14435026.583058018
# Country....  Comoros
# Population ->  1018113.06
# Proportions ->  [0.10987672 0.12377272 0.10946568 0.081491  ]
# Incidence ->  [3827.17676098 1067.30515975  947.51264415  676.29818655]
# Number of cases caused  13.5035457180144
# Number of cases inc/100.000  3.123672549067779
# Population under up until 18y  432297.09599504486
# Country....  Cape Verde
# Population ->  545873.75
# Proportions ->  [0.07070109 0.08721612 0.08191424 0.06478116]
# Incidence ->  [2562.62022206  952.02946809  721.75701219  508.71820093]
# Number of cases caused  22.173588728732156
# Number of cases inc/100.000  13.335089953326715
# Population under up until 18y  166280.00865641324
# Country....  Costa Rica
# Population ->  5916929.0
# Proportions ->  [0.05470352 0.06731258 0.06237598 0.0514708 ]
# Incidence ->  [5456.35051101 1287.76978677 1594.30624964 1072.17778223]
# Number of cases caused  2276.5305707389684
# Number of cases inc/100.000  163.12386078951897
# Population under up until 18y  1395584.0425309748
# Country....  Cuba
# Population ->  10656096.0
# Proportions ->  [0.04349369 0.05356775 0.05004924 0.04385117]
# Incidence ->  [9017.58003509 1493.946774   1732.63901702 1309.71740167]
# Number of cases caused  3105.7980371799536
# Number of cases inc/100.000  152.62590123945998
# Population under up until 18y  2034908.8928930622
# Country....  Cyprus
# Population ->  1363787.4
# Proportions ->  [0.04471665 0.05452815 0.05149966 0.04519064]
# Incidence ->  [1557.51865209  448.63524366  596.99096783  434.64602715]
# Number of cases caused  199.29977370136123
# Number of cases inc/100.000  74.58440014950624
# Population under up until 18y  267213.7515376674
# Country....  Czech Republic
# Population ->  11271592.0
# Proportions ->  [0.04440222 0.05531825 0.05174378 0.04126628]
# Incidence ->  [1549.95586906  608.82728072  586.14565188  525.41323009]
# Number of cases caused  285.6173768877487
# Number of cases inc/100.000  13.147676492340194
# Population under up until 18y  2172379.1048110193
# Country....  Germany
# Population ->  81352080.0
# Proportions ->  [0.0448091  0.05398672 0.0484902  0.03670631]
# Incidence ->  [1249.46632877  408.05825074  532.82921341  384.67010121]
# Number of cases caused  2454.9812303343715
# Number of cases inc/100.000  16.40136305892563
# Population under up until 18y  14968153.692557704
# Country....  Djibouti
# Population ->  1167196.8
# Proportions ->  [0.0756622  0.09174459 0.08549411 0.06825096]
# Incidence ->  [3507.23499616  994.65483094  903.7639726   633.39279886]
# Number of cases caused  165.4572994219864
# Number of cases inc/100.000  44.13991898300255
# Population under up until 18y  374847.31108296977
# Country....  Denmark
# Population ->  6078603.0
# Proportions ->  [0.05418351 0.06147491 0.05145416 0.04055176]
# Incidence ->  [2026.4992462   592.03716683  772.41728459  569.75423112]
# Number of cases caused  4.877143364502897
# Number of cases inc/100.000  0.3863668866492997
# Population under up until 18y  1262308.839869556
# Country....  Dominican Republic
# Population ->  11993334.0
# Proportions ->  [0.07285086 0.08859811 0.08225818 0.06462113]
# Incidence ->  [6578.62111238 1262.813628   1474.02155562 1087.76034427]
# Number of cases caused  6812.995391347836
# Number of cases inc/100.000  184.24035438643864
# Population under up until 18y  3697884.4369012564
# Country....  Algeria
# Population ->  44396916.0
# Proportions ->  [0.07443879 0.09666859 0.09754799 0.07179744]
# Incidence ->  [4620.56023004  868.78578763  833.80122579  661.64324552]
# Number of cases caused  14095.4650340244
# Number of cases inc/100.000  93.25441749892909
# Population under up until 18y  15115064.156811949
# Country....  Ecuador
# Population ->  17978846.0
# Proportions ->  [0.0755151  0.09016922 0.08160021 0.06303864]
# Incidence ->  [6670.80037914 1418.47562203 1302.41531214  799.41719093]
# Number of cases caused  5876.074997607011
# Number of cases inc/100.000  105.32011759833641
# Population under up until 18y  5579252.21847628
# Country....  Egypt
# Population ->  106585930.0
# Proportions ->  [0.09165423 0.10854666 0.1022324  0.07949681]
# Incidence ->  [5294.93914091  904.92024707  886.29867212  699.70145263]
# Number of cases caused  174805.66205270565
# Number of cases inc/100.000  429.40962772830045
# Population under up until 18y  40708370.46143504
# Country....  Eritrea
# Population ->  8419884.0
# Proportions ->  [0.1092058  0.12233231 0.1124911  0.08612523]
# Incidence ->  [3337.0286699   926.95194618  879.48175597  628.73660406]
# Number of cases caused  637.5511726926318
# Number of cases inc/100.000  17.60291542941203
# Population under up until 18y  3621849.8875894854
# Country....  Spain
# Population ->  50226230.0
# Proportions ->  [0.03797803 0.04636679 0.04256002 0.038439  ]
# Incidence ->  [1403.57279574  407.39957631  490.22180952  360.23148005]
# Number of cases caused  1538.5018693251404
# Number of cases inc/100.000  18.525896685500868
# Population under up until 18y  8304601.366633095
# Country....  Estonia
# Population ->  1295291.1
# Proportions ->  [0.04463933 0.05713425 0.05281227 0.04522152]
# Incidence ->  [1356.40357758  646.57821042  558.37374378  398.23971536]
# Number of cases caused  17.019158866902885
# Number of cases inc/100.000  6.575960097370033
# Population under up until 18y  258808.7308149797
# Country....  Ethiopia
# Population ->  124165280.0
# Proportions ->  [0.11145682 0.12695313 0.11117265 0.08115208]
# Incidence ->  [3021.02598492  969.96093407  876.8042713   585.30048935]
# Number of cases caused  15121.401022364464
# Number of cases inc/100.000  28.273638547927796
# Population under up until 18y  53482331.241985574
# Country....  Finland
# Population ->  5818852.0
# Proportions ->  [0.04345851 0.05120012 0.04784294 0.04400277]
# Incidence ->  [1783.60069591  505.56018052  643.68616316  451.62137221]
# Number of cases caused  37.30868051409658
# Number of cases inc/100.000  3.4378249031471357
# Population under up until 18y  1085240.85912411
# Country....  Fiji
# Population ->  959424.9
# Proportions ->  [0.07979    0.09582376 0.08923237 0.06949402]
# Incidence ->  [8072.65002489 1254.09680446 1048.33848602 1009.75714521]
# Number of cases caused  0.0
# Number of cases inc/100.000  0.0
# Population under up until 18y  320774.28206086543
# Country....  France
# Population ->  70312770.0
# Proportions ->  [0.05032204 0.05982271 0.0546303  0.04673704]
# Incidence ->  [1721.49960064  462.76042267  722.31361197  523.39123165]
# Number of cases caused  4421.961620929517
# Number of cases inc/100.000  29.733453425813845
# Population under up until 18y  14872008.164011247
# Country....  Micronesia (Federated States of)
# Population ->  111568.516
# Proportions ->  [0.09007509 0.10514671 0.0926654  0.06980896]
# Incidence ->  [8251.51016041 1297.84909013 1041.05657861 1006.2695096 ]
# Number of cases caused  0.0
# Number of cases inc/100.000  0.0
# Population under up until 18y  39907.62523027928
# Country....  Gabon
# Population ->  1982088.0
# Proportions ->  [0.10280812 0.12135643 0.11269441 0.07907373]
# Incidence ->  [5030.98530595 1056.35550679  847.74766423  687.14943288]
# Number of cases caused  1124.6228514148352
# Number of cases inc/100.000  136.41455754083532
# Population under up until 18y  824415.5694880163
# Country....  United Kingdom of Great Britain and Northern Ireland
# Population ->  69232220.0
# Proportions ->  [0.05184564 0.06208835 0.05504711 0.04690251]
# Incidence ->  [2851.71685061  729.82455506 1005.88943903  643.37910707]
# Number of cases caused  3048.971078487782
# Number of cases inc/100.000  20.399768719939054
# Population under up until 18y  14946106.107113212
# Country....  Georgia
# Population ->  3871044.0
# Proportions ->  [0.05335567 0.06758044 0.06740271 0.0569893 ]
# Incidence ->  [1659.25568777  722.8583094   665.4231804   450.41706715]
# Number of cases caused  638.3324600948177
# Number of cases inc/100.000  67.21581442819772
# Population under up until 18y  949676.0033707644
# Country....  Ghana
# Population ->  36048332.0
# Proportions ->  [0.10531433 0.11923608 0.10554422 0.07914561]
# Incidence ->  [2005.89015959  804.60090232  627.23165213  442.65954258]
# Number of cases caused  9021.799378568998
# Number of cases inc/100.000  61.15468571691205
# Population under up until 18y  14752425.382956486
# Country....  Guinea
# Population ->  13446847.0
# Proportions ->  [0.12486724 0.13694641 0.11718164 0.08423602]
# Incidence ->  [3015.94941212 1036.32051719  761.2741892   562.8457303 ]
# Number of cases caused  1647.2847376310945
# Number of cases inc/100.000  26.445403425501272
# Population under up until 18y  6229002.110977894
# Country....  Gambia
# Population ->  2555412.8
# Proportions ->  [0.12886168 0.14134906 0.12120627 0.08575804]
# Incidence ->  [2367.92672272  921.48608516  701.15461539  489.61100234]
# Number of cases caused  1258.0042288115997
# Number of cases inc/100.000  103.16759825284981
# Population under up until 18y  1219379.1947432968
# Country....  Guinea-Bissau
# Population ->  2121141.5
# Proportions ->  [0.11804959 0.13234432 0.11714336 0.08602303]
# Incidence ->  [2395.78453118  909.41047715  693.42361413  515.27252311]
# Number of cases caused  363.15401837795815
# Number of cases inc/100.000  37.74732419727005
# Population under up until 18y  962065.5929943294
# Country....  Equatorial Guinea
# Population ->  1105595.1
# Proportions ->  [0.11250879 0.12198733 0.10232103 0.0752326 ]
# Incidence ->  [4958.16796325 1032.44220758  829.12963444  662.76277977]
# Number of cases caused  82.97637970216039
# Number of cases inc/100.000  18.21413465640641
# Population under up until 18y  455560.37257567607
# Country....  Greece
# Population ->  11379352.0
# Proportions ->  [0.03466769 0.04214689 0.04040587 0.03738563]
# Incidence ->  [1547.86135527  455.98753423  584.48797762  418.79646231]
# Number of cases caused  796.4021760550862
# Number of cases inc/100.000  45.267705035310236
# Population under up until 18y  1759316.4385821358
# Country....  Grenada
# Population ->  121295.2
# Proportions ->  [0.06163198 0.07925197 0.07542741 0.06042974]
# Incidence ->  [7483.9315992  1326.37969855 1883.50824379 1384.66629908]
# Number of cases caused  5.818789149346086
# Number of cases inc/100.000  17.334659432809392
# Population under up until 18y  33567.3693036786
# Country....  Guatemala
# Population ->  20315920.0
# Proportions ->  [0.09029499 0.1055659  0.09412514 0.07213393]
# Incidence ->  [3437.85001902  948.07137279 1162.45092457  762.78109561]
# Number of cases caused  8381.46696580712
# Number of cases inc/100.000  113.92813105891294
# Population under up until 18y  7356801.948653938
# Country....  Guam
# Population ->  219413.16
# Proportions ->  [0.06901244 0.08075752 0.07056225 0.05594004]
# Incidence ->  [8754.93549277 1334.19015944 1065.24233408 1054.90844778]
# Number of cases caused  0.0
# Number of cases inc/100.000  0.0
# Population under up until 18y  60617.771868655684
# Country....  Guyana
# Population ->  779836.3
# Proportions ->  [0.07613044 0.09280513 0.08567194 0.06686609]
# Incidence ->  [7958.83033558 1441.62323198 1716.84374081 1284.63671798]
# Number of cases caused  16.40541186382279
# Number of cases inc/100.000  6.543921452776554
# Population under up until 18y  250696.9556742166
# Country....  Honduras
# Population ->  10016948.0
# Proportions ->  [0.08193632 0.09652303 0.08578768 0.06672134]
# Incidence ->  [5626.54451501 1182.12980005 1479.92184759 1010.21175097]
# Number of cases caused  4071.861449074816
# Number of cases inc/100.000  122.82060610217994
# Population under up until 18y  3315291.772528181
# Country....  Croatia
# Population ->  4220629.0
# Proportions ->  [0.04070741 0.04979205 0.04638557 0.04059039]
# Incidence ->  [1884.70082996  691.10586673  647.3046298   591.68074452]
# Number of cases caused  20.318244029211336
# Number of cases inc/100.000  2.7125073948408316
# Population under up until 18y  749057.6456254637
# Country....  Haiti
# Population ->  11822517.0
# Proportions ->  [0.0867341  0.10212952 0.09354795 0.07331826]
# Incidence ->  [8743.08009499 1261.21052223 1690.36388514 1270.03198867]
# Number of cases caused  8766.027012195742
# Number of cases inc/100.000  208.43586607896916
# Population under up until 18y  4205623.138234087
# Country....  Hungary
# Population ->  9527543.0
# Proportions ->  [0.04511023 0.05437624 0.04855769 0.03789433]
# Incidence ->  [1570.5251308   616.38052639  583.01026155  525.64345482]
# Number of cases caused  328.99012132336696
# Number of cases inc/100.000  18.57088935271386
# Population under up until 18y  1771536.7049736362
# Country....  Indonesia
# Population ->  276454340.0
# Proportions ->  [0.07050913 0.08368309 0.07676377 0.06303751]
# Incidence ->  [4804.41145853  924.05385926  894.90252265  749.97355105]
# Number of cases caused  322924.15767343604
# Number of cases inc/100.000  397.3190530613791
# Population under up until 18y  81275779.54927565
# Country....  India
# Population ->  1520157800.0
# Proportions ->  [0.07118213 0.08376281 0.07506293 0.06072039]
# Incidence ->  [915.81910684 461.24025972 227.71503466 184.59503093]
# Number of cases caused  219994.0216716958
# Number of cases inc/100.000  49.77768109804836
# Population under up until 18y  441953134.0529263
# Country....  Ireland
# Population ->  5493274.0
# Proportions ->  [0.04971695 0.06124292 0.05923562 0.05420204]
# Incidence ->  [2334.71067125  603.25666429  791.07778298  541.16023597]
# Number of cases caused  17.606111154396764
# Number of cases inc/100.000  1.428282507163884
# Population under up until 18y  1232677.0835663958
# Country....  Iran (Islamic Republic of)
# Population ->  88126200.0
# Proportions ->  [0.06369048 0.0822469  0.08035899 0.05817425]
# Incidence ->  [3239.36268903  764.92801253  771.55108316  586.19619273]
# Number of cases caused  48097.110068587994
# Number of cases inc/100.000  191.85672940384404
# Population under up until 18y  25069284.886717305
# Country....  Iraq
# Population ->  49970390.0
# Proportions ->  [0.10597237 0.11922294 0.1039194  0.08075974]
# Incidence ->  [4509.79140828  856.23018721  820.03329324  649.25403943]
# Number of cases caused  35331.58695870704
# Number of cases inc/100.000  172.50401646399374
# Population under up until 18y  20481602.50580699
# Country....  Iceland
# Population ->  411115.56
# Proportions ->  [0.05268441 0.06259855 0.05586131 0.04980216]
# Incidence ->  [2526.76084671  630.8677243   808.62913873  570.26642178]
# Number of cases caused  0.0
# Number of cases inc/100.000  0.0
# Population under up until 18y  90834.5267284666
# Country....  Israel
# Population ->  10896391.0
# Proportions ->  [0.07797251 0.09095922 0.08359159 0.06502045]
# Incidence ->  [1644.01404596  473.76321146  583.40796401  426.54991525]
# Number of cases caused  3622.0256534478244
# Number of cases inc/100.000  104.68040542847258
# Population under up until 18y  3460079.886605646
# Country....  Italy
# Population ->  61975372.0
# Proportions ->  [0.036128   0.04257482 0.03929216 0.03612836]
# Incidence ->  [1181.2424268   402.1753698   631.82697329  430.15838148]
# Number of cases caused  2241.2490803094506
# Number of cases inc/100.000  23.46401252727361
# Population under up until 18y  9551857.670141943
# Country....  Jamaica
# Population ->  2876547.5
# Proportions ->  [0.06386845 0.07898286 0.07277979 0.0578256 ]
# Incidence ->  [8481.9680196  1462.91529045 1731.37906896 1290.21807985]
# Number of cases caused  555.9074164220503
# Number of cases inc/100.000  70.67117891884669
# Population under up until 18y  786611.2111422556
# Country....  Jordan
# Population ->  9924447.0
# Proportions ->  [0.08393388 0.09668913 0.08431251 0.07447097]
# Incidence ->  [5451.08659192  937.73311097  884.68206322  710.89459946]
# Number of cases caused  9787.334132466453
# Number of cases inc/100.000  290.5616273914124
# Population under up until 18y  3368419.367806624
# Country....  Japan
# Population ->  120325620.0
# Proportions ->  [0.03550271 0.04242005 0.03899872 0.03536908]
# Incidence ->  [2426.62709375  610.65709841  481.7702135   403.44927344]
# Number of cases caused  10261.868126748132
# Number of cases inc/100.000  56.00096125767975
# Population under up until 18y  18324449.967081342
# Country....  Kazakhstan
# Population ->  18706794.0
# Proportions ->  [0.07104688 0.08863038 0.09092124 0.07377147]
# Incidence ->  [1428.50386901  616.27814197  534.13869714  405.34012707]
# Number of cases caused  1729.4310070583072
# Number of cases inc/100.000  28.501195125360404
# Population under up until 18y  6067924.518433464
# Country....  Kenya
# Population ->  60631976.0
# Proportions ->  [0.10578043 0.11799016 0.10234232 0.08128757]
# Incidence ->  [2619.42912077  915.03984093  812.69830628  552.45444708]
# Number of cases caused  11101.556330987054
# Number of cases inc/100.000  44.9428776270745
# Population under up until 18y  24701480.895605247
# Country....  Kyrgyzstan
# Population ->  6092815.0
# Proportions ->  [0.08362419 0.10235326 0.09920135 0.07987316]
# Incidence ->  [2044.33938587  778.74710579  646.17957016  501.35401674]
# Number of cases caused  725.6430618944356
# Number of cases inc/100.000  32.62498016892103
# Population under up until 18y  2224194.6451378763
# Country....  Cambodia
# Population ->  16616119.0
# Proportions ->  [0.08131708 0.09800298 0.09113358 0.07123351]
# Incidence ->  [4040.69480876  800.29799795  791.27406777  650.18922798]
# Number of cases caused  9674.957947121033
# Number of cases inc/100.000  170.40837287126706
# Population under up until 18y  5677513.248970379
# Country....  Kiribati
# Population ->  95301.5
# Proportions ->  [0.09573982 0.11422382 0.10469345 0.07835867]
# Incidence ->  [8249.35575669 1226.18196942 1097.14250693 1021.22297664]
# Number of cases caused  0.0
# Number of cases inc/100.000  0.0
# Population under up until 18y  37454.987716053285
# Country....  Republic of Korea
# Population ->  49694828.0
# Proportions ->  [0.03570255 0.04111545 0.0364446  0.03485619]
# Incidence ->  [2425.39300197  600.3698509   503.86949943  387.61016635]
# Number of cases caused  13976.886091577955
# Number of cases inc/100.000  189.88454340844837
# Population under up until 18y  7360728.704238542
# Country....  Kuwait
# Population ->  4423457.0
# Proportions ->  [0.05093637 0.05814436 0.06060786 0.05337039]
# Incidence ->  [5006.12810289  900.52754675  859.90005479  682.15066834]
# Number of cases caused  2681.392990980765
# Number of cases inc/100.000  271.7558458135506
# Population under up until 18y  986691.9267011633
# Country....  Lao People's Democratic Republic
# Population ->  7696361.5
# Proportions ->  [0.08320401 0.10017216 0.09267717 0.07138474]
# Incidence ->  [4977.17470181  774.55881692  819.8147044   710.05833856]
# Number of cases caused  2040.9709383264676
# Number of cases inc/100.000  76.3262736401207
# Population under up until 18y  2674008.360410296
# Country....  Lebanon
# Population ->  4904970.0
# Proportions ->  [0.06657196 0.08022864 0.06613761 0.0549448 ]
# Incidence ->  [5764.23921375  958.85647624  905.52653496  730.22228938]
# Number of cases caused  5155.373769565888
# Number of cases inc/100.000  392.35453679840674
# Population under up until 18y  1313957.9859668447
# Country....  Liberia
# Population ->  7469352.5
# Proportions ->  [0.11709382 0.12866849 0.11054346 0.0817051 ]
# Incidence ->  [2473.17797717  931.6517113   704.54569892  489.24230692]
# Number of cases caused  404.19571556380987
# Number of cases inc/100.000  12.35446108901815
# Population under up until 18y  3271658.0079976004
# Country....  Libya
# Population ->  8266879.0
# Proportions ->  [0.06776338 0.0838437  0.07980959 0.06758611]
# Incidence ->  [4253.06054809  828.31601364  801.94005764  630.63716246]
# Number of cases caused  1747.1253025881135
# Number of cases inc/100.000  70.68175151160507
# Population under up until 18y  2471819.479885494
# Country....  Saint Lucia
# Population ->  201732.45
# Proportions ->  [0.04962292 0.06196659 0.05575958 0.04529457]
# Incidence ->  [8346.53668645 1475.00424872 1745.08906092 1322.47694424]
# Number of cases caused  6.219674492304653
# Number of cases inc/100.000  14.49904617542046
# Population under up until 18y  42897.128659736045
# Country....  Sri Lanka
# Population ->  23432206.0
# Proportions ->  [0.06305651 0.07520068 0.07126658 0.05810377]
# Incidence ->  [4287.55906354  807.71314218  813.72188557  681.35454808]
# Number of cases caused  10232.481925397726
# Number of cases inc/100.000  163.1687225061028
# Population under up until 18y  6271105.006055933
# Country....  Lesotho
# Population ->  2519346.0
# Proportions ->  [0.09339857 0.10753165 0.09745776 0.07259179]
# Incidence ->  [1453.41008905  768.77443834  708.72885359  463.44489163]
# Number of cases caused  19.61548882623865
# Number of cases inc/100.000  2.098751082609654
# Population under up until 18y  934626.7401014572
# Country....  Lithuania
# Population ->  3051096.5
# Proportions ->  [0.04350156 0.05695264 0.05629261 0.0475803 ]
# Incidence ->  [1680.44480795  757.4428538   681.18473079  500.31962369]
# Number of cases caused  17.105241007834888
# Number of cases inc/100.000  2.743765575464807
# Population under up until 18y  623422.1013920687
# Country....  Luxembourg
# Population ->  640977.44
# Proportions ->  [0.04957485 0.05851515 0.05117595 0.04210323]
# Incidence ->  [2040.46724542  556.9579328   678.53951907  487.97678479]
# Number of cases caused  35.4077953520647
# Number of cases inc/100.000  27.43235609812391
# Population under up until 18y  129073.11069239958
# Country....  Latvia
# Population ->  2021167.0
# Proportions ->  [0.0424778  0.05691724 0.06414993 0.04136727]
# Incidence ->  [2000.4357867   841.51768248  749.49055598  554.14878431]
# Number of cases caused  1.8449340946943293
# Number of cases inc/100.000  0.44546203600231704
# Population under up until 18y  414161.9140547216
# Country....  Morocco
# Population ->  36699784.0
# Proportions ->  [0.07000653 0.08474724 0.07890394 0.06507929]
# Incidence ->  [3356.14060128  729.66841957  722.7717701   557.0892371 ]
# Number of cases caused  8357.400809670384
# Number of cases inc/100.000  76.22868930422116
# Population under up until 18y  10963589.8058234
# Country....  Republic of Moldova
# Population ->  2852623.2
# Proportions ->  [0.04305088 0.05535297 0.05080641 0.04436661]
# Incidence ->  [1765.69642305  780.46836542  702.28373934  515.82925275]
# Number of cases caused  23.121118017744884
# Number of cases inc/100.000  4.187074525336902
# Population under up until 18y  552202.2089130239
# Country....  Madagascar
# Population ->  33253620.0
# Proportions ->  [0.11892477 0.13104839 0.11109889 0.07928134]
# Incidence ->  [4096.62762985  965.3909172   988.04456782  750.45581277]
# Number of cases caused  3081.9966730556534
# Number of cases inc/100.000  21.047076182670057
# Population under up until 18y  14643348.30314026
# Country....  Maldives
# Population ->  396984.2
# Proportions ->  [0.05156274 0.06815285 0.06592791 0.0561544 ]
# Incidence ->  [4392.99738815  823.09289525  805.24155214  677.53062936]
# Number of cases caused  32.25121291191688
# Number of cases inc/100.000  33.598526843254476
# Population under up until 18y  95989.9612931747
# Country....  Mexico
# Population ->  136970750.0
# Proportions ->  [0.06856507 0.08259046 0.07562933 0.06172971]
# Incidence ->  [3244.89607948 1024.12945247 1081.34851358  711.53494096]
# Number of cases caused  63533.155758642715
# Number of cases inc/100.000  160.77005135900833
# Population under up until 18y  39518029.14883052
# Country....  The former Yugoslav Republic of Macedonia
# Population ->  2186053.2
# Proportions ->  [0.04629264 0.05750579 0.05317082 0.04393622]
# Incidence ->  [2089.87070656  734.45698208  710.70105807  638.88540454]
# Number of cases caused  121.2772702724491
# Number of cases inc/100.000  27.613855478069567
# Population under up until 18y  439189.9217722978
# Country....  Mali
# Population ->  25754680.0
# Proportions ->  [0.13870099 0.14786421 0.12571568 0.08940042]
# Incidence ->  [2049.69880612  831.18198005  647.26849635  500.72072208]
# Number of cases caused  4666.318116869254
# Number of cases inc/100.000  36.11524102983626
# Population under up until 18y  12920634.01436036
# Country....  Malta
# Population ->  444386.97
# Proportions ->  [0.04539131 0.05535627 0.04766857 0.03813835]
# Incidence ->  [1785.99147928  501.14823057  623.72430181  449.06806388]
# Number of cases caused  62.870130208381305
# Number of cases inc/100.000  75.83632834363733
# Population under up until 18y  82902.39200861326
# Country....  Myanmar
# Population ->  50970932.0
# Proportions ->  [0.07130884 0.08322425 0.07427308 0.05953668]
# Incidence ->  [4318.94654262  747.03946178  794.52955683  691.50582736]
# Number of cases caused  11594.616343160742
# Number of cases inc/100.000  78.89050452237464
# Population under up until 18y  14697100.003806312
# Country....  Montenegro
# Population ->  576325.3
# Proportions ->  [0.05206881 0.06322233 0.05762972 0.04618793]
# Incidence ->  [1814.14561583  673.67460314  631.15709888  577.40554476]
# Number of cases caused  0.6038507606463881
# Number of cases inc/100.000  0.47819189395020667
# Population under up until 18y  126277.91651969451
# Country....  Mongolia
# Population ->  3402033.2
# Proportions ->  [0.07841772 0.09822361 0.09837081 0.07591353]
# Incidence ->  [1773.26732217  704.08799866  598.03863419  460.0114319 ]
# Number of cases caused  117.437672039141
# Number of cases inc/100.000  9.836794411492182
# Population under up until 18y  1193861.2024049247
# Country....  Mozambique
# Population ->  33668230.0
# Proportions ->  [0.13015454 0.14191346 0.12038277 0.0858013 ]
# Incidence ->  [3421.93349037  984.89936117  905.57106569  648.70275181]
# Number of cases caused  3138.6174668481503
# Number of cases inc/100.000  19.492205246456518
# Population under up until 18y  16101910.621009488
# Country....  Mauritania
# Population ->  5005213.0
# Proportions ->  [0.11583351 0.12786116 0.11118108 0.08065923]
# Incidence ->  [3297.22516513 1116.24369296  812.47470993  576.39324955]
# Number of cases caused  323.3733435340114
# Number of cases inc/100.000  14.834010044333368
# Population under up until 18y  2179945.561365862
# Country....  Mauritius
# Population ->  1423854.0
# Proportions ->  [0.04833326 0.05659509 0.04902576 0.04215138]
# Incidence ->  [5302.46062933  890.23241708  880.46422455  747.33053184]
# Number of cases caused  46.56468254026682
# Number of cases inc/100.000  16.676369583889006
# Population under up until 18y  279225.53710522724
# Country....  Malawi
# Population ->  26223352.0
# Proportions ->  [0.1235975  0.13457008 0.1133823  0.08530675]
# Incidence ->  [3383.97223827  979.29048241  889.44686979  634.6696066 ]
# Number of cases caused  4726.249247549875
# Number of cases inc/100.000  39.45013920982081
# Population under up until 18y  11980310.696529333
# Country....  Malaysia
# Population ->  36488184.0
# Proportions ->  [0.06720894 0.0809452  0.07143005 0.05477313]
# Incidence ->  [4020.45017637  790.48504146  862.79499793  673.26958918]
# Number of cases caused  36053.96546871307
# Number of cases inc/100.000  360.15082747855126
# Population under up until 18y  10010796.232547948
# Country....  Namibia
# Population ->  2982699.8
# Proportions ->  [0.10095762 0.1178216  0.10733058 0.08148387]
# Incidence ->  [1640.93988001  848.80694917  762.85371457  506.57591505]
# Number of cases caused  79.04383651904992
# Number of cases inc/100.000  6.501767688090026
# Population under up until 18y  1215728.4035823497
# Country....  Niger
# Population ->  29652588.0
# Proportions ->  [0.15486784 0.16000756 0.13095429 0.08830746]
# Incidence ->  [2529.1438442   894.83986504  677.1854098   484.66578362]
# Number of cases caused  5096.888939845459
# Number of cases inc/100.000  32.18028446430342
# Population under up until 18y  15838545.322678171
# Country....  Nigeria
# Population ->  252850430.0
# Proportions ->  [0.12894218 0.13948093 0.11988    0.08584869]
# Incidence ->  [2487.9204675   842.77747852  651.73803387  473.5565701 ]
# Number of cases caused  83239.44713379182
# Number of cases inc/100.000  69.43011023423712
# Population under up until 18y  119889550.58974555
# Country....  Nicaragua
# Population ->  6760911.0
# Proportions ->  [0.07593349 0.09143582 0.08481454 0.06760021]
# Incidence ->  [4030.7849156  1064.50457523 1291.23679468  850.84695763]
# Number of cases caused  439.8386755097645
# Number of cases inc/100.000  20.343777899205545
# Population under up until 18y  2162030.4630190684
# Country....  Netherlands
# Population ->  17850448.0
# Proportions ->  [0.04890519 0.05692111 0.04864292 0.04057429]
# Incidence ->  [1456.98627196  407.59548132  520.59764378  382.22918652]
# Number of cases caused  1338.2996183202577
# Number of cases inc/100.000  38.439057579229214
# Population under up until 18y  3481614.0212641847
# Country....  Norway
# Population ->  5992047.5
# Proportions ->  [0.053371   0.06099641 0.05142186 0.0441161 ]
# Incidence ->  [2792.67613443  727.21733906  954.51134135  634.73146607]
# Number of cases caused  1.4266074099150492
# Number of cases inc/100.000  0.11342417983856
# Population under up until 18y  1257763.0377804644
# Country....  Nepal
# Population ->  40950624.0
# Proportions ->  [0.07235557 0.08960297 0.07796538 0.06346969]
# Incidence ->  [1209.4682867   514.34132025  328.37819066  276.78963965]
# Number of cases caused  2853.226499768002
# Number of cases inc/100.000  22.96515019571582
# Population under up until 18y  12424157.801938849
# Country....  New Zealand
# Population ->  5273856.0
# Proportions ->  [0.05558508 0.06577934 0.05885743 0.04912025]
# Incidence ->  [4717.26697186 1038.20748572  702.12979584  478.81321226]
# Number of cases caused  314.9425902064131
# Number of cases inc/100.000  26.038708738939768
# Population under up until 18y  1209516.9286771507
# Country....  Oman
# Population ->  4012189.5
# Proportions ->  [0.05853675 0.07632219 0.07533418 0.05175539]
# Incidence ->  [3843.2623506   779.6956483   757.22648119  591.73818975]
# Number of cases caused  859.1491904160819
# Number of cases inc/100.000  81.74692636982427
# Population under up until 18y  1050986.5368262026
# Country....  Pakistan
# Population ->  244536340.0
# Proportions ->  [0.09548557 0.11207791 0.10207906 0.07493042]
# Incidence ->  [1664.98001526  529.96513955  328.88327247  296.82359358]
# Number of cases caused  81309.81587669133
# Number of cases inc/100.000  86.46106540773516
# Population under up until 18y  94042116.52175294
# Country....  Panama
# Population ->  4460000.5
# Proportions ->  [0.07393756 0.08642516 0.07718179 0.06148775]
# Incidence ->  [5564.55279795 1214.01001427 1513.52388518 1014.48011682]
# Number of cases caused  1241.8877920837622
# Number of cases inc/100.000  93.11708355105486
# Population under up until 18y  1333684.1583991959
# Country....  Peru
# Population ->  32811166.0
# Proportions ->  [0.06963374 0.0847865  0.07601095 0.05586736]
# Incidence ->  [7130.40041485 1472.10881485 1356.38868954  827.13233634]
# Number of cases caused  16096.2838144539
# Number of cases inc/100.000  171.3503216271635
# Population under up until 18y  9393786.753127528
# Country....  Philippines
# Population ->  125228050.0
# Proportions ->  [0.08089584 0.09368418 0.08300803 0.07124315]
# Incidence ->  [7054.99332006  851.18724845  914.43994579  791.95374291]
# Number of cases caused  72455.1408456064
# Number of cases inc/100.000  175.95199901729535
# Population under up until 18y  41178924.50797581
# Country....  Papua New Guinea
# Population ->  9536360.0
# Proportions ->  [0.10028513 0.11342666 0.09983082 0.07547881]
# Incidence ->  [8999.19944788 1206.66842343 1119.44804654 1074.14058522]
# Number of cases caused  34.0623959934783
# Number of cases inc/100.000  0.9181616184781389
# Population under up until 18y  3709847.515727898
# Country....  Poland
# Population ->  37922504.0
# Proportions ->  [0.04187243 0.05333225 0.04992936 0.0402236 ]
# Incidence ->  [2459.55159267  839.65558619  726.82526962  685.79772157]
# Number of cases caused  1819.055785545202
# Number of cases inc/100.000  25.8784763812136
# Population under up until 18y  7029222.890671184
# Country....  Puerto Rico
# Population ->  3474375.8
# Proportions ->  [0.03930181 0.04102257 0.02970395 0.04415612]
# Incidence ->  [11808.9630006   1687.75559378  2057.3964325   1602.23904129]
# Number of cases caused  1620.9789721973434
# Number of cases inc/100.000  302.5938358973057
# Population under up until 18y  535694.6440731434
# Country....  Democratic People's Republic of Korea
# Population ->  25592082.0
# Proportions ->  [0.06018219 0.07205372 0.06367713 0.04914496]
# Incidence ->  [3258.63852704  742.0127275   636.84258303  504.86644761]
# Number of cases caused  3082.214414359553
# Number of cases inc/100.000  49.14604144773996
# Population under up until 18y  6271541.559734903
# Country....  Portugal
# Population ->  11081253.0
# Proportions ->  [0.0392769  0.04575932 0.03984966 0.03537898]
# Incidence ->  [2487.03361988  641.14469182  894.73365335  611.70312122]
# Number of cases caused  434.2764827643267
# Number of cases inc/100.000  24.45339784024203
# Population under up until 18y  1775935.1301668775
# Country....  Paraguay
# Population ->  8378024.0
# Proportions ->  [0.07922069 0.09461127 0.08505956 0.06592711]
# Incidence ->  [7477.57596946 1630.18619076 1802.20279265 1109.23091845]
# Number of cases caused  5966.158817151585
# Number of cases inc/100.000  219.2361647229367
# Population under up until 18y  2721338.801329341
# Country....  State of Palestine
# Population ->  5579556.0
# Proportions ->  [0.10306631 0.1186665  0.10538699 0.0818229 ]
# Incidence ->  [4720.98300707  875.53933724  833.84901783  659.72730191]
# Number of cases caused  4722.23233547079
# Number of cases inc/100.000  206.95949750051352
# Population under up until 18y  2281718.1103075845
# Country....  Qatar
# Population ->  3029320.0
# Proportions ->  [0.03914287 0.04786497 0.04314221 0.03515615]
# Incidence ->  [3750.13796571  767.42011973  739.83464889  556.51406646]
# Number of cases caused  1045.99089983425
# Number of cases inc/100.000  208.87846280922167
# Population under up until 18y  500765.3186291407
# Country....  Romania
# Population ->  19695578.0
# Proportions ->  [0.04443337 0.0539555  0.05009807 0.04116918]
# Incidence ->  [2162.20592496  750.71386511  694.33551145  644.91951426]
# Number of cases caused  790.4186114547415
# Number of cases inc/100.000  21.16029857683319
# Population under up until 18y  3735384.9643696006
# Country....  Russian Federation
# Population ->  139611860.0
# Proportions ->  [0.04915731 0.06403862 0.0634953  0.05140889]
# Incidence ->  [1545.14540703  752.10904606  681.31151143  494.41761315]
# Number of cases caused  13046.61406945577
# Number of cases inc/100.000  40.968477144487714
# Population under up until 18y  31845494.33810523
# Country....  Rwanda
# Population ->  16842354.0
# Proportions ->  [0.10881327 0.12492633 0.11243012 0.07993726]
# Incidence ->  [4777.28385325 1161.91966516 1057.92814554  768.09547708]
# Number of cases caused  6218.296843539652
# Number of cases inc/100.000  86.6463163128154
# Population under up until 18y  7176643.056688075
# Country....  Saudi Arabia
# Population ->  41718332.0
# Proportions ->  [0.06139104 0.07763553 0.07343388 0.05867701]
# Incidence ->  [3125.19643477  717.79354035  665.68717604  480.45563208]
# Number of cases caused  1797.2685696909443
# Number of cases inc/100.000  15.889002536962709
# Population under up until 18y  11311399.601768233
# Country....  Sudan
# Population ->  52033920.0
# Proportions ->  [0.11510475 0.12646521 0.10970958 0.0807899 ]
# Incidence ->  [4569.08598331  830.9996888   812.77063625  637.82364666]
# Number of cases caused  8431.018018230034
# Number of cases inc/100.000  37.50073998968463
# Population under up until 18y  22482271.071315292
# Country....  Senegal
# Population ->  18602842.0
# Proportions ->  [0.11988969 0.13332433 0.11720719 0.08685549]
# Incidence ->  [2129.72429935  834.80281723  645.76225352  455.85408612]
# Number of cases caused  5282.927605341602
# Number of cases inc/100.000  62.10353879003573
# Population under up until 18y  8506645.045143913
# Country....  Singapore
# Population ->  6236800.0
# Proportions ->  [0.0403827  0.04852767 0.04139754 0.02976043]
# Incidence ->  [2404.05324732  606.5489419   496.14423346  390.98486373]
# Number of cases caused  5206.2577044989175
# Number of cases inc/100.000  521.5049627275762
# Population under up until 18y  998314.1248108435
# Country....  Solomon Islands
# Population ->  748808.06
# Proportions ->  [0.1144382  0.12880844 0.11579236 0.082945  ]
# Incidence ->  [7800.16103678 1264.89295864 1023.26750468  971.2403943 ]
# Number of cases caused  6.004468848152674
# Number of cases inc/100.000  1.8142518053966916
# Population under up until 18y  330961.16152629536
# Country....  Sierra Leone
# Population ->  8754925.0
# Proportions ->  [0.11113168 0.12611929 0.11254742 0.08383604]
# Incidence ->  [2586.44988281  925.47270248  697.34176206  508.06357895]
# Number of cases caused  960.4227641879542
# Number of cases inc/100.000  25.29799948965404
# Population under up until 18y  3796437.598082537
# Country....  El Salvador
# Population ->  6479347.5
# ...
# Number of cases caused  5462.788043175681
# Number of cases inc/100.000  192.68017727566348
# Population under up until 18y  2835158.302434082
# Country....  State of Palestine
# Population ->  6216437.5
# Proportions ->  [0.08381243 0.09968406 0.09548067 0.07341009]
# Incidence ->  [4720.98300707  875.53933724  833.84901783  659.72730191]
# Number of cases caused  3041.218756813841
# Number of cases inc/100.000  138.83080638625663
# Population under up until 18y  2190593.5980466236
# Country....  Qatar
# Population ->  3778571.0
# Proportions ->  [0.03717496 0.04481347 0.0436339  0.03597062]
# Incidence ->  [3750.13796571  767.42011973  739.83464889  556.51406646]
# Number of cases caused  1002.2741597496876
# Number of cases inc/100.000  164.14830942290047
# Population under up until 18y  610590.6075264516
# Country....  Romania
# Population ->  17559112.0
# Proportions ->  [0.04697349 0.05886365 0.05929663 0.04771116]
# Incidence ->  [2162.20592496  750.71386511  694.33551145  644.91951426]
# Number of cases caused  256.0198853040424
# Number of cases inc/100.000  6.8502716359303015
# Population under up until 18y  3737368.3688862016
# Country....  Russian Federation
# Population ->  136708420.0
# Proportions ->  [0.05725101 0.06835935 0.06388654 0.04925843]
# Incidence ->  [1545.14540703  752.10904606  681.31151143  494.41761315]
# Number of cases caused  3542.303695445272
# Number of cases inc/100.000  10.85268826116428
# Population under up until 18y  32639873.275649145
# Country....  Rwanda
# Population ->  22958144.0
# Proportions ->  [0.08937354 0.10636023 0.10084252 0.07653129]
# Incidence ->  [4777.28385325 1161.91966516 1057.92814554  768.09547708]
# Number of cases caused  7489.605881428357
# Number of cases inc/100.000  87.43559664003439
# Population under up until 18y  8565854.376521828
# Country....  Saudi Arabia
# Population ->  54235172.0
# Proportions ->  [0.05384844 0.06518354 0.06340412 0.05057792]
# Incidence ->  [3125.19643477  717.79354035  665.68717604  480.45563208]
# Number of cases caused  1672.8631309249245
# Number of cases inc/100.000  13.237221631853973
# Population under up until 18y  12637569.857554974
# Country....  Sudan
# Population ->  65859536.0
# Proportions ->  [0.09683432 0.11307022 0.10645363 0.07972539]
# Incidence ->  [4569.08598331  830.9996888   812.77063625  637.82364666]
# Number of cases caused  8184.316998106382
# Number of cases inc/100.000  31.37452347638067
# Population under up until 18y  26085868.696197696
# Country....  Senegal
# Population ->  23998222.0
# Proportions ->  [0.10285234 0.11879197 0.10984537 0.08059482]
# Incidence ->  [2129.72429935  834.80281723  645.76225352  455.85408612]
# Number of cases caused  5547.5793532225325
# Number of cases inc/100.000  56.096807089137926
# Population under up until 18y  9889296.09560027
# Country....  Singapore
# Population ->  6722587.5
# Proportions ->  [0.03545012 0.04252679 0.04370944 0.03918599]
# Incidence ->  [2404.05324732  606.5489419   496.14423346  390.98486373]
# Number of cases caused  5185.355683503512
# Number of cases inc/100.000  479.4692655918026
# Population under up until 18y  1081478.2209456733
# Country....  Solomon Islands
# Population ->  932247.4
# Proportions ->  [0.10294885 0.1182035  0.1086984  0.07899359]
# Incidence ->  [7800.16103678 1264.89295864 1023.26750468  971.2403943 ]
# Number of cases caused  1.0689182909975565
# Number of cases inc/100.000  0.28044995449326554
# Population under up until 18y  381144.04152032925
# Country....  Sierra Leone
# Population ->  11274036.0
# Proportions ->  [0.09111114 0.10790383 0.10297091 0.07896233]
# Incidence ->  [2586.44988281  925.47270248  697.34176206  508.06357895]
# Number of cases caused  985.146697731729
# Number of cases inc/100.000  22.93801134672562
# Population under up until 18y  4294821.738643694
# Country....  El Salvador
# Population ->  6201797.0
# Proportions ->  [0.05843347 0.07222564 0.07275092 0.05978253]
# Incidence ->  [5022.65150696 1233.22856214 1529.30815223 1021.24435862]
# Number of cases caused  2798.9057217353484
# Number of cases inc/100.000  171.47355435036454
# Population under up until 18y  1632266.6969487695
# Country....  Somalia
# Population ->  16131355.0
# Proportions ->  [0.12052874 0.13365482 0.12127722 0.08818107]
# Incidence ->  [3147.2395947   916.40533664  863.09482742  606.34363332]
# Number of cases caused  704.2510908513084
# Number of cases inc/100.000  9.416167780923256
# Population under up until 18y  7479168.885224096
# Country....  Serbia
# Population ->  7669823.0
# Proportions ->  [0.04203725 0.05391116 0.0565447  0.04723428]
# Incidence ->  [1429.72113878  584.32631395  550.74782336  498.87607437]
# Number of cases caused  2.558225008183436
# Number of cases inc/100.000  0.16699975826544394
# Population under up until 18y  1531873.479791013
# Country....  South Sudan
# Population ->  15747296.0
# Proportions ->  [0.10033378 0.1159186  0.10872167 0.08167322]
# Incidence ->  [3969.02524514  964.76694099  894.13953963  656.20498753]
# Number of cases caused  1989.4877965636135
# Number of cases inc/100.000  31.06831921564902
# Population under up until 18y  6403590.045391044
# Country....  Sao Tome and Principe
# Population ->  207235.4
# Proportions ->  [0.1013422  0.11752372 0.10946585 0.08130736]
# Incidence ->  [2442.28909832  958.82899146  743.16611279  566.43935729]
# Number of cases caused  0.6573939362138976
# Number of cases inc/100.000  0.7743910815606087
# Population under up until 18y  84891.72355769775
# Country....  Suriname
# Population ->  661254.25
# Proportions ->  [0.06380265 0.07862651 0.07866805 0.0632978 ]
# Incidence ->  [8681.07326476 1498.94555463 1760.44216728 1328.68279025]
# Number of cases caused  221.51011543096436
# Number of cases inc/100.000  117.78860393298339
# Population under up until 18y  188057.34004368878
# Country....  Slovakia
# Population ->  5539414.5
# Proportions ->  [0.04604975 0.05603166 0.05494546 0.04492039]
# Incidence ->  [1447.96034614  581.51255164  556.01145005  499.00466467]
# Number of cases caused  9.86033344248291
# Number of cases inc/100.000  0.8814342165903366
# Population under up until 18y  1118669.2389394373
# Country....  Slovenia
# Population ->  2212949.0
# Proportions ->  [0.0464847  0.05690268 0.05481234 0.04285773]
# Incidence ->  [2157.86098072  749.15903899  695.85207567  643.22538731]
# Number of cases caused  2.2552120889044334
# Number of cases inc/100.000  0.5068690159086765
# Population under up until 18y  444929.95589037135
# Country....  Sweden
# Population ->  12498127.0
# Proportions ->  [0.05334131 0.0639143  0.06158974 0.04937768]
# Incidence ->  [2075.30815086  693.12195337  885.17808603  640.96171198]
# Number of cases caused  0.9361407211742889
# Number of cases inc/100.000  0.03281987375351173
# Population under up until 18y  2852359.299749353
# Country....  Seychelles
# Population ->  99595.2
# Proportions ->  [0.06179779 0.07627475 0.07496057 0.05814614]
# Incidence ->  [4332.46969955  826.06622549  810.46729724  680.46105259]
# Number of cases caused  0.0
# Number of cases inc/100.000  0.0
# Population under up until 18y  27008.153998957758
# Country....  Syrian Arab Republic
# Population ->  33294062.0
# Proportions ->  [0.06913322 0.082103   0.07726982 0.05981997]
# Incidence ->  [4762.8223167   981.95939132  824.25418888  638.9014285 ]
# Number of cases caused  5793.063707939574
# Number of cases inc/100.000  60.347285849285626
# Population under up until 18y  9599543.088660963
# Country....  Chad
# Population ->  25131790.0
# Proportions ->  [0.11150064 0.12715335 0.11676473 0.0858687 ]
# Incidence ->  [2365.66672385  840.8197657   653.61283173  470.73946626]
# Number of cases caused  1534.3989584267522
# Number of cases inc/100.000  13.835440980845549
# Population under up until 18y  11090350.936779303
# Country....  Togo
# Population ->  10168086.0
# Proportions ->  [0.10251206 0.11760546 0.10894048 0.08065151]
# Incidence ->  [2736.25514627  995.3718456   739.76837615  532.24422705]
# Number of cases caused  2403.9475874298214
# Number of cases inc/100.000  57.70449622803482
# Population under up until 18y  4165962.350541935
# Country....  Thailand
# Population ->  73688000.0
# Proportions ->  [0.04199187 0.05257204 0.05364303 0.04449366]
# Incidence ->  [4239.72163416  732.12964178  860.35801622  735.97201783]
# Number of cases caused  21144.009549137936
# Number of cases inc/100.000  148.90434052118758
# Population under up until 18y  14199726.801200503
# Country....  Tajikistan
# Population ->  8270009.5
# Proportions ->  [0.09483141 0.1140588  0.10596156 0.07470691]
# Incidence ->  [1626.35891928  669.29262054  571.48628617  436.5446171 ]
# Number of cases caused  971.7568443535661
# Number of cases inc/100.000  30.16329933248728
# Population under up until 18y  3221653.0215808935
# Country....  Turkmenistan
# Population ->  6390211.5
# Proportions ->  [0.07400309 0.09024869 0.08562331 0.06441446]
# Incidence ->  [1707.50533612  688.57206888  590.08669543  452.07046206]
# Number of cases caused  505.339149016355
# Number of cases inc/100.000  25.161535564103804
# Population under up until 18y  2008379.6067569375
# Country....  Timor-Leste
# Population ->  2002030.6
# Proportions ->  [0.08228457 0.09767262 0.09636834 0.07707725]
# Incidence ->  [4455.67968559  769.69101304  789.23986362  652.62393999]
# Number of cases caused  160.43458498999723
# Number of cases inc/100.000  22.675522022655027
# Population under up until 18y  707523.2262776913
# Country....  Tonga
# Population ->  102639.72
# Proportions ->  [0.08288283 0.10257024 0.10201596 0.07801059]
# Incidence ->  [10394.2751981   1412.93926901  1132.88231558  1161.99850676]
# Number of cases caused  0.0
# Number of cases inc/100.000  0.0
# Population under up until 18y  37512.726818057294
# Country....  Trinidad and Tobago
# Population ->  1239042.5
# Proportions ->  [0.04982174 0.06275377 0.06318196 0.05024447]
# Incidence ->  [9099.89958055 1529.76106263 1852.98320156 1396.17925228]
# Number of cases caused  102.64127515727893
# Number of cases inc/100.000  36.654193169914606
# Population under up until 18y  280026.0114346913
# Country....  Tunisia
# Population ->  12748625.0
# Proportions ->  [0.05852289 0.07026903 0.0671031  0.05266147]
# Incidence ->  [3654.73467571  758.35477001  739.40598627  574.4738709 ]
# Number of cases caused  1918.9981872403696
# Number of cases inc/100.000  60.560078733328154
# Population under up until 18y  3168751.1432911716
# Country....  Turkey
# Population ->  95869650.0
# Proportions ->  [0.05395429 0.066963   0.06778988 0.05504711]
# Incidence ->  [3892.3139714   741.4979776   702.50827146  571.66058578]
# Number of cases caused  3395.3198947885576
# Number of cases inc/100.000  14.529395001876292
# Population under up until 18y  23368625.426936865
# Country....  Taiwan
# Population ->  21260308.0
# Proportions ->  [0.03555413 0.04532604 0.04954082 0.04379613]
# Incidence ->  [5919.1437892   805.79882667  570.00889452  471.56791624]
# Number of cases caused  3524.4363407368314
# Number of cases inc/100.000  95.15452205702847
# Population under up until 18y  3703908.4055559114
# Country....  United Republic of Tanzania
# Population ->  102119080.0
# Proportions ->  [0.11318998 0.12735692 0.11513886 0.08330518]
# Incidence ->  [4662.70838973 1173.77916975 1052.2860645   738.92442035]
# Number of cases caused  11376.350736852552
# Number of cases inc/100.000  25.37701363382252
# Population under up until 18y  44829351.8733431
# Country....  Uganda
# Population ->  92730150.0
# Proportions ->  [0.0970364  0.11451501 0.10843844 0.08235828]
# Incidence ->  [3964.31544789 1064.57151434  951.34945142  674.08509497]
# Number of cases caused  20095.112908495
# Number of cases inc/100.000  53.86016407715616
# Population under up until 18y  37309787.76764995
# Country....  Ukraine
# Population ->  38902750.0
# Proportions ->  [0.04715817 0.05895063 0.05849876 0.04647482]
# Incidence ->  [2052.65485736  900.70312555  782.62300749  565.58408186]
# Number of cases caused  628.4619704683228
# Number of cases inc/100.000  7.653263126628008
# Population under up until 18y  8211686.441064783
# Country....  Uruguay
# Population ->  3327044.0
# Proportions ->  [0.05428307 0.06649795 0.06647327 0.0543834 ]
# Incidence ->  [3299.26649664  810.03103721  551.20976947  398.68055636]
# Number of cases caused  133.23382983651877
# Number of cases inc/100.000  16.57262382063554
# Population under up until 18y  803939.2631999622
# Country....  United States of America
# Population ->  401977250.0
# Proportions ->  [0.05356031 0.0653752  0.06533855 0.05340528]
# Incidence ->  [3657.58160135  944.50359176  684.11656103  620.66974814]
# Number of cases caused  43175.06047523754
# Number of cases inc/100.000  45.18978265671591
# Population under up until 18y  95541642.24071799
# Country....  Uzbekistan
# Population ->  33526986.0
# Proportions ->  [0.06712564 0.08292455 0.08050495 0.06150326]
# Incidence ->  [2094.91678918  779.27193189  647.1443566   503.97157243]
# Number of cases caused  4549.203746955088
# Number of cases inc/100.000  46.45915647818748
# Population under up until 18y  9791834.574290933
# Country....  Saint Vincent and the Grenadines
# Population ->  95967.55
# Proportions ->  [0.05328185 0.06629439 0.06786728 0.05621125]
# Incidence ->  [8296.54096912 1459.94772488 1715.06902591 1284.46414142]
# Number of cases caused  2.2974382553196477
# Number of cases inc/100.000  9.825271577170888
# Population under up until 18y  23382.949135551302
# Country....  Venezuela (Bolivarian Republic of)
# Population ->  41608360.0
# Proportions ->  [0.06219164 0.07577453 0.07650174 0.06300762]
# Incidence ->  [4097.77857806 1100.90099954 1341.04723842  887.85353814]
# Number of cases caused  17984.55907022009
# Number of cases inc/100.000  155.77358541331006
# Population under up until 18y  11545320.101930067
# Country....  United States Virgin Islands
# Population ->  115740.0
# Proportions ->  [0.04807475 0.06191736 0.06590652 0.05352732]
# Incidence ->  [8936.85922645 1456.34396512 1747.93518497 1327.96368607]
# Number of cases caused  21.69024584231248
# Number of cases inc/100.000  81.68428600481636
# Population under up until 18y  26553.755811777006
# Country....  Viet Nam
# Population ->  104221550.0
# Proportions ->  [0.05663443 0.0674494  0.0651226  0.05300078]
# Incidence ->  [3441.69371124  726.65561704  717.79566473  577.96927679]
# Number of cases caused  43028.90533346961
# Number of cases inc/100.000  170.45732377233753
# Population under up until 18y  25243213.01145085
# Country....  Vanuatu
# Population ->  424158.28
# Proportions ->  [0.09498426 0.10989138 0.10229789 0.07615519]
# Incidence ->  [8486.65353487 1315.43098567 1066.27801432 1036.85661397]
# Number of cases caused  0.01751244256418812
# Number of cases inc/100.000  0.010770786773310722
# Population under up until 18y  162592.04580655857
# Country....  Western Samoa
# Population ->  166094.94
# Proportions ->  [0.08860833 0.10812785 0.10263876 0.07516436]
# Incidence ->  [8010.80265147 1289.56070073 1026.28846587  991.32370564]
# Number of cases caused  0.0
# Number of cases inc/100.000  0.0
# Population under up until 18y  62209.07319507181
# Country....  Yemen
# Population ->  56907950.0
# Proportions ->  [0.07929093 0.09694568 0.09503531 0.07469668]
# Incidence ->  [3558.64639663  755.72171163  751.82646464  581.3474181 ]
# Number of cases caused  4734.050831262177
# Number of cases inc/100.000  24.044901922304437
# Population under up until 18y  19688376.548838384
# Country....  South Africa
# Population ->  63106100.0
# Proportions ->  [0.07026397 0.0852655  0.08349419 0.06584904]
# Incidence ->  [874.28637042 523.2973822  445.35290263 319.5452059 ]
# Number of cases caused  3466.445735286611
# Number of cases inc/100.000  18.017500164521433
# Population under up until 18y  19239326.785812654
# Country....  Zambia
# Population ->  30011614.0
# Proportions ->  [0.1096863  0.12482948 0.11411714 0.08358788]
# Incidence ->  [3278.54933979  906.52535486  843.1751051   604.87309437]
# Number of cases caused  2782.5190285454305
# Number of cases inc/100.000  21.45079114282966
# Population under up until 18y  12971638.248762403
# Country....  Zimbabwe
# Population ->  13274143.0
# Proportions ->  [0.08856133 0.10813341 0.10460513 0.07890796]
# Incidence ->  [1331.2482735   744.2769308   684.59405894  446.97310845]
# Number of cases caused  865.2235552699204
# Number of cases inc/100.000  17.143562387098967
# Population under up until 18y  5046929.778848219

# %%
#results.to_csv("./pwc_mediumpop.csv")
results.to_csv("./asthma_highvariant_lowfunction.csv",index=False)
#results=pd.read_csv("./asthma_estimates_v2.csv")
#results=results.iloc[:,1:]
#results.head()

# %%
# Out:
#    1-18 population      NO2cases  NO2incidence               country scenario  \
# 0     1.663338e+07  26338.797225    158.349041           Afghanistan
# 1     1.294021e+07  29418.076158    227.338471                Angola
# 2     6.986212e+05    326.811545     46.779503               Albania
# 3     1.449896e+06   6831.962321    471.203497  United Arab Emirates
# 4     1.301828e+07  15271.266101    117.306338             Argentina
#
#      year
# 0  2015.0
# 1  2015.0
# 2  2015.0
# 3  2015.0
# 4  2015.0

# %%
np.unique(results["country"][results.iloc[:,0]==""])
# Out:
# array(['Aruba', 'Curaçao', 'French Guiana', 'French Polynesia',
#        'Guadeloupe', 'Martinique', 'Mayotte', 'New Caledonia', 'Réunion',
#        'State of Palestine',
#        'United Kingdom of Great Britain and Northern Ireland',
#        'United States Virgin Islands', 'Western Sahara'], dtype=object)

# %%
# conc_raster=gdal.Open("./data/nox/Exposure_2011_Susan_extended.tif")
# trans=conc_raster.GetGeoTransform()
# projection=conc_raster.GetProjection()

# conc_array=(100*conc_raster.ReadAsArray())
# conc_array[conc_array<0]=-10
# rows,cols=conc_array.shape

# # create the output image
# driver = gdal.GetDriverByName( 'GTiff' )
# #print driver
# outDs = driver.Create("./data/nox/Exposure_2011_Susan_extended_int.tif", cols, rows, 1, gdalconst.GDT_Int16)


# outBand = outDs.GetRasterBand(1)

# # write the data
# outBand.WriteArray(conc_array)

# # flush data to disk, set the NoData value and calculate stats
# outBand.FlushCache()
# outBand.SetNoDataValue(-10)

# # georeference the image and set the projection
# outDs.SetGeoTransform(trans)
# outDs.SetProjection(projection)
# outDs = None
# del conc_array
# conc_raster=None

# %%
paper_data=pd.read_csv("./data_papers2.csv")
paper_data.columns=["country"]+list(paper_data.columns[1:])
paper_data.sort_values(by="country",inplace=True)
paper_data.head()
# Out:
#   country  NO2incidence  NO2cases   children
# 2  Brazil           220    140000   62000000
# 3  Canada           450     34000    7500000
# 9   Chile           320     16000    5000000
# 4   China           260    760000  290000000
# 5  France           180     26000   14000000

# %%
results.head()
# Out:
#    1-18 population       NO2cases  NO2incidence                   country  \
# 0     7.904812e+07  321528.599946    406.750459  United States of America
# 1     4.783155e+08  831578.825803    173.855705                     India
# 2     7.389690e+06   31399.515467    424.909756                    Canada
# 3     8.130768e+06   11044.025054    135.830028                     Spain
# 4     1.419576e+07   30760.376780    216.687122                    France
#
#   scenario    year
# 0           2010.0
# 1           2010.0
# 2           2010.0
# 3           2010.0
# 4           2010.0

# %%
choice=results
choice.sort_values(by="country",inplace=True)
#choice.drop(9,inplace=True)#China is duplicated


choice["paperpopulation"]=paper_data["children"].values
choice["papercases"]=paper_data["NO2cases"].values
choice["paperincidence"]=paper_data["NO2incidence"].values

# %%
plt.figure(figsize=(12,10))
import seaborn as sns
x=choice["1-18 population"]
y=choice["paperpopulation"]
sns.scatterplot(data=choice,x="1-18 population",y="paperpopulation",hue="country")
plt.xlabel("Our module",fontsize=20)
plt.ylabel("Achakulwisut et al",fontsize=20)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title("1-18y population",fontsize=32)
plt.plot([0,max(max(x),max(y))],[0,max(max(x),max(y))],"k-")
#plt.savefig("/home/gaia/Desktop/asthma/population_comparison.png")
plt.show()

# %%
plt.figure(figsize=(12,10))
import seaborn as sns
x=choice["NO2cases"]
y=choice["papercases"]
sns.scatterplot(data=choice,x="NO2cases",y="papercases",hue="country")
plt.xlabel("Our module",fontsize=20)
plt.ylabel("Achakulwisut et al",fontsize=20)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title("Asthma NO2 cases",fontsize=32)
plt.plot([0,max(max(x),max(y))],[0,max(max(x),max(y))],"k-")
plt.savefig("/home/gaia/Desktop/asthma/EMEP_cases_comparison_threshold5.png")
plt.show()

# %%
choice
# Out:
#     1-18 population      NO2cases  NO2incidence                   country  \
# 7      6.295025e+07  4.390324e+05    697.427604                    Brazil
# 2      7.389690e+06  3.139952e+04    424.909756                    Canada
# 12     4.934539e+06  1.940829e+04    393.315119                     Chile
# 11     3.193627e+08  1.014520e+06    317.670193                     China
# 4      1.419576e+07  3.076038e+04    216.687122                    France
# 1      4.783155e+08  8.315788e+05    173.855705                     India
# 9      1.133978e+06  1.459925e+03    128.743636                   Ireland
# 6      2.060197e+07  5.739741e+04    278.601503                     Japan
# 10     2.240358e+07  2.600554e+04    116.077610                     Kenya
# 8      8.874167e+07  3.331337e+05    375.397188                   Nigeria
# 5      1.189597e+06  5.297797e+02     44.534376                    Norway
# 13     1.932606e+07  1.396268e+04     72.247954              South Africa
# 3      8.130768e+06  1.104403e+04    135.830028                     Spain
# 0      7.904812e+07  3.215286e+05    406.750459  United States of America
#
#    scenario    year  paperpopulation  papercases  paperincidence
# 7            2010.0         62000000      140000             220
# 2            2010.0          7500000       34000             450
# 12           2010.0          5000000       16000             320
# 11           2010.0        290000000      760000             260
# 4            2010.0         14000000       26000             180
# 1            2010.0        490000000      350000              72
# 9            2010.0          1200000        1700             150
# 6            2010.0         21000000       57000             280
# 10           2010.0         22000000       14000              64
# 8            2010.0         86000000      110000             130
# 5            2010.0          1200000        1600             140
# 13           2010.0         19000000       34000             180
# 3            2010.0          8200000       14000             170
# 0            2010.0         78000000      240000             300

# %%
plt.figure(figsize=(12,10))
import seaborn as sns
x=choice["NO2incidence"]
y=choice["paperincidence"]
sns.scatterplot(data=choice,x="NO2incidence",y="paperincidence",hue="country",s=80)
plt.xlabel("Our module",fontsize=20)
plt.ylabel("Achakulwisut et al",fontsize=20)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title("Asthma NO2 incidence",fontsize=32)
plt.plot([0,max(max(x),max(y))],[0,max(max(x),max(y))],"k-")
plt.savefig("/home/gaia/Desktop/asthma/EMEP_inc_comparison_threshold5.png")
plt.show()

# %%
plt.figure(figsize=(12,10))
import seaborn as sns
results["year"]=[int(x) for x in results["year"]]
data=results.loc[results.scenario!="MFR",:]
sns.barplot(data=data,x="country",y="NO2incidence",hue="year")
plt.xlabel("Country",fontsize=20)
plt.ylabel("NO2 asthma incidence",fontsize=20)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title("CLE - Asthma trends",fontsize=32)
plt.savefig("/home/gaia/Desktop/asthma/CE.png")
plt.show()
# Out:
# /usr/local/lib/python3.5/dist-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize=(12,10))
import seaborn as sns
results["year"]=[int(x) for x in results["year"]]
data=results.loc[results.scenario!="CLE",:]
sns.barplot(data=data,x="country",y="NO2incidence",hue="year")
plt.xlabel("Country",fontsize=20)
plt.ylabel("NO2 asthma incidence",fontsize=20)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title("MFR - Asthma trends",fontsize=32)
plt.savefig("/home/gaia/Desktop/asthma/MFR.png")
plt.show()
# Out:
# /usr/local/lib/python3.5/dist-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# countries=[x for x in countries_masks if (x not in countries_un)&(x not in un_translate.keys()) ]
# countries
# with open("./data/non_included_countries.txt", "w") as file:
#     file.write(str(countries))

with open("./data/non_included_countries.txt", "r") as file:
    non_included_countries = eval(file.readline())

# %%
scenario_dir="./data/population_projections/ssp1/"
scenarios=os.listdir(scenario_dir)
store_results="/media/gaia/Seagate Expansion Drive/Liliana/fon/asthma/population_projections/"

for scenario in scenarios:
    ds=gdal.Open(os.path.join(scenario_dir,scenario))
    ds = gdal.Translate(os.path.join(store_results,"corrected_"+scenario), ds, 
                        projWin = [-180, 90, 180, -90],format="GTiff",outputType=gdalconst.GDT_Int32)
    ds=None

# %%
nox_dir="/media/gaia/Seagate Expansion Drive/Liliana/fon/Downscaling"
scenarios=os.listdir(scenario_dir)
store_results="/media/gaia/Seagate Expansion Drive/Liliana/fon/asthma/population_projections/"

for scenario in scenarios:
    ds=gdal.Open(os.path.join(scenario_dir,scenario))
    ds = gdal.Translate(os.path.join(store_results,"corrected_"+scenario), ds, 
                        projWin = [-180, 90, 180, -90],format="GTiff",outputType=gdalconst.GDT_Int32)
    ds=None
# Out:
# (-180.0, 0.008333333333333333, 0.0, 90.0, 0.0, -0.008333333333333333)

# %%
nox_dir="/media/gaia/Seagate Expansion Drive/Liliana/fon/Downscaling"
scenarios=os.listdir(nox_dir)[:10]
for scenario in scenarios:
    ds=gdal.Open(os.path.join(nox_dir,scenario))
    ds = gdal.Translate(os.path.join(nox_dir,"extended","extended"+scenario), ds, 
                        projWin = [-180, 90, 180, -90])
    ds=None

# %%
1-np.exp(-10*beta)
# Out:
# 0.26

# %%
beta
# Out:
# 0.03011050927839216
